# %% [markdown]
# <a href="https://colab.research.google.com/github/Nischay-verma/Just_watch_scrapping/blob/main/Numerical_Programming_in_Python_Web_Scraping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Web Scraping & Data Handling Challenge**

# %% [markdown]
# ### **Website:**
# JustWatch -  https://www.justwatch.com/in/movies?release_year_from=2000
#
#
# ### **Description:**
#
# JustWatch is a popular platform that allows users to search for movies and TV shows across multiple streaming services like Netflix, Amazon Prime, Hulu, etc. For this assignment, you will be required to scrape movie and TV show data from JustWatch using Selenium, Python, and BeautifulSoup. Extract data from HTML, not by directly calling their APIs. Then, perform data filtering and analysis using Pandas, and finally, save the results to a CSV file.
#
# ### **Tasks:**
#
# **1. Web Scraping:**
#
# Use BeautifulSoup to scrape the following data from JustWatch:
#
#    **a. Movie Information:**
#
#       - Movie title
#       - Release year
#       - Genre
#       - IMDb rating
#       - Streaming services available (Netflix, Amazon Prime, Hulu, etc.)
#       - URL to the movie page on JustWatch
#
#    **b. TV Show Information:**
#
#       - TV show title
#       - Release year
#       - Genre
#       - IMDb rating
#       - Streaming services available (Netflix, Amazon Prime, Hulu, etc.)
#       - URL to the TV show page on JustWatch
#
#   **c. Scope:**
#
# ```
#  ` - Scrape data for at least 50 movies and 50 TV shows.
#    - You can choose the entry point (e.g., starting with popular movies,
#      or a specific genre, etc.) to ensure a diverse dataset.`
#
# ```
#
#
# **2. Data Filtering & Analysis:**
#
#    After scraping the data, use Pandas to perform the following tasks:
#
#    **a. Filter movies and TV shows based on specific criteria:**
#
#    ```
#       - Only include movies and TV shows released in the last 2 years (from the current date).
#       - Only include movies and TV shows with an IMDb rating of 7 or higher.
# ```
#
#    **b. Data Analysis:**
#
#    ```
#       - Calculate the average IMDb rating for the scraped movies and TV shows.
#       - Identify the top 5 genres that have the highest number of available movies and TV shows.
#       - Determine the streaming service with the most significant number of offerings.
#
#    ```
#
# **3. Data Export:**
#
# ```
#    - Dump the filtered and analysed data into a CSV file for further processing and reporting.
#
#    - Keep the CSV file in your Drive Folder and Share the Drive link on the colab while keeping view access with anyone.
# ```
#
# **Submission:**
# ```
# - Submit a link to your Colab made for the assignment.
#
# - The Colab should contain your Python script (.py format only) with clear
#   comments explaining the scraping, filtering, and analysis process.
#
# - Your Code shouldn't have any errors and should be executable at a one go.
#
# - Before Conclusion, Keep your Dataset Drive Link in the Notebook.
# ```
#
#
#
# **Note:**
#
# 1. Properly handle errors and exceptions during web scraping to ensure a robust script.
#
# 2. Make sure your code is well-structured, easy to understand, and follows Python best practices.
#
# 3. The assignment will be evaluated based on the correctness of the scraped data, accuracy of data filtering and analysis, and the overall quality of the Python code.

# %% [markdown]
# # **Start The Project**

# %% [markdown]
# ## **Task 1:- Web Scrapping**

# %%
#Installing all necessary labraries
# !pip install bs4
# !pip install requests
# Out:
# Collecting bs4
#   Downloading bs4-0.0.2-py2.py3-none-any.whl (1.2 kB)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from bs4) (4.12.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->bs4) (2.5)
# Installing collected packages: bs4
# Successfully installed bs4-0.0.2
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2024.6.2)

# %%
#import all necessary labraries
import requests
from bs4 import BeautifulSoup
import re
import pandas as pd
import numpy as np
import time

# %% [markdown]
# ## **Scrapping Movies Data**

# %%
# Specifying the URL from which movies related data will be fetched
url='https://www.justwatch.com/in/movies?release_year_from=2000'
headers = {
'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36',
'Accept-Language': 'en-US,en;q=0.9',
'Accept-Encoding': 'gzip, deflate, br',
'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
}

# Sending an HTTP GET request to the URL
response=requests.get(url, headers= headers)
# Parsing the HTML content using BeautifulSoup with the 'html.parser'
soup=BeautifulSoup(response.text,'html.parser')
# Printing the prettified HTML content
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html data-vue-meta="%7B%22dir%22:%7B%22ssr%22:%22ltr%22%7D,%22lang%22:%7B%22ssr%22:%22en%22%7D%7D" data-vue-meta-server-rendered="" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta charset="utf-8" data-vue-meta="ssr"/>
#   <meta content="IE=edge" data-vue-meta="ssr" httpequiv="X-UA-Compatible"/>
#   <meta content="viewport-fit=cover, width=device-width, initial-scale=1.0, minimum-scale=1.0, maximum-scale=1.0, user-scalable=no" data-vue-meta="ssr" name="viewport"/>
#   <meta content="JustWatch" data-vue-meta="ssr" property="og:site_name"/>
#   <meta content="794243977319785" data-vue-meta="ssr" property="fb:app_id"/>
#   <meta content="/appassets/img/JustWatch_logo_with_claim.png" data-vmid="og:image" data-vue-meta="ssr" property="og:image"/>
#   <meta content="606" data-vmid="og:image:width" data-vue-meta="ssr" property="og:image:width"/>
#   <meta content="302" data-vmid="og:image:height" data-vue-meta="ssr" property="og:image:height"/>
#   <meta content="yes" data-vue-meta="ssr" name="mobile-web-app-capable"/>
#   <meta content="yes" data-vue-meta="ssr" name="apple-mobile-web-app-capable"/>
#   <meta content="#182531" data-vue-meta="ssr" name="theme-color"/>
#   <meta content="4eBTNBm4L6RaWdF8V51EHZajskAMgXYAg81iRXJqumQ" data-vue-meta="ssr" name="google-site-verification"/>
#   <meta content="d61y4roe8t5xwbb0gfu6gwe8j8iq3i" data-vue-meta="ssr" name="facebook-domain-verification"/>
#   <meta content="dmorpwc4h544ct6mv" data-vue-meta="ssr" name="dailymotion-domain-verification"/>
#   <meta content="Watch movies online" data-vmid="og:title" data-vue-meta="ssr" property="og:title"/>
#   <meta content="movies, watch online, streaming, rental, download" data-vue-meta="ssr" name="keywords"/>
#   <meta content="Where to watch movies online? Find with JustWatch all the movies you can watch online on Netflix, iflix, Hooq and 4 other streaming providers. Purchase, rent online &amp; flat-rate." data-vmid="description" data-vue-meta="ssr" name="description"/>
#   <meta content="Where to watch movies online? Find with JustWatch all the movies you can watch online on Netflix, iflix, Hooq and 4 other streaming providers. Purchase, rent online &amp; flat-rate." data-vmid="og:description" data-vue-meta="ssr" property="og:description"/>
#   <meta content="noindex, follow" data-vmid="robots" data-vue-meta="ssr" name="robots"/>
#   <title>
#    Watch movies online
#   </title>
#   <link as="font" crossorigin="true" data-vue-meta="ssr" href="/appassets/fonts/lato-regular.woff2" rel="preload" type="font/woff2"/>
#   <link as="font" crossorigin="true" data-vue-meta="ssr" href="/appassets/fonts/lato-700.woff2" rel="preload" type="font/woff2"/>
#   <link as="font" crossorigin="true" data-vue-meta="ssr" href="/appassets/fonts/lato-900.woff2" rel="preload" type="font/woff2"/>
#   <link as="font" crossorigin="true" data-vue-meta="ssr" href="/appassets/fonts/anton.woff" rel="preload" type="font/woff2"/>
#   <link data-vue-meta="ssr" href="/appassets/favicon.ico" rel="icon"/>
#   <link crossorigin="use-credentials" data-vue-meta="ssr" href="https://images.justwatch.com" rel="preconnect"/>
#   <link data-vue-meta="ssr" href="https://www.googletagmanager.com/" rel="dns-prefetch"/>
#   <link data-vue-meta="ssr" href="https://ib.adnxs.com" rel="dns-prefetch"/>
#   <link data-vmid="canonical" data-vue-meta="ssr" href="https://www.justwatch.com/in/movies" rel="canonical"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/ar/peliculas" hreflang="es-AR" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/at/Filme" hreflang="de-AT" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/au/movies" hreflang="en-AU" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/be/films" hreflang="fr-BE" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/bg/филми" hreflang="bg-BG" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/br/filmes" hreflang="pt-BR" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/ca/movies" hreflang="en-CA" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/ch/Filme" hreflang="de-CH" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/cl/peliculas" hreflang="es-CL" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/co/peliculas" hreflang="es-CO" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/cz/filmy" hreflang="cs-CZ" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/de/Filme" hreflang="de-DE" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/dk/movies" hreflang="en-DK" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/ec/peliculas" hreflang="es-EC" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/eg/movies" hreflang="ar-EG" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/es/peliculas" hreflang="es-ES" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/fi/elokuvat" hreflang="fi-FI" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/fr/films" hreflang="fr-FR" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/uk/movies" hreflang="en-GB" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/gr/ταινίες" hreflang="el-GR" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/hk/電影" hreflang="zh-HK" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/hr/filmovi" hreflang="hr-HR" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/hu/filmek" hreflang="hu-HU" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/ie/movies" hreflang="en-IE" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/in/movies" hreflang="en-IN" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/iq/movies" hreflang="ar-IQ" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/is/kvikmyndir" hreflang="is-IS" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/it/film" hreflang="it-IT" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/jp/映画" hreflang="ja-JP" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/kr/영화" hreflang="ko-KR" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/lb/movies" hreflang="ar-LB" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/mx/peliculas" hreflang="es-MX" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/my/movies" hreflang="en-MY" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/nl/movies" hreflang="en-NL" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/no/movies" hreflang="en-NO" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/nz/movies" hreflang="en-NZ" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/pe/peliculas" hreflang="es-PE" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/ph/movies" hreflang="en-PH" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/pl/filmy" hreflang="pl-PL" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/ps/movies" hreflang="ar-PS" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/pt/filmes" hreflang="pt-PT" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/ro/filme" hreflang="ro-RO" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/ru/фильмы" hreflang="ru-RU" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/se/filmer" hreflang="sv-SE" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/sg/movies" hreflang="en-SG" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/sk/filmy" hreflang="sk-SK" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/tr/filmler" hreflang="tr-TR" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/us/movies" hreflang="en-US" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/va/film" hreflang="it-VA" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/xk/filmat" hreflang="sq-XK" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/za/movies" hreflang="en-ZA" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/ee/filmid" hreflang="et-EE" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/lt/filmai" hreflang="lt-LT" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/id/movies" hreflang="en-ID" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/th/movies" hreflang="en-TH" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/tw/電影" hreflang="zh-TW" rel="alternate"/>
#   <base href="/" target="_self"/>
#   <link as="image" href="/appassets/img/logo/JustWatch-logo-large.webp" imagesrcset="/appassets/img/logo/JustWatch-logo-large.webp 1px" importance="high" rel="preload"/>
#   <link as="image" href="https://www.justwatch.com/images/icon/207360008/s100/netflix.{format}/icon.webp" imagesrcset="https://www.justwatch.com/images/icon/207360008/s100/netflix.{format}/icon.webp 1px" importance="high" media="(min-width: 0px)" rel="preload"/>
#   <link as="image" href="https://www.justwatch.com/images/icon/52449861/s100/amazonprimevideo.{format}/icon.webp" imagesrcset="https://www.justwatch.com/images/icon/52449861/s100/amazonprimevideo.{format}/icon.webp 1px" importance="high" media="(min-width: 0px)" rel="preload"/>
#   <link as="image" href="https://www.justwatch.com/images/icon/152862153/s100/appletvplus.{format}/icon.webp" imagesrcset="https://www.justwatch.com/images/icon/152862153/s100/appletvplus.{format}/icon.webp 1px" importance="high" media="(min-width: 0px)" rel="preload"/>
#   <link as="image" href="https://www.justwatch.com/images/icon/190848813/s100/itunes.{format}/icon.webp" imagesrcset="https://www.justwatch.com/images/icon/190848813/s100/itunes.{format}/icon.webp 1px" importance="high" media="(min-width: 0px)" rel="preload"/>
#   <link as="image" href="https://www.justwatch.com/images/icon/127445869/s100/crunchyroll.{format}/icon.webp" imagesrcset="https://www.justwatch.com/images/icon/127445869/s100/crunchyroll.{format}/icon.webp 1px" importance="high" media="(min-width: 0px)" rel="preload"/>
#   <link as="image" href="https://www.justwatch.com/images/icon/240029443/s100/hotstar.{format}/icon.webp" imagesrcset="https://www.justwatch.com/images/icon/240029443/s100/hotstar.{format}/icon.webp 1px" importance="high" media="(min-width: 0px)" rel="preload"/>
#   <link as="image" href="https://www.justwatch.com/images/icon/312325227/s100/jiocinema.{format}/icon.webp" imagesrcset="https://www.justwatch.com/images/icon/312325227/s100/jiocinema.{format}/icon.webp 1px" importance="high" media="(min-width: 0px)" rel="preload"/>
#   <link as="image" href="https://www.justwatch.com/images/poster/318152051/s166/aavesham-2024.webp" imagesrcset="https://www.justwatch.com/images/poster/318152051/s166/aavesham-2024.webp 1px, https://www.justwatch.com/images/poster/318152051/s166/aavesham-2024.webp" importance="high" rel="preload"/>
#   <link as="image" href="https://www.justwatch.com/images/poster/317224107/s166/munjha.webp" imagesrcset="https://www.justwatch.com/images/poster/317224107/s166/munjha.webp 1px, https://www.justwatch.com/images/poster/317224107/s166/munjha.webp" importance="high" rel="preload"/>
#   <link as="image" href="https://www.justwatch.com/images/poster/318017051/s166/project-k.webp" imagesrcset="https://www.justwatch.com/images/poster/318017051/s166/project-k.webp 1px, https://www.justwatch.com/images/poster/318017051/s166/project-k.webp" importance="high" rel="preload"/>
#   <link as="image" href="https://www.justwatch.com/images/poster/314734440/s166/hit-man.webp" imagesrcset="https://www.justwatch.com/images/poster/314734440/s166/hit-man.webp 1px, https://www.justwatch.com/images/poster/314734440/s166/hit-man.webp" importance="high" rel="preload"/>
#   <style data-vue-ssr-id="16dee5de:0 16dee5de:1 374c0f88:0 4d630dd0:0 166f4014:0 7c8ec326:0 2c4532b4:0 794ed965:0 f084ba36:0 389924d2:0 6dcc8ee6:0 244ddff4:0 b9b753ae:0 08ddf3ea:0 9ddc65f6:0 5e9f69f2:0 05c8a9ca:0 71268dee:0 6f4f883c:0 7d006f6e:0 6240279c:0 7bd50544:0 8fcf6830:0 25065816:0 37592880:0 d9ba2922:0 75bd5612:0 24a30aba:0 2810ebd5:0 2020975e:0 c5ab8c9a:0 44770f63:0 3cf28c3e:0 b5340c7a:0 0de9810f:0 7fbcc135:0 05def2d1:0">
#    html.ios{--ion-default-font:-apple-system,BlinkMacSystemFont,"Helvetica Neue","Roboto",sans-serif}html.md{--ion-default-font:"Roboto","Helvetica Neue",sans-serif}html{--ion-font-family:var(--ion-default-font)}body{background:var(--ion-background-color)}body.backdrop-no-scroll{overflow:hidden}html.ios ion-modal.modal-card .ion-page>ion-header>ion-toolbar:first-of-type{padding-top:0}html.ios ion-modal .ion-page{border-radius:inherit}.ion-color-primary{--ion-color-base:var(--ion-color-primary,#3880ff)!important;--ion-color-base-rgb:var(--ion-color-primary-rgb,56,128,255)!important;--ion-color-contrast:var(--ion-color-primary-contrast,#fff)!important;--ion-color-contrast-rgb:var(--ion-color-primary-contrast-rgb,255,255,255)!important;--ion-color-shade:var(--ion-color-primary-shade,#3171e0)!important;--ion-color-tint:var(--ion-color-primary-tint,#4c8dff)!important}.ion-color-secondary{--ion-color-base:var(--ion-color-secondary,#3dc2ff)!important;--ion-color-base-rgb:var(--ion-color-secondary-rgb,61,194,255)!important;--ion-color-contrast:var(--ion-color-secondary-contrast,#fff)!important;--ion-color-contrast-rgb:var(--ion-color-secondary-contrast-rgb,255,255,255)!important;--ion-color-shade:var(--ion-color-secondary-shade,#36abe0)!important;--ion-color-tint:var(--ion-color-secondary-tint,#50c8ff)!important}.ion-color-tertiary{--ion-color-base:var(--ion-color-tertiary,#5260ff)!important;--ion-color-base-rgb:var(--ion-color-tertiary-rgb,82,96,255)!important;--ion-color-contrast:var(--ion-color-tertiary-contrast,#fff)!important;--ion-color-contrast-rgb:var(--ion-color-tertiary-contrast-rgb,255,255,255)!important;--ion-color-shade:var(--ion-color-tertiary-shade,#4854e0)!important;--ion-color-tint:var(--ion-color-tertiary-tint,#6370ff)!important}.ion-color-success{--ion-color-base:var(--ion-color-success,#2dd36f)!important;--ion-color-base-rgb:var(--ion-color-success-rgb,45,211,111)!important;--ion-color-contrast:var(--ion-color-success-contrast,#fff)!important;--ion-color-contrast-rgb:var(--ion-color-success-contrast-rgb,255,255,255)!important;--ion-color-shade:var(--ion-color-success-shade,#28ba62)!important;--ion-color-tint:var(--ion-color-success-tint,#42d77d)!important}.ion-color-warning{--ion-color-base:var(--ion-color-warning,#ffc409)!important;--ion-color-base-rgb:var(--ion-color-warning-rgb,255,196,9)!important;--ion-color-contrast:var(--ion-color-warning-contrast,#000)!important;--ion-color-contrast-rgb:var(--ion-color-warning-contrast-rgb,0,0,0)!important;--ion-color-shade:var(--ion-color-warning-shade,#e0ac08)!important;--ion-color-tint:var(--ion-color-warning-tint,#ffca22)!important}.ion-color-danger{--ion-color-base:var(--ion-color-danger,#eb445a)!important;--ion-color-base-rgb:var(--ion-color-danger-rgb,235,68,90)!important;--ion-color-contrast:var(--ion-color-danger-contrast,#fff)!important;--ion-color-contrast-rgb:var(--ion-color-danger-contrast-rgb,255,255,255)!important;--ion-color-shade:var(--ion-color-danger-shade,#cf3c4f)!important;--ion-color-tint:var(--ion-color-danger-tint,#ed576b)!important}.ion-color-light{--ion-color-base:var(--ion-color-light,#f4f5f8)!important;--ion-color-base-rgb:var(--ion-color-light-rgb,244,245,248)!important;--ion-color-contrast:var(--ion-color-light-contrast,#000)!important;--ion-color-contrast-rgb:var(--ion-color-light-contrast-rgb,0,0,0)!important;--ion-color-shade:var(--ion-color-light-shade,#d7d8da)!important;--ion-color-tint:var(--ion-color-light-tint,#f5f6f9)!important}.ion-color-medium{--ion-color-base:var(--ion-color-medium,#92949c)!important;--ion-color-base-rgb:var(--ion-color-medium-rgb,146,148,156)!important;--ion-color-contrast:var(--ion-color-medium-contrast,#fff)!important;--ion-color-contrast-rgb:var(--ion-color-medium-contrast-rgb,255,255,255)!important;--ion-color-shade:var(--ion-color-medium-shade,#808289)!important;--ion-color-tint:var(--ion-color-medium-tint,#9d9fa6)!important}.ion-color-dark{--ion-color-base:var(--ion-color-dark,#222428)!important;--ion-color-b ...
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
#  */:root{--border-secondary:#657182;--border-secondary-medium:#c6c8cd;--border-primary:#fbc500;--border-radius-xs:4px;--border-radius-sm:8px;--border-radius-md:12px;--border-width-100:1px;--border-width-200:2px;--link-link-medium:#78a6b8;--text-high-default:#fff;--text-medium-default:#b9bdcc;--background-medium:#111924;--background-medium-active:#222c38}/*! Source: https://github.com/h5bp/html5-boilerplate/blob/master/src/css/main.css */@media print{*,:after,:before{color:#000!important;text-shadow:none!important;background:transparent!important;box-shadow:none!important}a,a:visited{text-decoration:underline}a[href]:after{content:" (" attr(href) ")"}abbr[title]:after{content:" (" attr(title) ")"}a[href^="#"]:after,a[href^="javascript:"]:after{content:""}blockquote,pre{border:1px solid #999;page-break-inside:avoid}thead{display:table-header-group}img,tr{page-break-inside:avoid}img{max-width:100%!important}h2,h3,p{orphans:3;widows:3}h2,h3{page-break-after:avoid}.navbar{display:none}.btn>.caret,.dropup>.btn>.caret{border-top-color:#000!important}.label{border:1px solid #000}.table{border-collapse:collapse!important}.table td,.table th{background-color:#fff!important}.table-bordered td,.table-bordered th{border:1px solid #ddd!important}}*,:after,:before{box-sizing:border-box}html{font-size:10px;-webkit-tap-highlight-color:rgba(0,0,0,0)}body{font-family:Lato,Lato-fallback,Arial,sans-serif;font-size:14px;line-height:1.428571429;color:#333;background-color:#fff}button,input,select,textarea{font-family:inherit;font-size:inherit;line-height:inherit}a{color:#428bca}a,a:focus,a:hover{text-decoration:none}a:focus,a:hover{color:#2a6496}a:focus{outline:5px auto -webkit-focus-ring-color;outline-offset:-2px}figure{margin:0}img{vertical-align:middle}.img-responsive{display:block;max-width:100%;height:auto}.img-rounded{border-radius:6px}.img-thumbnail{padding:4px;line-height:1.428571429;background-color:#fff;border:1px solid #ddd;border-radius:4px;transition:all .2s ease-in-out;display:inline-block;max-width:100%;height:auto}.img-circle{border-radius:50%}hr{margin-top:20px;margin-bottom:20px;border:0;border-top:1px solid #eee}.sr-only{position:absolute;width:1px;height:1px;padding:0;margin:-1px;overflow:hidden;clip:rect(0,0,0,0);border:0}.sr-only-focusable:active,.sr-only-focusable:focus{position:static;width:auto;height:auto;margin:0;overflow:visible;clip:auto}[role=button]{cursor:pointer}.container{padding-right:15px;padding-left:15px;margin-right:auto;margin-left:auto}.container:after,.container:before{display:table;content:" "}.container:after{clear:both}@media(min-width:768px){.container{width:750px}}@media(min-width:992px){.container{width:970px}}@media(min-width:1200px){.container{width:1170px}}.container-fluid{padding-right:15px;padding-left:15px;margin-right:auto;margin-left:auto}.container-fluid:after,.container-fluid:before{display:table;content:" "}.container-fluid:after{clear:both}.row{margin-right:-15px;margin-left:-15px}.row:after,.row:before{display:table;content:" "}.row:after{clear:both}.row-no-gutters{margin-right:0;margin-left:0}.row-no-gutters [class*=col-]{padding-right:0;padding-left:0}.col-lg-1,.col-lg-2,.col-lg-3,.col-lg-4,.col-lg-5,.col-lg-6,.col-lg-7,.col-lg-8,.col-lg-9,.col-lg-10,.col-lg-11,.col-lg-12,.col-md-1,.col-md-2,.col-md-3,.col-md-4,.col-md-5,.col-md-6,.col-md-7,.col-md-8,.col-md-9,.col-md-10,.col-md-11,.col-md-12,.col-sm-1,.col-sm-2,.col-sm-3,.col-sm-4,.col-sm-5,.col-sm-6,.col-sm-7,.col-sm-8,.col-sm-9,.col-sm-10,.col-sm-11,.col-sm-12,.col-xs-1,.col-xs-2,.col-xs-3,.col-xs-4,.col-xs-5,.col-xs-6,.col-xs-7,.col-xs-8,.col-xs-9,.col-xs-10,.col-xs-11,.col-xs-12{position:relative;min-height:1px;padding-right:15px;padding-left:15px}.col-xs-1,.col-xs-2,.col-xs-3,.col-xs-4,.col-xs-5,.col-xs-6,.col-xs-7,.col-xs-8,.col-xs-9,.col-xs-10,.col-xs-11,.col-xs-12{float:left}.col-xs-1{width:8.3333333333%}.col-xs-2{width:16.6666666667%}.col-xs-3{width:25%}.col-xs-4{width:33.3333333333%}.col-xs-5{width:41.6666666667%}.col-xs-6{wid ...
# :host,:root{--fa-font-solid:normal 900 1em/1 "Font Awesome 6 Solid";--fa-font-regular:normal 400 1em/1 "Font Awesome 6 Regular";--fa-font-light:normal 300 1em/1 "Font Awesome 6 Light";--fa-font-thin:normal 100 1em/1 "Font Awesome 6 Thin";--fa-font-duotone:normal 900 1em/1 "Font Awesome 6 Duotone";--fa-font-sharp-solid:normal 900 1em/1 "Font Awesome 6 Sharp";--fa-font-sharp-regular:normal 400 1em/1 "Font Awesome 6 Sharp";--fa-font-sharp-light:normal 300 1em/1 "Font Awesome 6 Sharp";--fa-font-brands:normal 400 1em/1 "Font Awesome 6 Brands"}svg:not(:host).svg-inline--fa,svg:not(:root).svg-inline--fa{overflow:visible;box-sizing:content-box}.svg-inline--fa{display:var(--fa-display,inline-block);height:1em;overflow:visible;vertical-align:-.125em}.svg-inline--fa.fa-2xs{vertical-align:.1em}.svg-inline--fa.fa-xs{vertical-align:0}.svg-inline--fa.fa-sm{vertical-align:-.07143em}.svg-inline--fa.fa-lg{vertical-align:-.2em}.svg-inline--fa.fa-xl{vertical-align:-.25em}.svg-inline--fa.fa-2xl{vertical-align:-.3125em}.svg-inline--fa.fa-pull-left{margin-right:var(--fa-pull-margin,.3em);width:auto}.svg-inline--fa.fa-pull-right{margin-left:var(--fa-pull-margin,.3em);width:auto}.svg-inline--fa.fa-li{width:var(--fa-li-width,2em);top:.25em}.svg-inline--fa.fa-fw{width:var(--fa-fw-width,1.25em)}.fa-layers svg.svg-inline--fa{bottom:0;left:0;margin:auto;position:absolute;right:0;top:0}.fa-layers-counter,.fa-layers-text{display:inline-block;position:absolute;text-align:center}.fa-layers{display:inline-block;height:1em;position:relative;text-align:center;vertical-align:-.125em;width:1em}.fa-layers svg.svg-inline--fa{transform-origin:center center}.fa-layers-text{left:50%;top:50%;transform:translate(-50%,-50%);transform-origin:center center}.fa-layers-counter{background-color:var(--fa-counter-background-color,#ff253a);border-radius:var(--fa-counter-border-radius,1em);box-sizing:border-box;color:var(--fa-inverse,#fff);line-height:var(--fa-counter-line-height,1);max-width:var(--fa-counter-max-width,5em);min-width:var(--fa-counter-min-width,1.5em);overflow:hidden;padding:var(--fa-counter-padding,.25em .5em);right:var(--fa-right,0);text-overflow:ellipsis;top:var(--fa-top,0);transform:scale(var(--fa-counter-scale,.25));transform-origin:top right}.fa-layers-bottom-right{bottom:var(--fa-bottom,0);right:var(--fa-right,0);top:auto;transform:scale(var(--fa-layers-scale,.25));transform-origin:bottom right}.fa-layers-bottom-left{bottom:var(--fa-bottom,0);left:var(--fa-left,0);right:auto;top:auto;transform:scale(var(--fa-layers-scale,.25));transform-origin:bottom left}.fa-layers-top-right{top:var(--fa-top,0);right:var(--fa-right,0);transform:scale(var(--fa-layers-scale,.25));transform-origin:top right}.fa-layers-top-left{left:var(--fa-left,0);right:auto;top:var(--fa-top,0);transform:scale(var(--fa-layers-scale,.25));transform-origin:top left}.fa-1x{font-size:1em}.fa-2x{font-size:2em}.fa-3x{font-size:3em}.fa-4x{font-size:4em}.fa-5x{font-size:5em}.fa-6x{font-size:6em}.fa-7x{font-size:7em}.fa-8x{font-size:8em}.fa-9x{font-size:9em}.fa-10x{font-size:10em}.fa-2xs{font-size:.625em;line-height:.1em;vertical-align:.225em}.fa-xs{font-size:.75em;line-height:.08333em;vertical-align:.125em}.fa-sm{font-size:.875em;line-height:.07143em;vertical-align:.05357em}.fa-lg{font-size:1.25em;line-height:.05em;vertical-align:-.075em}.fa-xl{font-size:1.5em;line-height:.04167em;vertical-align:-.125em}.fa-2xl{font-size:2em;line-height:.03125em;vertical-align:-.1875em}.fa-fw{text-align:center;width:1.25em}.fa-ul{list-style-type:none;margin-left:var(--fa-li-margin,2.5em);padding-left:0}.fa-ul>li{position:relative}.fa-li{left:calc(var(--fa-li-width, 2em)*-1);position:absolute;text-align:center;width:var(--fa-li-width,2em);line-height:inherit}.fa-border{border-radius:var(--fa-border-radius,.1em);border:var(--fa-border-width,.08em) var(--fa-border-style,solid) var(--fa-border-color,#eee);padding:var(--fa-border-padding,.2em .25em .15em)}.fa-pull-left{float:left;margin-right:var(--fa-pull-margin,.3em)}.fa ...
# .vue-recycle-scroller{position:relative}.vue-recycle-scroller.direction-vertical:not(.page-mode){overflow-y:auto}.vue-recycle-scroller.direction-horizontal:not(.page-mode){overflow-x:auto}.vue-recycle-scroller.direction-horizontal{display:-webkit-box;display:-ms-flexbox;display:flex}.vue-recycle-scroller__slot{-webkit-box-flex:1;-ms-flex:auto 0 0px;flex:auto 0 0}.vue-recycle-scroller__item-wrapper{-webkit-box-flex:1;-ms-flex:1;flex:1;-webkit-box-sizing:border-box;box-sizing:border-box;overflow:hidden;position:relative}.vue-recycle-scroller.ready .vue-recycle-scroller__item-view{position:absolute;top:0;left:0;will-change:transform}.vue-recycle-scroller.direction-vertical .vue-recycle-scroller__item-wrapper{width:100%}.vue-recycle-scroller.direction-horizontal .vue-recycle-scroller__item-wrapper{height:100%}.vue-recycle-scroller.ready.direction-vertical .vue-recycle-scroller__item-view{width:100%}.vue-recycle-scroller.ready.direction-horizontal .vue-recycle-scroller__item-view{height:100%}.resize-observer[data-v-b329ee4c]{border:none;background-color:transparent;opacity:0}.resize-observer[data-v-b329ee4c],.resize-observer[data-v-b329ee4c] object{position:absolute;top:0;left:0;z-index:-1;width:100%;height:100%;pointer-events:none;display:block;overflow:hidden}
# :root{--border-secondary:#657182;--border-secondary-medium:#c6c8cd;--border-primary:#fbc500;--border-radius-xs:4px;--border-radius-sm:8px;--border-radius-md:12px;--border-width-100:1px;--border-width-200:2px;--link-link-medium:#78a6b8;--text-high-default:#fff;--text-medium-default:#b9bdcc;--background-medium:#111924;--background-medium-active:#222c38}body{overflow-x:hidden}ion-menu ion-content ion-toolbar,ion-popover ion-toolbar{--background:transparent!important}#app{position:relative;z-index:0}
# :root{--border-secondary:#657182;--border-secondary-medium:#c6c8cd;--border-primary:#fbc500;--border-radius-xs:4px;--border-radius-sm:8px;--border-radius-md:12px;--border-width-100:1px;--border-width-200:2px;--link-link-medium:#78a6b8;--text-high-default:#fff;--text-medium-default:#b9bdcc;--background-medium:#111924;--background-medium-active:#222c38}.navbar__button__link__item{text-transform:capitalize}.search-overlay{position:fixed;display:block;width:100vw;height:100vh;top:0;left:0;right:0;bottom:0;background-color:rgba(0,0,0,.5);cursor:pointer}.navbar{position:sticky;display:flex;background:#060d17;height:56px;width:100%;top:0;margin:0 auto;z-index:100}@media(max-width:1050px){.navbar{max-height:105px}}.navbar__wrapper{display:flex;justify-content:flex-end;width:100%;align-items:center;overflow:visible}@media(max-width:1050px){.navbar__wrapper{justify-content:center}}.navbar.navbar-hide{display:none!important}.navbar.bg-dark-brown{background:#141100}.navbar.landing-page{background:transparent}@media(min-width:1050px){.navbar.landing-page{height:86px;padding-top:15px;margin-bottom:-86px}.navbar.landing-page .navbar__logo img{width:219px}}@media(max-width:1050px){.navbar.landing-page{margin-bottom:0}}.navbar--hidden,.navbar.landing-page .landing-hide{display:none}.navbar--absolute{position:absolute}@media(max-width:1050px){.navbar{height:105px;align-items:flex-end}}@media(max-width:1050px){.navbar.navbar__button--watchlist a{color:var(--ion-color-primary)!important}}.navbar__logo{padding-inline-end:15px;display:flex;align-items:center;flex-shrink:0}.navbar__logo img{width:131px}@media(max-width:1050px){.navbar__logo{position:absolute;top:0;width:100%;min-height:46px;display:flex;justify-content:center;align-items:center;margin:0;padding-inline-end:0}}.navbar--is-mobile .navbar__logo{justify-content:left}.navbar--is-ios .navbar__logo{height:56px}.navbar__logo-link{display:flex;align-items:center}.navbar__logo .valentine-link{font-size:24px;margin-top:2px;margin-inline-start:8px}.navbar.container .navbar__logo{margin-inline-start:0;padding-inline-start:0}.navbar__search{z-index:1;flex-grow:2;height:52px;margin:0;margin-inline-end:7px;display:flex}.navbar__search .search-suggester .searchbar-input{color:#fff;box-shadow:none;border-radius:4px;font-size:15px;padding:4px 0;padding-inline-start:50px;padding-inline-end:15px}@media(max-width:992px){.navbar__search--expanded{left:0;right:0;position:absolute}}.navbar.landing-page .navbar__search{flex-grow:0;width:35em;transition:width .6s;transition-delay:.1s;align-items:center;display:flex}.navbar.landing-page .navbar__search:focus-within{width:100%}@media(max-width:1050px){.navbar.landing-page .navbar__search:focus-within{display:flex;align-items:center;justify-content:space-around}}.navbar__extra{display:flex;min-width:92px}@media(max-width:1050px){.navbar__extra{display:none}}.navbar__extra__small{display:none}@media(max-width:1050px){.navbar__extra__small{display:block;position:absolute;top:0;width:100%}[dir=ltr] .navbar__extra__small{right:0}[dir=rtl] .navbar__extra__small{left:0}.navbar__extra__small--left{display:flex;position:absolute}[dir=ltr] .navbar__extra__small--left{left:4px}[dir=rtl] .navbar__extra__small--left{right:4px}.navbar__extra__small--right{display:flex;position:absolute}[dir=ltr] .navbar__extra__small--right{right:0}[dir=rtl] .navbar__extra__small--right{left:0}}.navbar__extra--remove-spacing{min-width:unset}.navbar__button{height:56px;flex-grow:inherit;cursor:pointer}.navbar__button a{padding:0}.navbar__button>div,.navbar__button__link{justify-content:center}.navbar__button__link{display:flex;align-items:center;height:100%;white-space:nowrap;font-size:14px;color:#999c9f}.navbar__button__link.nav-link-active,.navbar__button__link.router-link-exact-active{font-weight:700;color:#d9e8ed!important}.navbar__button__link__item{margin:0 15px;display:flex;margin-inline-end:15px}@media(max-width:1050px){.navbar__button--home .navbar__button__link__item,.navbar__button- ...
# :root{--border-secondary:#657182;--border-secondary-medium:#c6c8cd;--border-primary:#fbc500;--border-radius-xs:4px;--border-radius-sm:8px;--border-radius-md:12px;--border-width-100:1px;--border-width-200:2px;--link-link-medium:#78a6b8;--text-high-default:#fff;--text-medium-default:#b9bdcc;--background-medium:#111924;--background-medium-active:#222c38}.freemium-filter__badge{display:inline-flex;align-items:center;font-size:14px;line-height:22px;letter-spacing:.2px;font-weight:700;text-align:center;color:#fff;background:linear-gradient(-225deg,#5c6374,#3b404e 31%,#272939 68%,#191d2a);padding:2px 7px;border-radius:4px;margin-inline-start:8px}.freemium-filter__badge--sm{padding:2px 6px;font-size:12px;line-height:16px}.freemium-filter__badge svg{margin-inline-end:8px}
# :root{--border-secondary:#657182;--border-secondary-medium:#c6c8cd;--border-primary:#fbc500;--border-radius-xs:4px;--border-radius-sm:8px;--border-radius-md:12px;--border-width-100:1px;--border-width-200:2px;--link-link-medium:#78a6b8;--text-high-default:#fff;--text-medium-default:#b9bdcc;--background-medium:#111924;--background-medium-active:#222c38}.search-suggester__results{overflow:auto;border-bottom-left-radius:8px;border-bottom-right-radius:8px;max-height:90vh;max-width:100vw}.search-suggester{position:relative}.search-suggester .sponsored-recommendation-search{margin-top:-10px;z-index:1000;position:relative;display:flex;width:100%}.search-suggester input[type=search]::-webkit-search-cancel-button{display:none}.search-suggester__results{z-index:200;padding:0 8px 8px;margin:-9px 0 0}.search-suggester__results--mobile{padding:0;margin:-11px -1em -.4em}.search-suggester--web{text-align:start;width:100%;padding:0;height:52px;z-index:10}.search-suggester--web ion-searchbar.ios{--background:#10161d;padding:8px;height:52px}.search-suggester--web .searchbar-cancel-button.sc-ion-searchbar-ios{background:#10161d;padding-inline-end:8px}.search-suggester__searchbar--mobile{padding-top:3px!important;padding-bottom:10px!important}.search-suggester__searchbar--mobile.md{height:52px;--background:#fff;--color:var(--ion-color-tertiary-shade)!important}.search-suggester__searchbar--mobile.md .searchbar-input{border-radius:4px!important}.search-suggester__searchbar input::-webkit-search-cancel-button{-webkit-appearance:none}.search-suggester__searchbar .searchbar-clear-icon{color:var(--ion-color-secondary)!important}.search-suggester__blocking{position:absolute;width:100%;padding:8px}.search-suggester__blocking__input{width:100%;height:38px;display:flex;align-items:center;background-color:var(--ion-color-tertiary-shade)}.searchbar-clear-button.sc-ion-searchbar-md{color:#fff!important}
# [data-v-6aa447f4]:root{--border-secondary:#657182;--border-secondary-medium:#c6c8cd;--border-primary:#fbc500;--border-radius-xs:4px;--border-radius-sm:8px;--border-radius-md:12px;--border-width-100:1px;--border-width-200:2px;--link-link-medium:#78a6b8;--text-high-default:#fff;--text-medium-default:#b9bdcc;--background-medium:#111924;--background-medium-active:#222c38}.logged-in[data-v-6aa447f4]{padding:0 15px;color:var(--ion-color-primary);font-size:18px}.logged-in[data-v-6aa447f4],.not-logged-in[data-v-6aa447f4]{height:100%;display:flex;align-items:center}@media(max-width:1050px){.not-logged-in__button[data-v-6aa447f4]{display:none}}.not-logged-in__icon[data-v-6aa447f4]{display:none;font-size:16px;cursor:pointer}@media(max-width:1050px){.not-logged-in__icon[data-v-6aa447f4]{display:block}}@media(max-width:1050px){.not-logged-in[data-v-6aa447f4]{padding:0 15px}}
# :root{--border-secondary:#657182;--border-secondary-medium:#c6c8cd;--border-primary:#fbc500;--border-radius-xs:4px;--border-radius-sm:8px;--border-radius-md:12px;--border-width-100:1px;--border-width-200:2px;--link-link-medium:#78a6b8;--text-high-default:#fff;--text-medium-default:#b9bdcc;--background-medium:#111924;--background-medium-active:#222c38}.basic-button{background:none;border:none;margin:0;padding:0;outline:none;white-space:nowrap;cursor:pointer}.basic-button__content{overflow:hidden;text-overflow:ellipsis;display:flex;align-items:center;justify-content:center}.basic-button.sm{font-size:13px;padding:.4rem 1.35rem}.basic-button.md{padding:.75rem 1.5rem}.basic-button.lg{font-size:18px;padding:1.6rem 4rem}.basic-button.lg.rounded{border-radius:8px}.basic-button.w-full{width:100%}.basic-button.rounded{border-radius:4px}.basic-button.uppercase{text-transform:uppercase}.basic-button.primary{font-weight:700;background-color:#fbc500;color:#000}.basic-button.primary.bg-none{color:#fbc500}.basic-button.primary.bg-none:hover{background-color:rgba(251,197,0,.1)}.basic-button.primary.border{color:#fbcb1a;border:1px solid #fbcb1a}.basic-button.primary.border:hover{background-color:rgba(251,197,0,.1)}.basic-button.primary:hover{background-color:#ddad00}.basic-button.secondary{color:#fff;font-weight:700;background-color:#4c5a67}.basic-button.secondary.bg-none{color:#4c5a67}.basic-button.secondary.bg-none:hover{background-color:rgba(94,107,118,.1)}.basic-button.secondary.border{border:1px solid #5e6b76}.basic-button.secondary.border:hover{background-color:rgba(94,107,118,.1)}.basic-button.secondary:hover{background-color:#ddad00}.basic-button.tertiary{color:#fff;background-color:#1c252f}.basic-button.tertiary.bg-none{color:#1c252f}.basic-button.tertiary.bg-none:hover{background-color:rgba(94,107,118,.1)}.basic-button.tertiary.border{border:1px solid #383d47}.basic-button.tertiary.border:hover{background-color:rgba(56,61,71,.1)}.basic-button.tertiary:hover{background-color:#383d47}.basic-button.light{color:#d9e8ed;background-color:#1c252f}.basic-button.light:hover{background-color:#383d47}.basic-button.medium{color:#fff;background-color:#8c8c8c}.basic-button.medium.border{color:#999c9f;border:1px solid #999c9f}.basic-button.medium.border:hover{background-color:rgba(153,156,159,.1)}.basic-button.medium:hover{background-color:#999c9f}.basic-button.bg-none{background:transparent}.basic-button.disabled{cursor:default;opacity:.5;pointer-events:none}
# .navbar__button__link[data-v-701c8f36]{background:none;border:none;outline:none;cursor:pointer}
# .login-menu-button__button[data-v-4dfb297b]{all:unset;display:flex;align-items:center;height:100%;padding:0 15px;font-size:16px}.login-menu-button__button--logged-in[data-v-4dfb297b]{color:var(--ion-color-primary)}
# [data-v-64e4e508]:root{--border-secondary:#657182;--border-secondary-medium:#c6c8cd;--border-primary:#fbc500;--border-radius-xs:4px;--border-radius-sm:8px;--border-radius-md:12px;--border-width-100:1px;--border-width-200:2px;--link-link-medium:#78a6b8;--text-high-default:#fff;--text-medium-default:#b9bdcc;--background-medium:#111924;--background-medium-active:#222c38}html[data-v-64e4e508]{scroll-padding-top:56px}@media screen and (max-width:1050px){html[data-v-64e4e508]{scroll-padding-top:105px}}.popular-page__spinner[data-v-64e4e508]{width:100%;height:100vh;display:flex;align-items:center;justify-content:center}.overlay-blocking-element[data-v-64e4e508]{position:absolute;height:100vh;width:100vw}.content-provider-content[data-v-64e4e508]{position:relative;width:100vw}.content-provider-content h1.section-title[data-v-64e4e508]{font-size:32px}@media(max-width:599px){.content-provider-content .content-header[data-v-64e4e508]{max-height:178px}.content-provider-content .content-header.content-header--expanded[data-v-64e4e508]{max-height:none}}.content-provider-content.font-style-2 .section-title[data-v-64e4e508]{font-family:Anton,Impact;letter-spacing:.64px!important;font-weight:400!important}.catalog-title[data-v-64e4e508]{display:flex;align-items:center;justify-content:flex-start;width:100%}@media(max-width:1050px){.catalog-title h2[data-v-64e4e508]{margin-inline-start:15px}}.show-filters[data-v-64e4e508]{margin:0 15px}@media(max-width:599px){.show-filters__text[data-v-64e4e508]{display:none}}.sponsored-recommendation[data-v-64e4e508]{grid-area:double-poster;height:100%}@media(max-width:540px){.sponsored-recommendation[data-v-64e4e508]{height:270px}}.list-options[data-v-64e4e508]{width:100%;display:flex;flex-direction:column;align-items:flex-start;justify-content:center;margin-bottom:16px}.filter-bar[data-v-64e4e508]{margin-top:24px}#catalog-jumplink[data-v-64e4e508]{position:relative;top:-50px}@media(max-width:1050px){#catalog-jumplink[data-v-64e4e508]{top:-90px}}
# [data-v-d7672432]:root{--border-secondary:#657182;--border-secondary-medium:#c6c8cd;--border-primary:#fbc500;--border-radius-xs:4px;--border-radius-sm:8px;--border-radius-md:12px;--border-width-100:1px;--border-width-200:2px;--link-link-medium:#78a6b8;--text-high-default:#fff;--text-medium-default:#b9bdcc;--background-medium:#111924;--background-medium-active:#222c38}.content[data-v-d7672432]{min-height:100vh;display:flex;flex-direction:column;--padding-top:56px}@media(max-width:1050px){.content[data-v-d7672432]{--padding-top:105px}}
# :root{--border-secondary:#657182;--border-secondary-medium:#c6c8cd;--border-primary:#fbc500;--border-radius-xs:4px;--border-radius-sm:8px;--border-radius-md:12px;--border-width-100:1px;--border-width-200:2px;--link-link-medium:#78a6b8;--text-high-default:#fff;--text-medium-default:#b9bdcc;--background-medium:#111924;--background-medium-active:#222c38}.toggle-filters{display:flex;align-items:center;margin:10px}.toggle-filters__label{margin-inline-end:5px}.toggle-filters.border.bg-none{color:#d5d5d5}.content-container{display:flex;align-items:center;position:relative}.center-banner{display:flex;justify-content:center}.display-none{display:none}.content-header{min-height:120px;max-height:120px;overflow:hidden;position:relative;width:100%}@media(max-width:1050px){.content-header{padding-left:15px;padding-right:15px}}.content-header:hover{cursor:pointer}.content-header--expanded{max-height:none}.content-header--no-text{min-height:70px}.content-header--gradient{position:absolute;bottom:0;width:100%;text-align:center;margin:0;padding:15px 0;background-image:linear-gradient(180deg,rgba(6,13,23,0),var(--ion-background-color))}[dir=ltr] .content-header--gradient{left:0}[dir=rtl] .content-header--gradient{right:0}.content-header h1{padding-inline-end:15px}.content-header__search-heading{flex-grow:1;display:flex;align-items:center}@media(max-width:1050px){.content-header__search-heading{padding-left:15px;padding-right:15px}}.content-header__search-heading h1{font-size:24px;line-height:32px;font-weight:700;color:#d9e8ed}@media(max-width:767px){.content-header__search-heading h1{font-size:16px;line-height:24px}}.content-header__search-heading div{font-size:15px;padding:10px 0 5px}.content-header__caret{position:absolute;top:18px}[dir=ltr] .content-header__caret{right:0}[dir=rtl] .content-header__caret{left:0}@media(max-width:1050px){[dir=ltr] .content-header__caret{right:20px}[dir=rtl] .content-header__caret{left:20px}}
# :root{--border-secondary:#657182;--border-secondary-medium:#c6c8cd;--border-primary:#fbc500;--border-radius-xs:4px;--border-radius-sm:8px;--border-radius-md:12px;--border-width-100:1px;--border-width-200:2px;--link-link-medium:#78a6b8;--text-high-default:#fff;--text-medium-default:#b9bdcc;--background-medium:#111924;--background-medium-active:#222c38}.popover__filter{--ion-background-color:#10161d}.popover__filter .popover-content{width:400px}.filter-bar-seo{background-color:rgba(6,13,23,.8);background:linear-gradient(180deg,#060d17,rgba(6,13,23,.85));-webkit-backdrop-filter:blur(20px);backdrop-filter:blur(20px);position:relative;width:100%;z-index:10;transition:transform .3s ease-out}@media(max-width:1050px){.filter-bar-seo .row-filter-bar{margin:0 15px}}.filter-bar-seo__reset{margin-inline-start:auto}.filter-bar-seo__popover{transform:translateY(50px)}@media(min-width:992px){.filter-bar-seo__filter-button{display:none!important}}@media(max-width:992px){.filter-bar-seo__filter-button{display:block}}.filter-bar-seo__additional{position:relative;padding-bottom:10px;display:flex;align-items:baseline;justify-content:flex-start}.filter-bar-seo__additional>div:not(:last-child){margin-inline-end:10px}.filter-bar-seo__additional__heading{white-space:nowrap;color:var(--ion-color-secondary);text-transform:uppercase;font-weight:700}.filter-bar-seo__additional .jw-chip-button{margin-bottom:0}.filter-bar-seo__additional .hidden-horizontal-scrollbar__items{margin:0!important;bottom:0!important}.filter-bar-seo__additional--long:not(:last-child){margin-inline-end:4px}@media(max-width:992px){.filter-bar-seo__additional--long{display:none!important}.filter-bar-seo__additional--long.always-active{display:block!important}}.filter-bar-seo a{transition:opacity .2s ease;cursor:pointer}.filter-bar-seo--inactive a{opacity:.4}.filter-bar-seo--hidden{transform:translateY(-180px)}.scrollbar div{padding-left:0!important}
# :root{--border-secondary:#657182;--border-secondary-medium:#c6c8cd;--border-primary:#fbc500;--border-radius-xs:4px;--border-radius-sm:8px;--border-radius-md:12px;--border-width-100:1px;--border-width-200:2px;--link-link-medium:#78a6b8;--text-high-default:#fff;--text-medium-default:#b9bdcc;--background-medium:#111924;--background-medium-active:#222c38}.filter-bar-container{display:flex;align-items:center}.filter-bar-seo__provider-row{margin-bottom:5px}@media(max-width:767px){.filter-bar-seo__provider-row{margin-left:0!important}.filter-bar-seo__provider-row .hidden-horizontal-scrollbar__items{padding-left:0!important}}.filter-bar-seo__provider-icon{display:inline-block;width:50px;height:50px;opacity:.25;margin:10px 5px;transition:opacity .2s ease-in-out;cursor:pointer}.filter-bar-seo__provider-icon button{all:unset}.filter-bar-seo__provider-icon img{width:100%}.filter-bar-seo__provider-icon:first-child{margin-inline-start:0}.filter-bar-seo__provider-icon.active{opacity:1}.filter-bar-seo__provider-icon.disabled{opacity:.25;filter:grayscale(100%);pointer-events:none}
# :root{--border-secondary:#657182;--border-secondary-medium:#c6c8cd;--border-primary:#fbc500;--border-radius-xs:4px;--border-radius-sm:8px;--border-radius-md:12px;--border-width-100:1px;--border-width-200:2px;--link-link-medium:#78a6b8;--text-high-default:#fff;--text-medium-default:#b9bdcc;--background-medium:#111924;--background-medium-active:#222c38}.provider-icon,.provider-icon img{border-radius:20%}.provider-icon--labelled{overflow:hidden;height:100%;display:flex;justify-content:center;align-items:center;font-size:1.2rem}.provider-icon--labelled.timeline__provider-block__logo{font-size:.7rem}.provider-icon .ribbon{position:absolute;top:6px;right:-10px;width:100%;text-align:center;background-color:#d5d5d5;color:#1c252f;font-size:9px;font-weight:700;padding:0 4px;border-radius:0 0 0 5px;z-index:1;transform:rotate(45deg)}
# ...
#          <li class="jw-app-footer__link" data-v-7c31ac2a="">
#           <a data-v-7c31ac2a="" href="/in/tv-show/sausage-party-foodtopia/season-1">
#            Sausage Party: Foodtopia Season 1
#           </a>
#          </li>
#          <li class="jw-app-footer__link" data-v-7c31ac2a="">
#           <a data-v-7c31ac2a="" href="/in/tv-show/vikings-valhalla/season-3">
#            Vikings: Valhalla Season 3
#           </a>
#          </li>
#          <li class="jw-app-footer__link" data-v-7c31ac2a="">
#           <a data-v-7c31ac2a="" href="/in/tv-show/me/season-1">
#            Me Season 1
#           </a>
#          </li>
#         </ul>
#        </div>
#        <div data-v-7c31ac2a="">
#         <h5 data-v-7c31ac2a="">
#          <a data-v-7c31ac2a="" href="/in/guide">
#           Top 5 latest news
#          </a>
#         </h5>
#         <ul class="list-unstyled top-articles" data-v-7c31ac2a="">
#          <li class="jw-app-footer__link" data-v-7c31ac2a="">
#           <a data-v-7c31ac2a="" href="/in/guide/movies-like-james-bond">
#            10 Best Movies to Watch If You Love James Bond (and Where to Stream Them)
#           </a>
#          </li>
#          <li class="jw-app-footer__link" data-v-7c31ac2a="">
#           <a data-v-7c31ac2a="" href="/in/guide/the-boys-in-order">
#            How to Watch The Boys in Order - A Complete Streaming Guide
#           </a>
#          </li>
#          <li class="jw-app-footer__link" data-v-7c31ac2a="">
#           <a data-v-7c31ac2a="" href="/in/guide/shows-like-stranger-things">
#            10 Best Shows to Watch If You Like Stranger Things and Where to Stream Them
#           </a>
#          </li>
#          <li class="jw-app-footer__link" data-v-7c31ac2a="">
#           <a data-v-7c31ac2a="" href="/in/guide/shows-like-bridgerton">
#            10 Shows to Watch If You Loved Bridgerton and Where to Stream Them
#           </a>
#          </li>
#          <li class="jw-app-footer__link" data-v-7c31ac2a="">
#           <a data-v-7c31ac2a="" href="/in/guide/game-of-thrones-in-order">
#            How to Watch Game of Thrones In Order: A Complete Streaming Guide
#           </a>
#          </li>
#         </ul>
#        </div>
#       </div>
#      </footer>
#      <!-- -->
#     </div>
#    </div>
#    <style>
#     null
#    </style>
#    <div>
#     <!-- -->
#     <!-- -->
#     <!-- -->
#     <!-- -->
#     <!-- -->
#     <!-- -->
#    </div>
#   </div>
#   <script data-vue-ssr-data="">
#    window.__DATA__={"state":{"app":{"geoLocation":"us","seoUser":true,"jwSession":null,"jwSessionExpires":null},"constant":{"providers":[{"clearName":"Netflix","hasSport":false,"hasTitles":true,"icon":"\u002Ficon\u002F207360008\u002F{profile}\u002Fnetflix.{format}","monetizationTypes":["FLATRATE"],"packageId":8,"selected":false,"shortName":"nfx","slug":"netflix","technicalName":"netflix"},{"clearName":"Amazon Prime Video","hasSport":true,"hasTitles":true,"icon":"\u002Ficon\u002F52449861\u002F{profile}\u002Famazonprimevideo.{format}","monetizationTypes":["FLATRATE"],"packageId":119,"selected":false,"shortName":"prv","slug":"amazon-prime-video","technicalName":"amazonprimevideo"},{"clearName":"Apple TV Plus","hasSport":true,"hasTitles":true,"icon":"\u002Ficon\u002F152862153\u002F{profile}\u002Fappletvplus.{format}","monetizationTypes":["FLATRATE"],"packageId":350,"selected":false,"shortName":"atp","slug":"apple-tv-plus","technicalName":"appletvplus"},{"clearName":"Apple TV","hasSport":true,"hasTitles":true,"icon":"\u002Ficon\u002F190848813\u002F{profile}\u002Fitunes.{format}","monetizationTypes":["BUY","RENT"],"packageId":2,"selected":false,"shortName":"itu","slug":"apple-tv","technicalName":"itunes"},{"clearName":"Crunchyroll","hasSport":false,"hasTitles":true,"icon":"\u002Ficon\u002F127445869\u002F{profile}\u002Fcrunchyroll.{format}","monetizationTypes":["ADS","FLATRATE"],"packageId":283,"selected":false,"shortName":"cru","slug":"crunchyroll","technicalName":"crunchyroll"},{"clearName":"Hotstar","hasSport":true,"hasTitles":true,"icon":"\u002Ficon\u002F240029443\u002F{profile}\u002Fhotstar.{format}","monetizationTypes":["FLATRATE"],"packageId":122,"selected":false,"shortName":"hst","slug":"hotstar","technicalName":"hotstar"},{"clearName":"Jio Cinema","hasSport":true,"hasTitles":true,"icon":"\u002Ficon\u002F312325227\u002F{profile}\u002Fjiocinema.{format}","monetizationTypes":["FLATRATE"],"packageId":220,"selected":false,"shortName":"jio","slug":"jio-cinema","technicalName":"jiocinema"},{"clearName":"Zee5","hasSport":false,"hasTitles":true,"icon":"\u002Ficon\u002F93795879\u002F{profile}\u002Fzee5.{format}","monetizationTypes":["ADS","FLATRATE","FREE"],"packageId":232,"selected":false,"shortName":"zee","slug":"zee5","technicalName":"zee5"},{"clearName":"Eros Now","hasSport":false,"hasTitles":true,"icon":"\u002Ficon\u002F247912837\u002F{profile}\u002Ferosnow.{format}","monetizationTypes":["FLATRATE"],"packageId":218,"selected":false,"shortName":"ern","slug":"eros-now","technicalName":"erosnow"},{"clearName":"MLS Season Pass","hasSport":true,"hasTitles":false,"icon":"\u002Ficon\u002F303372959\u002F{profile}\u002Fmlsseasonpass.{format}","monetizationTypes":["FLATRATE"],"packageId":1851,"selected":false,"shortName":"mls","slug":"mls-season-pass","technicalName":"mlsseasonpass"},{"clearName":"Google Play Movies","hasSport":false,"hasTitles":true,"icon":"\u002Ficon\u002F169478387\u002F{profile}\u002Fplay.{format}","monetizationTypes":["BUY","RENT"],"packageId":3,"selected":false,"shortName":"ply","slug":"google-play-movies","technicalName":"play"},{"clearName":"MUBI","hasSport":false,"hasTitles":true,"icon":"\u002Ficon\u002F164970114\u002F{profile}\u002Fmubi.{format}","monetizationTypes":["FLATRATE","RENT"],"packageId":11,"selected":false,"shortName":"mbi","slug":"mubi","technicalName":"mubi"},{"clearName":"Sony Liv","hasSport":true,"hasTitles":true,"icon":"\u002Ficon\u002F207468084\u002F{profile}\u002Fsonyliv.{format}","monetizationTypes":["ADS","FLATRATE"],"packageId":237,"selected":false,"shortName":"snl","slug":"sony-liv","technicalName":"sonyliv"},{"clearName":"YouTube","hasSport":true,"hasTitles":true,"icon":"\u002Ficon\u002F59562423\u002F{profile}\u002Fyoutube.{format}","monetizationTypes":["BUY","FLATRATE","RENT"],"packageId":192,"selected":false,"shortName":"yot","slug":"youtube","technicalName":"youtube"},{"clearName":"GuideDoc","hasSport":false,"hasTitles":true,"icon":"\u002Ficon\u002F2625277\u002F{profile}\u002Fguidedoc.{fo ...
#   </script>
#   <script>
#    window.__APOLLO_STATE__={"defaultClient":{"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).0":{"organization":"CBFC","__typename":"AgeCertification"},"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).1":{"organization":"CBFC","__typename":"AgeCertification"},"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).2":{"organization":"CBFC","__typename":"AgeCertification"},"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).3":{"organization":"CBFC","__typename":"AgeCertification"},"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).4":{"organization":"CBFC","__typename":"AgeCertification"},"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).5":{"organization":"CBFC","__typename":"AgeCertification"},"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).6":{"organization":"CBFC","__typename":"AgeCertification"},"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).7":{"organization":"CBFC","__typename":"AgeCertification"},"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).8":{"organization":"CBFC","__typename":"AgeCertification"},"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).9":{"organization":"CBFC","__typename":"AgeCertification"},"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).10":{"organization":"CBFC","__typename":"AgeCertification"},"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).11":{"organization":"CBFC","__typename":"AgeCertification"},"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).12":{"organization":"CBFC","__typename":"AgeCertification"},"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).13":{"organization":"CBFC","__typename":"AgeCertification"},"ROOT_QUERY":{"ageCertifications({\"country\":\"IN\"})":[{"type":"id","generated":true,"id":"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).0","typename":"AgeCertification"},{"type":"id","generated":true,"id":"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).1","typename":"AgeCertification"},{"type":"id","generated":true,"id":"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).2","typename":"AgeCertification"},{"type":"id","generated":true,"id":"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).3","typename":"AgeCertification"},{"type":"id","generated":true,"id":"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).4","typename":"AgeCertification"},{"type":"id","generated":true,"id":"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).5","typename":"AgeCertification"},{"type":"id","generated":true,"id":"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).6","typename":"AgeCertification"},{"type":"id","generated":true,"id":"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).7","typename":"AgeCertification"},{"type":"id","generated":true,"id":"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).8","typename":"AgeCertification"},{"type":"id","generated":true,"id":"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).9","typename":"AgeCertification"},{"type":"id","generated":true,"id":"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).10","typename":"AgeCertification"},{"type":"id","generated":true,"id":"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).11","typename":"AgeCertification"},{"type":"id","generated":true,"id":"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).12","typename":"AgeCertification"},{"type":"id","generated":true,"id":"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).13","typename":"AgeCertification"}],"ageCertifications({\"country\":\"IN\",\"objectType\":\"MOVIE\"})":[{"type":"id","generated":false,"id":"AgeCertification:27","typename":"AgeCertification"},{"type":"id","generated":false,"id":"AgeCertification:28","typename":"AgeCertification"},{"type":"id","generated":false,"id":"AgeCertification:29","typename":"AgeCertification"},{"type":"id","generated":false,"id":"AgeCertification:21388","typename":"AgeCertification"},{"type":"id","generated":false,"id":"AgeCertification:21405","typename":"AgeCertification"},{"type":"id","generated":false,"id":"AgeCertification:21427","typename":"AgeCertification"},{"type":"id","generated":false ...
#   </script>
#   <script>
#    // Runtime Env Vars
# 			window.DNS_PREFETCH=[{"rel":"dns-prefetch","href":"https://www.googletagmanager.com/"},{"rel":"dns-prefetch","href":"https://ib.adnxs.com"}];
# 			window.HTTP_PRECONNECT=[{"rel":"preconnect","crossorigin":"use-credentials","href":"https://images.justwatch.com"}];
# 			window.BUILD_CONFIG={"appVersion":"3.8.2","commitHash":"8685668d6a54ffbeb5c7cfa5957a6e2d2b8eb641","commitShortHash":"8685668","env":"prod","globals":{"ASSETS_DIR":"appassets","BUILD_TARGET":"SSR","IS_BUILD":true,"IS_SERVE":false,"IS_START":false,"IS_DEV":true,"IS_PROD":false}};
# 			window.JW_CONFIG={"API":"https://apis.justwatch.com/content","ASSETS_URL":"https://www.justwatch.com/static/compile_jw/assets","BRAZE_BASE_URL":"sdk.iad-05.braze.com","BRAZE_WEB_API_KEY":"1aad19f0-6f9f-4fd5-9a05-9ca5499795f9","CHECKIP_URL":"https://info.justwatch.com ","CLICK_URL":"https://click.justwatch.com","DISCOVERY_URL":"https://apis.justwatch.com/discovery","DOMAIN":"justwatch.com","EVENT_URL":"https://apis.justwatch.com/event","EXPERIMENT_CONFIG_URL":"https://apis.justwatch.com/configuration/experiments","FACEBOOK_APP_ID":"794243977319785","FEEDBACK_URL":"https://apis.justwatch.com/feedback","FIREBASE_API_KEY":"AIzaSyDv6JIzdDvbTBS-JWdR4Kl22UvgWGAyuo8","FIREBASE_APP_ID":"1:413470318987:web:28b910bbf217d7d5034f8e","FIREBASE_AUTH_DOMAIN":"accounts.justwatch.com","FIREBASE_MESSAGING_SENDER_ID":"413470318987","FIREBASE_PROJECT_ID":"justwatch-apps-beta","FIREBASE_STORAGE_BUCKET":"justwatch-apps-beta.appspot.com","GEOLOCATION_URL":"https://geo.justwatch.com","GOOGLE_CLIENT_ID":"532718895899-fhbuhnd9nsrae0ivadejq35vsr2sgr0l.apps.googleusercontent.com","GOOGLE_MAPS_API_KEY":"AIzaSyBVU86Zuf3v_6W8dnnV9BRKe_YSBXroqCA","GRAPHQL_URL":"https://apis.justwatch.com/graphql","GRAPHQL_INTERNAL_URL":"https://apis.justwatch.com/graphql","IDENTITY_URL":"https://apis.justwatch.com/identity","ID_URL":"https://i.tw.cx","IMAGESCALER_FAST_URL":"https://www.justwatch.com/images","IMAGESCALER_URL":"https://images.justwatch.com","JOBSITE_URL":"https://www.justwatch.com/talent/jobs","ITUNES_APP_ID":"979227482","NOTIFICATION_URL":"https://apis.justwatch.com/notification","PLOT_RECOMMENDER_URL":"https://apis.justwatch.com/plotpoint","REVENUE_CAT_API_URL":"https://api.revenuecat.com/v1","REVENUE_CAT_PUBLIC_KEY":"sijZLciaBRrTwuIAeBkAqzQNtMNQaXqV","SENTRY_DSN":"https://ad6b9c4b3a3f4e998e38c3c7ed92574f@sentry.justwatch.com/4","SENTRY_DSN_SSR_CLIENT":"https://e83b625f73464fe9af5aea210630233c@sentry.justwatch.com/9","SNOWPLOW_COLLECTOR_ENDPOINT":"sp.justwatch.com","USER_URL":"https://userapi.justwatch.com","WRITE_URL":"https://apis.justwatch.com/personalization","AD_TAG":"https://pubads.g.doubleclick.net/gampad/ads?iu=/21679119891/video_ads_trailers&description_url=https%3A%2F%2Fwww.justwatch.com%2F&tfcd=0&npa=0&sz=640x360%7C640x480&gdfp_req=1&output=vast&unviewed_position_start=1&env=vp&impl=s&correlator=&vad_type=linear","ZENDESK_SUBDOMAIN":"https://justwatch.zendesk.com","SUBSCRIPTIONS":{"regular":{"id":"prod_LKEY8MLBOZwwQN","priceId":"price_1Kda5MKD0TTmBHo0KnyileCK","type":"regular","timeframe":"monthly","price":2.49},"yearly":{"id":"prod_NzlZqI8lGP1soA","priceId":"price_1NDm2ZKD0TTmBHo0u99J14yr","type":"yearly","timeframe":"yearly","price":19.99},"monthly":{"id":"prod_NzlSDe5AXBSi4X","priceId":"price_1NDlvNKD0TTmBHo08pBWfjIZ","type":"monthly","timeframe":"monthly","price":3.99},"onetime":{"id":"prod_NzlbbPqyeBPsT8","priceId":"price_1NDm4CKD0TTmBHo0KnsX1AJw","type":"onetime","timeframe":"one time","price":59.99}}};
# 			window.IMG_POSTER_LOAD_COUNT=4;
# 			window.IMG_PROVIDERS_BAR_LOAD_COUNT=7;
# 			window.IMG_PROVIDERS_BUY_BOX_COUNT=6;
# 			window.IMG_NEW_TIMELINE_ROWS=1;
# 			window.IS_CANARY=false;
# 			window.NEW_TIMELINE_BUCKETS_LIMIT=4;
# 			window.NEW_TIMELINE_TITLES_PER_BUCKET_LIMIT=10;
# 			window.VUE_APP_TESTS_E2E=false;
#   </script>
#   <script defer="" src="/appassets/js/1720172319512_runtime.fc003d17.js">
#   </script>
#   <script defer="" src="/appassets/js/1720172319512_popular.e82ba5a3.js">
#   </script>
#   <script defer="" src="/appassets/js/1720172319512_chunk-5d4c672f.169e0d5f.js">
#   </script>
#   <script defer="" src="/appassets/js/1720172319512_title-list-grid.8f93decf.js">
#   </script>
#   <script defer="" src="/appassets/js/1720172319512_chunk-52c4f6ae.f1d5b608.js">
#   </script>
#   <script defer="" src="/appassets/js/1720172319512_chunk-e3426c90.6548c84e.js">
#   </script>
#   <script defer="" src="/appassets/js/1720172319512_default-footer.a4b9182a.js">
#   </script>
#   <script defer="" src="/appassets/js/1720172319512_low-priority-components.51993da0.js">
#   </script>
#   <script defer="" src="/appassets/js/1720172319512_npm.vue.53092bae.js">
#   </script>
#   <script defer="" src="/appassets/js/1720172319512_npm.firebase.3638ea87.js">
#   </script>
#   <script defer="" src="/appassets/js/1720172319512_npm.vueuse.b7d15e12.js">
#   </script>
#   <script defer="" src="/appassets/js/1720172319512_npm.sentry.911ad572.js">
#   </script>
#   <script defer="" src="/appassets/js/1720172319512_npm.sentry-internal.e001ff88.js">
#   </script>
#   <script defer="" src="/appassets/js/1720172319512_npm.graphql.f600a27c.js">
#   </script>
#   <script defer="" src="/appassets/js/1720172319512_npm.fortawesome.5e2b0570.js">
#   </script>
#   <script defer="" src="/appassets/js/1720172319512_npm.apollo-client.25b9e10b.js">
#   </script>
#   <script defer="" src="/appassets/js/1720172319512_npm.vue-router.3d04e099.js">
#   </script>
#   <script defer="" src="/appassets/js/1720172319512_npm.localforage.67c908d6.js">
#   </script>
#   <script defer="" src="/appassets/js/1720172319512_app.b9050618.js">
#   </script>
#  </body>
# </html>

# %% [markdown]
# ## **Fetching Movie URL's**

# %%
# fetching movie url
movie_url = []
for x in soup.find_all('a',attrs={'class':'title-list-grid__item--link'}):
  movie_url.append('https://www.justwatch.com'+x['href']) #append the url to movie url
print(movie_url)
print(len(movie_url))
# Out:
# ['https://www.justwatch.com/in/movie/aavesham-2024', 'https://www.justwatch.com/in/movie/munjha', 'https://www.justwatch.com/in/movie/project-k', 'https://www.justwatch.com/in/movie/hit-man', 'https://www.justwatch.com/in/movie/godzilla-minus-one', 'https://www.justwatch.com/in/movie/family-star', 'https://www.justwatch.com/in/movie/the-gangster-the-cop-the-devil', 'https://www.justwatch.com/in/movie/the-fall-guy', 'https://www.justwatch.com/in/movie/manjummel-boys', 'https://www.justwatch.com/in/movie/godzilla-x-kong-the-new-empire', 'https://www.justwatch.com/in/movie/laapataa-ladies', 'https://www.justwatch.com/in/movie/inside-out', 'https://www.justwatch.com/in/movie/maidaan', 'https://www.justwatch.com/in/movie/bade-miyan-chote-miyan-2023', 'https://www.justwatch.com/in/movie/the-crew-2024', 'https://www.justwatch.com/in/movie/furiosa', 'https://www.justwatch.com/in/movie/rockstar', 'https://www.justwatch.com/in/movie/dune-part-two', 'https://www.justwatch.com/in/movie/aranmanai-4', 'https://www.justwatch.com/in/movie/premalu', 'https://www.justwatch.com/in/movie/mad-max-fury-road', 'https://www.justwatch.com/in/movie/oppenheimer', 'https://www.justwatch.com/in/movie/hereditary', 'https://www.justwatch.com/in/movie/civil-war-2024-0', 'https://www.justwatch.com/in/movie/kung-fu-panda-4', 'https://www.justwatch.com/in/movie/varshangalkku-shesham', 'https://www.justwatch.com/in/movie/365-days', 'https://www.justwatch.com/in/movie/challengers', 'https://www.justwatch.com/in/movie/maharshi', 'https://www.justwatch.com/in/movie/maharaja-2024', 'https://www.justwatch.com/in/movie/madgaon-express', 'https://www.justwatch.com/in/movie/lovers-2024', 'https://www.justwatch.com/in/movie/12th-fail', 'https://www.justwatch.com/in/movie/exhuma', 'https://www.justwatch.com/in/movie/gangs-of-godavari', 'https://www.justwatch.com/in/movie/salaar', 'https://www.justwatch.com/in/movie/animal-2022', 'https://www.justwatch.com/in/movie/hanu-man', 'https://www.justwatch.com/in/movie/je-jatt-vigad-gya', 'https://www.justwatch.com/in/movie/maharaj', 'https://www.justwatch.com/in/movie/sous-la-seine', 'https://www.justwatch.com/in/movie/inside-out-2', 'https://www.justwatch.com/in/movie/black-magic-2024', 'https://www.justwatch.com/in/movie/aadujeevitham', 'https://www.justwatch.com/in/movie/dune-2021', 'https://www.justwatch.com/in/movie/anyone-but-you', 'https://www.justwatch.com/in/movie/spider-man-no-way-home', 'https://www.justwatch.com/in/movie/abigail-2024', 'https://www.justwatch.com/in/movie/ghostbusters-frozen-empire', 'https://www.justwatch.com/in/movie/blink-2024', 'https://www.justwatch.com/in/movie/the-first-omen', 'https://www.justwatch.com/in/movie/kingdom-of-the-planet-of-the-apes', 'https://www.justwatch.com/in/movie/mallari', 'https://www.justwatch.com/in/movie/harry-potter-and-the-philosophers-stone', 'https://www.justwatch.com/in/movie/pushpa', 'https://www.justwatch.com/in/movie/guruvayoor-ambalanadayil', 'https://www.justwatch.com/in/movie/tumbbad', 'https://www.justwatch.com/in/movie/sam-bahadur', 'https://www.justwatch.com/in/movie/garudan-2024', 'https://www.justwatch.com/in/movie/777-charlie', 'https://www.justwatch.com/in/movie/the-adjustment-bureau', 'https://www.justwatch.com/in/movie/satyabhama', 'https://www.justwatch.com/in/movie/love-me-if-you-dare-2024', 'https://www.justwatch.com/in/movie/k-g-f-chapter-1', 'https://www.justwatch.com/in/movie/yodha-2022', 'https://www.justwatch.com/in/movie/monkey-man', 'https://www.justwatch.com/in/movie/swatantra-veer-savarkar', 'https://www.justwatch.com/in/movie/a-quiet-place', 'https://www.justwatch.com/in/movie/freelance', 'https://www.justwatch.com/in/movie/chandu-champion', 'https://www.justwatch.com/in/movie/rasavathi', 'https://www.justwatch.com/in/movie/kurangu-pedal', 'https://www.justwatch.com/in/movie/pt-sir', 'https://www.justwatch.com/in/movie/trigger-warning', 'https://www.justwatch.com/in/movie/aquaman-and-the-lost-kingdom', 'https://www.justwatch.com/in/movie/t ...
# 100

# %% [markdown]
# ## **Scrapping Movie Title**

# %%
# movie title

movie_title = []
for url in movie_url:
  try:
    headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36',
    'Accept-Language': 'en-US,en;q=0.9',
    'Accept-Encoding': 'gzip, deflate, br',
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
}
    data = requests.get(url, headers = headers)
    soup = BeautifulSoup(data.text,'html.parser')
    title = soup.find_all('div',attrs={'class':'title-detail-hero__details'})[0].find_all('h1')[0].text
  except:
    title = "NA"
  movie_title.append(title)

print(movie_title)
print(len(movie_title))
# Out:
# [' Aavesham (2024)', ' Munjya (2024)', ' Kalki 2898 AD (2024)', ' Hit Man (2024)', ' Godzilla Minus One (2023)', ' Family Star (2024)', ' The Gangster, the Cop, the Devil (2019)', ' The Fall Guy (2024)', ' Manjummel Boys (2024)', ' Godzilla x Kong: The New Empire (2024)', ' Laapataa Ladies (2024)', ' Inside Out (2015)', ' Maidaan (2024)', ' Bade Miyan Chote Miyan (2024)', ' Crew (2024)', ' Furiosa: A Mad Max Saga (2024)', ' Rockstar (2011)', ' Dune: Part Two (2024)', ' Aranmanai 4 (2024)', ' Premalu (2024)', ' Mad Max: Fury Road (2015)', ' Oppenheimer (2023)', ' Hereditary (2018)', ' Civil War (2024)', ' Kung Fu Panda 4 (2024)', ' Varshangalkku Shesham (2024)', ' 365 Days (2020)', ' Challengers (2024)', ' Maharshi (2019)', ' Maharaja (2024)', ' Madgaon Express (2024)', ' Do Aur Do Pyaar (2024)', ' 12th Fail (2023)', ' Exhuma (2024)', ' Gangs of Godavari (2024)', ' Salaar (2023)', ' Animal (2023)', ' Hanu-Man (2024)', ' Je Jatt Vigarh Gya (2024)', ' Maharaj (2024)', ' Under Paris (2024)', ' Inside Out 2 (2024)', ' Shaitaan (2024)', ' The Goat Life (2024)', ' Dune (2021)', ' Anyone But You (2023)', ' Spider-Man: No Way Home (2021)', ' Abigail (2024)', ' Ghostbusters: Frozen Empire (2024)', ' Blink (2024)', ' The First Omen (2024)', ' Kingdom of the Planet of the Apes (2024)', ' Mallari (2023)', " Harry Potter and the Philosopher's Stone (2001)", ' Pushpa: The Rise (2021)', 'NA', 'NA', ' Sam Bahadur (2023)', ' Garudan (2024)', ' 777 Charlie (2022)', ' The Adjustment Bureau (2011)', 'NA', 'NA', 'NA', ' Yodha (2024)', ' Monkey Man (2024)', ' Swatantrya Veer Savarkar (2024)', 'NA', ' Freelance (2023)', ' Chandu Champion (2024)', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', ' Siddharth Roy (2024)', ' Mr. & Mrs. Mahi (2024)', ' Rathnam (2024)', 'NA', ' Addicted (2014)', ' Oru Nodi (2024)', 'NA', ' Teri Baaton Mein Aisa Uljha Jiya (2024)', 'NA', 'NA', ' Perfect Days (2023)', 'NA', 'NA', 'NA', 'NA', ' Late Night with the Devil (2024)', ' Laila Majnu (2018)', 'NA', ' Tarot (2024)', 'NA', 'NA']
# 100

# %% [markdown]
# ## **Scrapping release Year**

# %%
release_years_list = []

for url in movie_url:
    try:
        headers = {
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36',
            'Accept-Language': 'en-US,en;q=0.9',
            'Accept-Encoding': 'gzip, deflate, br',
            'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
        }

        response = requests.get(url, headers=headers)

        # Check if request was successful
        if response.status_code == 200:
            soup = BeautifulSoup(response.text, 'html.parser')

            # Extract release year
            release_element = soup.find('span', class_='release-year')

            if release_element:
                release_year = release_element.text.strip()
            else:
                release_year = "NA"  #  release year not found

        else:
            release_year = "NA"  # If request was not successful

    except Exception as e:
        print(f"Error processing {url}: {e}")
        release_year = "NA"  # If any exception occurs

    release_years_list.append(release_year)

# Print release years
print(release_years_list)
print(len(release_years_list))
# Out:
# ['(2024)', '(2024)', '(2024)', '(2024)', '(2023)', '(2024)', '(2019)', '(2024)', '(2024)', '(2024)', '(2024)', '(2015)', '(2024)', '(2024)', '(2024)', '(2024)', '(2011)', '(2024)', '(2024)', '(2024)', '(2015)', '(2023)', '(2018)', '(2024)', '(2024)', '(2024)', '(2020)', '(2024)', '(2019)', '(2024)', '(2024)', '(2024)', '(2023)', '(2024)', '(2024)', '(2023)', '(2023)', '(2024)', '(2024)', '(2024)', '(2024)', '(2024)', '(2024)', '(2024)', '(2021)', '(2023)', '(2021)', '(2024)', '(2024)', '(2024)', '(2024)', '(2024)', '(2023)', '(2001)', '(2021)', '(2024)', '(2018)', '(2023)', '(2024)', '(2022)', '(2011)', '(2024)', '(2024)', '(2018)', '(2024)', 'NA', 'NA', 'NA', 'NA', 'NA', '(2024)', 'NA', 'NA', 'NA', 'NA', '(2013)', 'NA', 'NA', 'NA', 'NA', '(2024)', '(2024)', '(2022)', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', '(2024)', 'NA', '(2014)', '(2024)', 'NA', '(2024)']
# 100

# %% [markdown]
# ## Convert  Release year to string

# %%
release_years = []
# Function to extract year from string
def extract_year(year_str):
    if not isinstance(year_str, str):
        return None
    match = re.search(r'\((\d{4})\)', year_str)
    return match.group(1) if match else 'NA'

# Append release years as strings to the list
for year in release_years_list:
    release_year = extract_year(year)
    release_years.append(str(release_year))

# Print the result
print(release_years)
# Out:
# ['2024', '2024', '2024', '2024', '2023', '2024', '2019', '2024', '2024', '2024', '2024', '2015', '2024', '2024', '2024', '2024', '2011', '2024', '2024', '2024', '2015', '2023', '2018', '2024', '2024', '2024', '2020', '2024', '2019', '2024', '2024', '2024', '2023', '2024', '2024', '2023', '2023', '2024', '2024', '2024', '2024', '2024', '2024', '2024', '2021', '2023', '2021', '2024', '2024', '2024', '2024', '2024', '2023', '2001', '2021', '2024', '2018', '2023', '2024', '2022', '2011', '2024', '2024', '2018', '2024', 'NA', 'NA', 'NA', 'NA', 'NA', '2024', 'NA', 'NA', 'NA', 'NA', '2013', 'NA', 'NA', 'NA', 'NA', '2024', '2024', '2022', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', '2024', 'NA', '2014', '2024', 'NA', '2024']

# %% [markdown]
# ## **Scrapping Genres**

# %%
genre_list = []

for url in movie_url:
    try:
        headers = {
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36',
            'Accept-Language': 'en-US,en;q=0.9',
            'Accept-Encoding': 'gzip, deflate, br',
            'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
        }

        response = requests.get(url, headers=headers)

        # Check if request was successful
        if response.status_code == 200:
            soup = BeautifulSoup(response.text, 'html.parser')

            # Extract genres
            genres = []
            h3_element = soup.find('h3', class_='detail-infos__subheading', string='Genres')
            if h3_element:
                div_element = h3_element.find_next_sibling('div', class_='detail-infos__value')
                if div_element:
                    genres = [genre.strip() for genre in div_element.text.split(',')]
                else:
                    genres = ["Genre Not Listed"]
            else:
                genres = ["Genre Not Listed"]

        else:
            genres = ["NA"]  # If request was not successful

    except Exception as e:
        print(f"Error processing {url}: {e}")
        genres = ["NA"]  # If any exception occurs

    genre_list.append(genres)

# Print the scraped genres
print(genre_list)
print(len(genre_list))
# Out:
# [['NA'], ['Comedy', 'Horror'], ['Fantasy', 'Science-Fiction', 'Drama', 'Action & Adventure', 'Mystery & Thriller'], ['NA'], ['Horror', 'Drama', 'Science-Fiction', 'Action & Adventure'], ['Drama', 'Action & Adventure', 'Comedy', 'Romance'], ['Action & Adventure', 'Mystery & Thriller', 'Crime'], ['NA'], ['Drama', 'Mystery & Thriller'], ['Action & Adventure', 'Fantasy', 'Science-Fiction', 'Mystery & Thriller'], ['NA'], ['NA'], ['NA'], ['Mystery & Thriller', 'Action & Adventure', 'Science-Fiction'], ['Comedy', 'Drama'], ['NA'], ['Drama', 'Music & Musical', 'Romance'], ['Science-Fiction', 'Action & Adventure', 'Drama'], ['NA'], ['NA'], ['Action & Adventure', 'Science-Fiction', 'Mystery & Thriller'], ['Drama', 'History'], ['Horror', 'Mystery & Thriller', 'Drama'], ['NA'], ['NA'], ['NA'], ['NA'], ['NA'], ['Drama', 'Action & Adventure'], ['Action & Adventure', 'Drama', 'Mystery & Thriller'], ['Comedy', 'Drama'], ['NA'], ['Drama'], ['NA'], ['Action & Adventure', 'Drama', 'Crime', 'History'], ['Action & Adventure', 'Crime', 'Drama', 'Mystery & Thriller'], ['Action & Adventure', 'Crime', 'Drama', 'Mystery & Thriller'], ['Science-Fiction', 'Fantasy', 'Action & Adventure', 'Comedy'], ['Drama'], ['NA'], ['NA'], ['Animation', 'Kids & Family', 'Action & Adventure', 'Comedy', 'Drama', 'Fantasy'], ['Mystery & Thriller', 'Horror', 'Drama'], ['Drama'], ['NA'], ['Romance', 'Comedy'], ['Action & Adventure', 'Science-Fiction', 'Fantasy'], ['Horror', 'Mystery & Thriller'], ['NA'], ['NA'], ['NA'], ['Science-Fiction', 'Action & Adventure', 'Drama', 'Mystery & Thriller'], ['NA'], ['NA'], ['Mystery & Thriller', 'Action & Adventure', 'Drama', 'Crime'], ['Comedy'], ['NA'], ['Drama', 'War & Military'], ['Action & Adventure', 'Crime', 'Mystery & Thriller'], ['Action & Adventure', 'Comedy', 'Drama'], ['NA'], ['NA'], ['NA'], ['Action & Adventure', 'Crime', 'Mystery & Thriller', 'Drama'], ['Mystery & Thriller', 'Action & Adventure', 'Drama'], ['Mystery & Thriller', 'Action & Adventure', 'Crime'], ['Drama', 'History'], ['Horror', 'Drama', 'Science-Fiction'], ['NA'], ['Drama', 'History', 'Sport', 'War & Military', 'Action & Adventure'], ['NA'], ['Drama'], ['NA'], ['NA'], ['Action & Adventure', 'Fantasy', 'Science-Fiction'], ['NA'], ['NA'], ['NA'], ['NA'], ['Drama', 'Romance'], ['Drama', 'Romance', 'Sport'], ['Action & Adventure', 'Romance'], ['NA'], ['NA'], ['NA'], ['NA'], ['NA'], ['NA'], ['NA'], ['Drama'], ['NA'], ['Mystery & Thriller', 'Drama', 'Action & Adventure'], ['NA'], ['Comedy', 'Drama', 'Romance', 'Kids & Family'], ['Horror'], ['Romance', 'Drama'], ['NA'], ['NA'], ['Action & Adventure', 'Drama', 'History'], ['NA']]
# 100

# %% [markdown]
# ## **Scrapping IMBD Rating**

# %%
imdb_list = []

for url in movie_url:
    try:
        # Constructing the absolute URL for fetching each movie
        headers = {
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36',
            'Accept-Language': 'en-US,en;q=0.9',
            'Accept-Encoding': 'gzip, deflate, br',
            'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
        }

        response_g = requests.get(url, headers=headers)
        soup = BeautifulSoup(response_g.text, 'html.parser')

        # Selecting only those h3 whose heading is Rating
        h3_element = soup.find('h3', class_='detail-infos__subheading', string='Rating')

        if h3_element:
            # Check if the next sibling is a div with class "detail-infos__value"
            div_element = h3_element.find_next_sibling('div', class_='detail-infos__value')

            if div_element:
                inside_div = div_element.find_all('div', class_='jw-scoring-listing__rating')

                # Check if inside_div is non-empty
                if inside_div:
                    inside_div_last = inside_div[-1] # extracting last div of inside div as last div elemnt contains span (in which last span contains rating)

                    # Check if inside_div_last is non-empty
                    if inside_div_last:
                        span_all = inside_div_last.find_all('span')

                        # Check if span_all is non-empty
                        if span_all:
                            span_last = span_all[-1] # Here we are extracting rating from the last span(span_last) inside last div(inside_div_last) of main div_element(div_element)
                            imdb_list.append(span_last.text.strip())
                        else:
                            imdb_list.append("Imdb Rating Not Listed.")
                    else:
                        imdb_list.append("Imdb Rating Not Listed.")
                else:
                    imdb_list.append("Imdb Rating Not Listed.")
            else:
                imdb_list.append("Imdb Rating Not Listed.")
        else:
            imdb_list.append("Imdb Rating Not Listed.")

    except Exception as e:
        print(f"Error processing {url}: {e}")
        imdb_list.append("Imdb Rating Not Listed.")

# Print theIMDb ratings
print(imdb_list)
print(len(imdb_list))
# Out:
# ['8.0  (13k)', '7.2  (14k)', '8.0  (28k)', 'Imdb Rating Not Listed.', '7.7  (129k)', '5.2  (3k)', '6.9  (24k)', '7.0  (113k)', '8.3  (17k)', '6.2  (78k)', '8.5  (34k)', 'Imdb Rating Not Listed.', '8.1  (16k)', '4.1  (37k)', '5.9  (34k)', 'Imdb Rating Not Listed.', 'Imdb Rating Not Listed.', 'Imdb Rating Not Listed.', '5.2  (1k)', '7.9  (12k)', '8.1  (1m)', '8.3  (762k)', '7.3  (384k)', '7.2  (123k)', 'Imdb Rating Not Listed.', 'Imdb Rating Not Listed.', '3.3  (99k)', 'Imdb Rating Not Listed.', 'Imdb Rating Not Listed.', 'Imdb Rating Not Listed.', '7.1  (35k)', '6.4  (5k)', '8.9  (120k)', '6.9  (11k)', 'Imdb Rating Not Listed.', '6.5  (66k)', '6.2  (93k)', '7.9  (25k)', '4.7', '6.4  (6k)', 'Imdb Rating Not Listed.', '7.9  (56k)', 'Imdb Rating Not Listed.', '8.6  (7k)', '8.0  (884k)', '6.1  (97k)', '8.2  (890k)', 'Imdb Rating Not Listed.', '6.1  (54k)', 'Imdb Rating Not Listed.', 'Imdb Rating Not Listed.', '7.2  (56k)', '6.3', 'Imdb Rating Not Listed.', '7.6  (88k)', '6.7  (1k)', 'Imdb Rating Not Listed.', '7.7  (17k)', '7.5  (1k)', 'Imdb Rating Not Listed.', 'Imdb Rating Not Listed.', 'Imdb Rating Not Listed.', 'Imdb Rating Not Listed.', '8.2  (99k)', '5.7  (6k)', 'Imdb Rating Not Listed.', 'Imdb Rating Not Listed.', '7.5  (592k)', 'Imdb Rating Not Listed.', 'Imdb Rating Not Listed.', 'Imdb Rating Not Listed.', 'Imdb Rating Not Listed.', 'Imdb Rating Not Listed.', 'Imdb Rating Not Listed.', 'Imdb Rating Not Listed.', '8.2  (1m)', '7.5  (38k)', '6.9  (48k)', '7.8  (24k)', '7.5  (1k)', 'Imdb Rating Not Listed.', 'Imdb Rating Not Listed.', 'Imdb Rating Not Listed.', '5.0  (12k)', 'Imdb Rating Not Listed.', 'Imdb Rating Not Listed.', 'Imdb Rating Not Listed.', '7.9  (20k)', 'Imdb Rating Not Listed.', 'Imdb Rating Not Listed.', 'Imdb Rating Not Listed.', 'Imdb Rating Not Listed.', '6.2  (25k)', '6.1  (15k)', 'Imdb Rating Not Listed.', '7.7  (4k)', 'Imdb Rating Not Listed.', '4.8  (14k)', 'Imdb Rating Not Listed.', 'Imdb Rating Not Listed.']
# 100

# %% [markdown]
# ### IMDB Rating

# %%
# Function to extract the first value
def extract_first_value(imdb_rating):
    match = re.match(r"(\d+(\.\d+)?)", imdb_rating)
    return match.group(1) if match else None

# Extracted ratings
imdb_ratings = [extract_first_value(rating) for rating in imdb_list]

# Print the extracted ratings
print(imdb_ratings)

# Print the length of the extracted ratings list
print(len(imdb_ratings))
# Out:
# ['8.0', '7.2', '8.0', None, '7.7', '5.2', '6.9', '7.0', '8.3', '6.2', '8.5', None, '8.1', '4.1', '5.9', None, None, None, '5.2', '7.9', '8.1', '8.3', '7.3', '7.2', None, None, '3.3', None, None, None, '7.1', '6.4', '8.9', '6.9', None, '6.5', '6.2', '7.9', '4.7', '6.4', None, '7.9', None, '8.6', '8.0', '6.1', '8.2', None, '6.1', None, None, '7.2', '6.3', None, '7.6', '6.7', None, '7.7', '7.5', None, None, None, None, '8.2', '5.7', None, None, '7.5', None, None, None, None, None, None, None, '8.2', '7.5', '6.9', '7.8', '7.5', None, None, None, '5.0', None, None, None, '7.9', None, None, None, None, '6.2', '6.1', None, '7.7', None, '4.8', None, None]
# 100

# %% [markdown]
# ### Number of reviews

# %%
# Function to extract the second value
def extract_second_value(imdb_rating):
    match = re.search(r"\((\d+[kKmM]?)\)", imdb_rating)
    return match.group(1) if match else 'NA'

# Extracted second values
reviews = [extract_second_value(rating) for rating in imdb_list]

# Print the extracted second values
print(reviews)

# Print the length of the extracted second values list
print(len(reviews))
# Out:
# ['13k', '14k', '28k', 'NA', '129k', '3k', '24k', '113k', '17k', '78k', '34k', 'NA', '16k', '37k', '34k', 'NA', 'NA', 'NA', '1k', '12k', '1m', '762k', '384k', '123k', 'NA', 'NA', '99k', 'NA', 'NA', 'NA', '35k', '5k', '120k', '11k', 'NA', '66k', '93k', '25k', 'NA', '6k', 'NA', '56k', 'NA', '7k', '884k', '97k', '890k', 'NA', '54k', 'NA', 'NA', '56k', 'NA', 'NA', '88k', '1k', 'NA', '17k', '1k', 'NA', 'NA', 'NA', 'NA', '99k', '6k', 'NA', 'NA', '592k', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', '1m', '38k', '48k', '24k', '1k', 'NA', 'NA', 'NA', '12k', 'NA', 'NA', 'NA', '20k', 'NA', 'NA', 'NA', 'NA', '25k', '15k', 'NA', '4k', 'NA', '14k', 'NA', 'NA']
# 100

# %% [markdown]
# ## **Scrapping Runtime/Duration**

# %%
# Write Your Code here

runtime_list=[]

# For every movie title present in movies_title_list
for url in movie_url:

    headers = {
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36',
            'Accept-Language': 'en-US,en;q=0.9',
            'Accept-Encoding': 'gzip, deflate, br',
            'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
        }

    response_g = requests.get(url, headers=headers)
    soup = BeautifulSoup(response_g.text,'html.parser')

    # Selecting only those h3 whose heading is runtine
    h3_element = soup.find('h3', class_='detail-infos__subheading', string='Runtime')

    if h3_element:
        # Check if the next sibling is a div with class "detail-infos__value"
        div_element = h3_element.find_next_sibling('div', class_='detail-infos__value')

        if div_element:
            runtime_list.append(div_element.text.strip())
        else:
            runtime_list.append("No Runtime/Duration mentioned")
    else:
      runtime_list.append("No Runtime/Duration mentioned")

print(runtime_list)
print(len(runtime_list))
# Out:
# ['2h 38min', '2h 3min', 'No Runtime/Duration mentioned', '1h 56min', '2h 5min', 'No Runtime/Duration mentioned', '1h 50min', 'No Runtime/Duration mentioned', '2h 15min', '1h 55min', '2h 2min', '1h 35min', 'No Runtime/Duration mentioned', '2h 44min', '1h 58min', '2h 28min', 'No Runtime/Duration mentioned', '2h 47min', '2h 28min', 'No Runtime/Duration mentioned', '2h 1min', '3h 0min', '2h 6min', 'No Runtime/Duration mentioned', 'No Runtime/Duration mentioned', 'No Runtime/Duration mentioned', 'No Runtime/Duration mentioned', 'No Runtime/Duration mentioned', '2h 56min', 'No Runtime/Duration mentioned', '2h 23min', 'No Runtime/Duration mentioned', '2h 26min', '2h 14min', '2h 23min', '2h 55min', '3h 21min', '2h 39min', '2h 12min', '2h 12min', '1h 44min', '1h 37min', '2h 12min', '2h 52min', 'No Runtime/Duration mentioned', '1h 44min', '2h 28min', '1h 49min', 'No Runtime/Duration mentioned', '2h 16min', '2h 0min', '2h 25min', '2h 9min', 'No Runtime/Duration mentioned', '2h 59min', '2h 12min', 'No Runtime/Duration mentioned', '2h 30min', 'No Runtime/Duration mentioned', 'No Runtime/Duration mentioned', 'No Runtime/Duration mentioned', 'No Runtime/Duration mentioned', '2h 8min', '2h 36min', '2h 10min', 'No Runtime/Duration mentioned', 'No Runtime/Duration mentioned', '1h 31min', 'No Runtime/Duration mentioned', 'No Runtime/Duration mentioned', 'No Runtime/Duration mentioned', 'No Runtime/Duration mentioned', 'No Runtime/Duration mentioned', 'No Runtime/Duration mentioned', 'No Runtime/Duration mentioned', '3h 0min', 'No Runtime/Duration mentioned', 'No Runtime/Duration mentioned', 'No Runtime/Duration mentioned', 'No Runtime/Duration mentioned', 'No Runtime/Duration mentioned', 'No Runtime/Duration mentioned', 'No Runtime/Duration mentioned', '1h 45min', '2h 8min', '1h 45min', '2h 21min', '2h 38min', 'No Runtime/Duration mentioned', '2h 4min', 'No Runtime/Duration mentioned', 'No Runtime/Duration mentioned', 'No Runtime/Duration mentioned', 'No Runtime/Duration mentioned', '1h 33min', '2h 19min', '1h 54min', '1h 32min', 'No Runtime/Duration mentioned', 'No Runtime/Duration mentioned']
# 100

# %% [markdown]
# ## **Scrapping Age Rating**

# %%
# Write Your Code here

age_rating_list = []

# For every movie title present in movies_title_list , Finding their Age Rating
for url in movie_url:
    headers = {
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36',
            'Accept-Language': 'en-US,en;q=0.9',
            'Accept-Encoding': 'gzip, deflate, br',
            'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
        }

    response_g = requests.get(url, headers=headers)

    soup = BeautifulSoup(response_g.text,'html.parser')

    # Selecting only those h3 whose heading is Age rating
    h3_element = soup.find('h3', class_='detail-infos__subheading', string='Age rating')

    if h3_element:
        # Check if the next sibling is a div with class "detail-infos__value"
        div_element = h3_element.find_next_sibling('div', class_='detail-infos__value')

        if div_element:
            age_rating_list.append(div_element.text.strip())
        else:
            age_rating_list.append("Age Rating Not Listed.")
    else:
         age_rating_list.append("Age Rating Not Listed.")

print(age_rating_list)
print(len(age_rating_list))
# Out:
# ['Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'UA', 'UA', 'UA', 'UA', 'U', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'U', 'A', 'Age Rating Not Listed.', 'A', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'A', 'UA', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'UA', 'Age Rating Not Listed.', 'A', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'UA', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'A', 'UA', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'A', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'U', 'UA', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'UA', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'A', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'UA', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'A', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'UA', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'A', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'UA', 'A', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'UA', 'UA', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'UA', 'Age Rating Not Listed.']
# 100

# %% [markdown]
# ## **Fetching Production Countries Details**

# %%
# Write Your Code here
movie_production_country_list=[]# List to store all movie production country

# For every movie title present in movies_title_list , Finding their Production country
for movie in movie_title:
    headers = {
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36',
            'Accept-Language': 'en-US,en;q=0.9',
            'Accept-Encoding': 'gzip, deflate, br',
            'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
        }

    # Constructing the absolute URL for fetching each movie
    response_g = requests.get(url, headers=headers)
    soup = BeautifulSoup(response_g.text,'html.parser')

    # Selecting only those h3 whose sub-heading inside details- infos is 'Production Country'
    h3_element = soup.find('h3', class_='detail-infos__subheading', string=' Production country ')

    if h3_element:
        # Check if the next sibling is a div with class "detail-infos__value"
        div_element = h3_element.find_next_sibling('div', class_='detail-infos__value')

        if div_element:
            movie_production_country_list.append(div_element.text.strip())
        else:
            movie_production_country_list.append("Production Country Not Listed")
    else:
       movie_production_country_list.append("Production Country Not Listed")
print(movie_production_country_list)
print(len(movie_production_country_list))
# Out:
# ['Production Country Not Listed', 'Production Country Not Listed', 'Production Country Not Listed', 'United States', 'Production Country Not Listed', 'Production Country Not Listed', 'United States', 'United States', 'Production Country Not Listed', 'United States', 'Production Country Not Listed', 'United States', 'Production Country Not Listed', 'Production Country Not Listed', 'Production Country Not Listed', 'Production Country Not Listed', 'United States', 'Production Country Not Listed', 'United States', 'Production Country Not Listed', 'United States', 'Production Country Not Listed', 'Production Country Not Listed', 'Production Country Not Listed', 'Production Country Not Listed', 'Production Country Not Listed', 'United States', 'United States', 'Production Country Not Listed', 'Production Country Not Listed', 'Production Country Not Listed', 'Production Country Not Listed', 'United States', 'United States', 'Production Country Not Listed', 'United States', 'United States', 'United States', 'United States', 'Production Country Not Listed', 'United States', 'United States', 'United States', 'United States', 'United States', 'United States', 'United States', 'Production Country Not Listed', 'United States', 'United States', 'Production Country Not Listed', 'United States', 'United States', 'United States', 'Production Country Not Listed', 'Production Country Not Listed', 'United States', 'United States', 'United States', 'Production Country Not Listed', 'Production Country Not Listed', 'United States', 'United States', 'United States', 'United States', 'United States', 'United States', 'United States', 'Production Country Not Listed', 'United States', 'United States', 'United States', 'United States', 'United States', 'United States', 'Production Country Not Listed', 'United States', 'United States', 'United States', 'United States', 'United States', 'United States', 'United States', 'United States', 'United States', 'United States', 'United States', 'United States', 'United States', 'United States', 'United States', 'United States', 'United States', 'United States', 'United States', 'United States', 'United States', 'United States', 'United States', 'United States']
# 100

# %% [markdown]
# ## **Fetching Streaming Service Details**

# %%
# Write Your Code here
streaming_list=[]# List to store all movie streaming platform

# For every movie title present in movies_title_list , Finding their Streaming Platform
for url in movie_url:

    headers = {
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36',
            'Accept-Language': 'en-US,en;q=0.9',
            'Accept-Encoding': 'gzip, deflate, br',
            'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
        }

    response_g = requests.get(url, headers=headers)
    soup = BeautifulSoup(response_g.text,'html.parser')

    # Finding the outer div element with the class "buybox-row stream"
    outer_div = soup.find('div', class_='buybox-row stream')

    if outer_div:
        # Finding the nested div with class "buybox-row__offers" inside the outer div
        inner_div = outer_div.find('div', class_='buybox-row__offers')

        if inner_div:
            # Find the picture element within the nested div
            picture_element = inner_div.find('picture')

            if picture_element:
                # Extract the alt attribute from the img element inside the picture which contains streaming platform name
                img_element = picture_element.find('img')
                if img_element:
                    alt_text = img_element['alt']
                    streaming_list.append(alt_text)
                else:
                    streaming_list.append("Not Available for Streaming.")
            else:
                streaming_list.append("Not Available for Streaming.")
        else:
            streaming_list.append("Not Available for Streaming.")
    else:
        streaming_list.append("Not Available for Streaming.")

print(streaming_list)
print(len(streaming_list))
# Out:
# ['Not Available for Streaming.', 'Not Available for Streaming.', 'Not Available for Streaming.', 'Not Available for Streaming.', 'Not Available for Streaming.', 'Not Available for Streaming.', 'Not Available for Streaming.', 'Not Available for Streaming.', 'Not Available for Streaming.', 'Not Available for Streaming.', 'Not Available for Streaming.', 'Not Available for Streaming.', 'Not Available for Streaming.', 'Not Available for Streaming.', 'Not Available for Streaming.', 'Not Available for Streaming.', 'Not Available for Streaming.', 'Not Available for Streaming.', 'Not Available for Streaming.', 'Not Available for Streaming.', 'Not Available for Streaming.', 'Not Available for Streaming.', 'Not Available for Streaming.', 'Not Available for Streaming.', 'Not Available for Streaming.', 'Not Available for Streaming.', 'Not Available for Streaming.', 'Not Available for Streaming.', 'Not Available for Streaming.', 'Not Available for Streaming.', 'Not Available for Streaming.', 'Not Available for Streaming.', 'Not Available for Streaming.', 'Not Available for Streaming.', 'Not Available for Streaming.', 'Not Available for Streaming.', 'Not Available for Streaming.', 'Not Available for Streaming.', 'Not Available for Streaming.', 'Not Available for Streaming.', 'Not Available for Streaming.', 'Not Available for Streaming.', 'Not Available for Streaming.', 'Not Available for Streaming.', 'Not Available for Streaming.', 'Not Available for Streaming.', 'Not Available for Streaming.', 'Not Available for Streaming.', 'Not Available for Streaming.', 'Not Available for Streaming.', 'Not Available for Streaming.', 'Not Available for Streaming.', 'Not Available for Streaming.', 'Not Available for Streaming.', 'Not Available for Streaming.', 'Not Available for Streaming.', 'Not Available for Streaming.', 'Not Available for Streaming.', 'Not Available for Streaming.', 'Not Available for Streaming.', 'Not Available for Streaming.', 'Not Available for Streaming.', 'Not Available for Streaming.', 'Not Available for Streaming.', 'Not Available for Streaming.', 'Not Available for Streaming.', 'Not Available for Streaming.', 'Not Available for Streaming.', 'Not Available for Streaming.', 'Not Available for Streaming.', 'Not Available for Streaming.', 'Not Available for Streaming.', 'Not Available for Streaming.', 'Not Available for Streaming.', 'Not Available for Streaming.', 'Not Available for Streaming.', 'Not Available for Streaming.', 'Not Available for Streaming.', 'Not Available for Streaming.', 'Not Available for Streaming.', 'Not Available for Streaming.', 'Not Available for Streaming.', 'Not Available for Streaming.', 'Not Available for Streaming.', 'Not Available for Streaming.', 'Not Available for Streaming.', 'Not Available for Streaming.', 'Not Available for Streaming.', 'Not Available for Streaming.', 'Not Available for Streaming.', 'Not Available for Streaming.', 'Not Available for Streaming.', 'Not Available for Streaming.', 'Not Available for Streaming.', 'Not Available for Streaming.', 'Not Available for Streaming.', 'Not Available for Streaming.', 'Not Available for Streaming.', 'Not Available for Streaming.', 'Not Available for Streaming.']
# 100

# %% [markdown]
# ## **Now Creating Movies DataFrame**

# %%
# Write Your Code here
data_movies = {
    'Movie Title':movie_title,
    'IMDB Rating':imdb_ratings,
    'Number of Reviews':reviews,
    'Release Year': release_years,
    'Genre':genre_list,
    'Runtime/Duration':runtime_list,
    'Age Rating':age_rating_list,
    'Production Country':movie_production_country_list,
    'Streaming Platform':streaming_list,
    'URL':movie_url
}

df_movies = pd.DataFrame(data_movies)
df_movies.head(10)
# Out:
#                                 Movie Title IMDB Rating Number of Reviews  \
# 0                           Aavesham (2024)         8.0               13k
# 1                             Munjya (2024)         7.2               14k
# 2                      Kalki 2898 AD (2024)         8.0               28k
# 3                            Hit Man (2024)        None                NA
# 4                 Godzilla Minus One (2023)         7.7              129k
# 5                        Family Star (2024)         5.2                3k
# 6   The Gangster, the Cop, the Devil (2019)         6.9               24k
# 7                       The Fall Guy (2024)         7.0              113k
# 8                     Manjummel Boys (2024)         8.3               17k
# 9    Godzilla x Kong: The New Empire (2024)         6.2               78k
#
#   Release Year                                              Genre  \
# 0         2024                                               [NA]
# 1         2024                                   [Comedy, Horror]
# 2         2024  [Fantasy, Science-Fiction, Drama, Action & Adv...
# 3         2024                                               [NA]
# 4         2023  [Horror, Drama, Science-Fiction, Action & Adve...
# 5         2024       [Drama, Action & Adventure, Comedy, Romance]
# 6         2019    [Action & Adventure, Mystery & Thriller, Crime]
# 7         2024                                               [NA]
# 8         2024                        [Drama, Mystery & Thriller]
# 9         2024  [Action & Adventure, Fantasy, Science-Fiction,...
#
#                 Runtime/Duration              Age Rating  \
# 0                       2h 38min  Age Rating Not Listed.
# 1                        2h 3min  Age Rating Not Listed.
# 2  No Runtime/Duration mentioned  Age Rating Not Listed.
# 3                       1h 56min  Age Rating Not Listed.
# 4                        2h 5min  Age Rating Not Listed.
# 5  No Runtime/Duration mentioned  Age Rating Not Listed.
# 6                       1h 50min  Age Rating Not Listed.
# 7  No Runtime/Duration mentioned                      UA
# 8                       2h 15min                      UA
# 9                       1h 55min                      UA
#
#               Production Country            Streaming Platform  \
# 0  Production Country Not Listed  Not Available for Streaming.
# 1  Production Country Not Listed  Not Available for Streaming.
# 2  Production Country Not Listed  Not Available for Streaming.
# 3                  United States  Not Available for Streaming.
# 4  Production Country Not Listed  Not Available for Streaming.
# 5  Production Country Not Listed  Not Available for Streaming.
# 6                  United States  Not Available for Streaming.
# 7                  United States  Not Available for Streaming.
# 8  Production Country Not Listed  Not Available for Streaming.
# 9                  United States  Not Available for Streaming.
#
#                                                  URL
# 0   https://www.justwatch.com/in/movie/aavesham-2024
# 1          https://www.justwatch.com/in/movie/munjha
# 2       https://www.justwatch.com/in/movie/project-k
# 3         https://www.justwatch.com/in/movie/hit-man
# 4  https://www.justwatch.com/in/movie/godzilla-mi...
# 5     https://www.justwatch.com/in/movie/family-star
# 6  https://www.justwatch.com/in/movie/the-gangste...
# 7    https://www.justwatch.com/in/movie/the-fall-guy
# 8  https://www.justwatch.com/in/movie/manjummel-boys
# 9  https://www.justwatch.com/in/movie/godzilla-x-...

# %% [markdown]
# ## **Scraping TV  Show Data**

# %%
# Specifying the URL from which tv show related data will be fetched
tv_url='https://www.justwatch.com/in/tv-shows?release_year_from=2000'
headers = {
'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36',
'Accept-Language': 'en-US,en;q=0.9',
'Accept-Encoding': 'gzip, deflate, br',
'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
}

# Sending an HTTP GET request to the URL
page=requests.get(tv_url, headers=headers )
# Parsing the HTML content using BeautifulSoup with the 'html.parser'
soup=BeautifulSoup(page.text,'html.parser')
# Printing the prettified HTML content
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html data-vue-meta="%7B%22dir%22:%7B%22ssr%22:%22ltr%22%7D,%22lang%22:%7B%22ssr%22:%22en%22%7D%7D" data-vue-meta-server-rendered="" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta charset="utf-8" data-vue-meta="ssr"/>
#   <meta content="IE=edge" data-vue-meta="ssr" httpequiv="X-UA-Compatible"/>
#   <meta content="viewport-fit=cover, width=device-width, initial-scale=1.0, minimum-scale=1.0, maximum-scale=1.0, user-scalable=no" data-vue-meta="ssr" name="viewport"/>
#   <meta content="JustWatch" data-vue-meta="ssr" property="og:site_name"/>
#   <meta content="794243977319785" data-vue-meta="ssr" property="fb:app_id"/>
#   <meta content="/appassets/img/JustWatch_logo_with_claim.png" data-vmid="og:image" data-vue-meta="ssr" property="og:image"/>
#   <meta content="606" data-vmid="og:image:width" data-vue-meta="ssr" property="og:image:width"/>
#   <meta content="302" data-vmid="og:image:height" data-vue-meta="ssr" property="og:image:height"/>
#   <meta content="yes" data-vue-meta="ssr" name="mobile-web-app-capable"/>
#   <meta content="yes" data-vue-meta="ssr" name="apple-mobile-web-app-capable"/>
#   <meta content="#182531" data-vue-meta="ssr" name="theme-color"/>
#   <meta content="4eBTNBm4L6RaWdF8V51EHZajskAMgXYAg81iRXJqumQ" data-vue-meta="ssr" name="google-site-verification"/>
#   <meta content="d61y4roe8t5xwbb0gfu6gwe8j8iq3i" data-vue-meta="ssr" name="facebook-domain-verification"/>
#   <meta content="dmorpwc4h544ct6mv" data-vue-meta="ssr" name="dailymotion-domain-verification"/>
#   <meta content="Watch series online" data-vmid="og:title" data-vue-meta="ssr" property="og:title"/>
#   <meta content="watch series, watch tv series online, series online, online watch tv shows online, best shows to binge watch, popular tv shows" data-vue-meta="ssr" name="keywords"/>
#   <meta content="Where to watch TV series online? Find with JustWatch all the series you can stream online on Netflix, Hooq, Voot and 10 other streaming providers. Purchase, rent online &amp; flat-rate." data-vmid="description" data-vue-meta="ssr" name="description"/>
#   <meta content="Where to watch TV series online? Find with JustWatch all the series you can stream online on Netflix, Hooq, Voot and 10 other streaming providers. Purchase, rent online &amp; flat-rate." data-vmid="og:description" data-vue-meta="ssr" property="og:description"/>
#   <meta content="noindex, follow" data-vmid="robots" data-vue-meta="ssr" name="robots"/>
#   <title>
#    Watch series online
#   </title>
#   <link as="font" crossorigin="true" data-vue-meta="ssr" href="/appassets/fonts/lato-regular.woff2" rel="preload" type="font/woff2"/>
#   <link as="font" crossorigin="true" data-vue-meta="ssr" href="/appassets/fonts/lato-700.woff2" rel="preload" type="font/woff2"/>
#   <link as="font" crossorigin="true" data-vue-meta="ssr" href="/appassets/fonts/lato-900.woff2" rel="preload" type="font/woff2"/>
#   <link as="font" crossorigin="true" data-vue-meta="ssr" href="/appassets/fonts/anton.woff" rel="preload" type="font/woff2"/>
#   <link data-vue-meta="ssr" href="/appassets/favicon.ico" rel="icon"/>
#   <link crossorigin="use-credentials" data-vue-meta="ssr" href="https://images.justwatch.com" rel="preconnect"/>
#   <link data-vue-meta="ssr" href="https://www.googletagmanager.com/" rel="dns-prefetch"/>
#   <link data-vue-meta="ssr" href="https://ib.adnxs.com" rel="dns-prefetch"/>
#   <link data-vmid="canonical" data-vue-meta="ssr" href="https://www.justwatch.com/in/tv-shows" rel="canonical"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/ar/series" hreflang="es-AR" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/at/Serien" hreflang="de-AT" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/au/tv-shows" hreflang="en-AU" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/be/series" hreflang="fr-BE" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/bg/сериали" hreflang="bg-BG" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/br/series" hreflang="pt-BR" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/ca/tv-shows" hreflang="en-CA" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/ch/Serien" hreflang="de-CH" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/cl/series" hreflang="es-CL" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/co/series" hreflang="es-CO" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/cz/serialy" hreflang="cs-CZ" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/de/Serien" hreflang="de-DE" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/dk/tv-series" hreflang="en-DK" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/ec/series" hreflang="es-EC" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/eg/tv-shows" hreflang="ar-EG" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/es/series" hreflang="es-ES" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/fi/sarjat" hreflang="fi-FI" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/fr/series" hreflang="fr-FR" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/uk/tv-series" hreflang="en-GB" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/gr/τηλεοπτικές-σειρές" hreflang="el-GR" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/hk/電視節目" hreflang="zh-HK" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/hr/serije" hreflang="hr-HR" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/hu/tv-sorozat" hreflang="hu-HU" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/ie/tv-series" hreflang="en-IE" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/in/tv-shows" hreflang="en-IN" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/iq/tv-shows" hreflang="ar-IQ" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/is/þættir" hreflang="is-IS" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/it/serie-tv" hreflang="it-IT" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/jp/テレビ番組" hreflang="ja-JP" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/kr/TV-프로그램" hreflang="ko-KR" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/lb/tv-shows" hreflang="ar-LB" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/mx/series" hreflang="es-MX" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/my/tv-shows" hreflang="en-MY" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/nl/tv-series" hreflang="en-NL" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/no/tv-series" hreflang="en-NO" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/nz/tv-shows" hreflang="en-NZ" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/pe/series" hreflang="es-PE" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/ph/tv-shows" hreflang="en-PH" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/pl/seriale" hreflang="pl-PL" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/ps/tv-shows" hreflang="ar-PS" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/pt/series" hreflang="pt-PT" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/ro/seriale" hreflang="ro-RO" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/ru/сериалы" hreflang="ru-RU" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/se/tv-serier" hreflang="sv-SE" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/sg/tv-shows" hreflang="en-SG" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/sk/seriály" hreflang="sk-SK" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/tr/tv-dizileri" hreflang="tr-TR" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/us/tv-shows" hreflang="en-US" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/va/serie-tv" hreflang="it-VA" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/xk/seriale-televizive" hreflang="sq-XK" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/za/tv-series" hreflang="en-ZA" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/ee/seriaalid" hreflang="et-EE" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/lt/tv-laidos" hreflang="lt-LT" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/id/tv-shows" hreflang="en-ID" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/tw/電視節目" hreflang="zh-TW" rel="alternate"/>
#   <base href="/" target="_self"/>
#   <link as="image" href="/appassets/img/logo/JustWatch-logo-large.webp" imagesrcset="/appassets/img/logo/JustWatch-logo-large.webp 1px" importance="high" rel="preload"/>
#   <link as="image" href="https://www.justwatch.com/images/icon/207360008/s100/netflix.{format}/icon.webp" imagesrcset="https://www.justwatch.com/images/icon/207360008/s100/netflix.{format}/icon.webp 1px" importance="high" media="(min-width: 0px)" rel="preload"/>
#   <link as="image" href="https://www.justwatch.com/images/icon/52449861/s100/amazonprimevideo.{format}/icon.webp" imagesrcset="https://www.justwatch.com/images/icon/52449861/s100/amazonprimevideo.{format}/icon.webp 1px" importance="high" media="(min-width: 0px)" rel="preload"/>
#   <link as="image" href="https://www.justwatch.com/images/icon/152862153/s100/appletvplus.{format}/icon.webp" imagesrcset="https://www.justwatch.com/images/icon/152862153/s100/appletvplus.{format}/icon.webp 1px" importance="high" media="(min-width: 0px)" rel="preload"/>
#   <link as="image" href="https://www.justwatch.com/images/icon/190848813/s100/itunes.{format}/icon.webp" imagesrcset="https://www.justwatch.com/images/icon/190848813/s100/itunes.{format}/icon.webp 1px" importance="high" media="(min-width: 0px)" rel="preload"/>
#   <link as="image" href="https://www.justwatch.com/images/icon/127445869/s100/crunchyroll.{format}/icon.webp" imagesrcset="https://www.justwatch.com/images/icon/127445869/s100/crunchyroll.{format}/icon.webp 1px" importance="high" media="(min-width: 0px)" rel="preload"/>
#   <link as="image" href="https://www.justwatch.com/images/icon/240029443/s100/hotstar.{format}/icon.webp" imagesrcset="https://www.justwatch.com/images/icon/240029443/s100/hotstar.{format}/icon.webp 1px" importance="high" media="(min-width: 0px)" rel="preload"/>
#   <link as="image" href="https://www.justwatch.com/images/icon/312325227/s100/jiocinema.{format}/icon.webp" imagesrcset="https://www.justwatch.com/images/icon/312325227/s100/jiocinema.{format}/icon.webp 1px" importance="high" media="(min-width: 0px)" rel="preload"/>
#   <link as="image" href="https://www.justwatch.com/images/poster/316699631/s166/panchayat.webp" imagesrcset="https://www.justwatch.com/images/poster/316699631/s166/panchayat.webp 1px, https://www.justwatch.com/images/poster/316699631/s166/panchayat.webp" importance="high" rel="preload"/>
#   <link as="image" href="https://www.justwatch.com/images/poster/301444667/s166/house-of-the-dragon.webp" imagesrcset="https://www.justwatch.com/images/poster/301444667/s166/house-of-the-dragon.webp 1px, https://www.justwatch.com/images/poster/301444667/s166/house-of-the-dragon.webp" importance="high" rel="preload"/>
#   <link as="image" href="https://www.justwatch.com/images/poster/98979565/s166/mirzapur.webp" imagesrcset="https://www.justwatch.com/images/poster/98979565/s166/mirzapur.webp 1px, https://www.justwatch.com/images/poster/98979565/s166/mirzapur.webp" importance="high" rel="preload"/>
#   <link as="image" href="https://www.justwatch.com/images/poster/139452660/s166/the-boys.webp" imagesrcset="https://www.justwatch.com/images/poster/139452660/s166/the-boys.webp 1px, https://www.justwatch.com/images/poster/139452660/s166/the-boys.webp" importance="high" rel="preload"/>
#   <style data-vue-ssr-id="16dee5de:0 16dee5de:1 374c0f88:0 4d630dd0:0 166f4014:0 7c8ec326:0 2c4532b4:0 794ed965:0 f084ba36:0 389924d2:0 6dcc8ee6:0 244ddff4:0 b9b753ae:0 08ddf3ea:0 9ddc65f6:0 5e9f69f2:0 05c8a9ca:0 71268dee:0 6f4f883c:0 7d006f6e:0 6240279c:0 7bd50544:0 8fcf6830:0 25065816:0 37592880:0 d9ba2922:0 75bd5612:0 24a30aba:0 2810ebd5:0 2020975e:0 c5ab8c9a:0 b5340c7a:0 44770f63:0 3cf28c3e:0 0de9810f:0 7fbcc135:0 05def2d1:0">
#    html.ios{--ion-default-font:-apple-system,BlinkMacSystemFont,"Helvetica Neue","Roboto",sans-serif}html.md{--ion-default-font:"Roboto","Helvetica Neue",sans-serif}html{--ion-font-family:var(--ion-default-font)}body{background:var(--ion-background-color)}body.backdrop-no-scroll{overflow:hidden}html.ios ion-modal.modal-card .ion-page>ion-header>ion-toolbar:first-of-type{padding-top:0}html.ios ion-modal .ion-page{border-radius:inherit}.ion-color-primary{--ion-color-base:var(--ion-color-primary,#3880ff)!important;--ion-color-base-rgb:var(--ion-color-primary-rgb,56,128,255)!important;--ion-color-contrast:var(--ion-color-primary-contrast,#fff)!important;--ion-color-contrast-rgb:var(--ion-color-primary-contrast-rgb,255,255,255)!important;--ion-color-shade:var(--ion-color-primary-shade,#3171e0)!important;--ion-color-tint:var(--ion-color-primary-tint,#4c8dff)!important}.ion-color-secondary{--ion-color-base:var(--ion-color-secondary,#3dc2ff)!important;--ion-color-base-rgb:var(--ion-color-secondary-rgb,61,194,255)!important;--ion-color-contrast:var(--ion-color-secondary-contrast,#fff)!important;--ion-color-contrast-rgb:var(--ion-color-secondary-contrast-rgb,255,255,255)!important;--ion-color-shade:var(--ion-color-secondary-shade,#36abe0)!important;--ion-color-tint:var(--ion-color-secondary-tint,#50c8ff)!important}.ion-color-tertiary{--ion-color-base:var(--ion-color-tertiary,#5260ff)!important;--ion-color-base-rgb:var(--ion-color-tertiary-rgb,82,96,255)!important;--ion-color-contrast:var(--ion-color-tertiary-contrast,#fff)!important;--ion-color-contrast-rgb:var(--ion-color-tertiary-contrast-rgb,255,255,255)!important;--ion-color-shade:var(--ion-color-tertiary-shade,#4854e0)!important;--ion-color-tint:var(--ion-color-tertiary-tint,#6370ff)!important}.ion-color-success{--ion-color-base:var(--ion-color-success,#2dd36f)!important;--ion-color-base-rgb:var(--ion-color-success-rgb,45,211,111)!important;--ion-color-contrast:var(--ion-color-success-contrast,#fff)!important;--ion-color-contrast-rgb:var(--ion-color-success-contrast-rgb,255,255,255)!important;--ion-color-shade:var(--ion-color-success-shade,#28ba62)!important;--ion-color-tint:var(--ion-color-success-tint,#42d77d)!important}.ion-color-warning{--ion-color-base:var(--ion-color-warning,#ffc409)!important;--ion-color-base-rgb:var(--ion-color-warning-rgb,255,196,9)!important;--ion-color-contrast:var(--ion-color-warning-contrast,#000)!important;--ion-color-contrast-rgb:var(--ion-color-warning-contrast-rgb,0,0,0)!important;--ion-color-shade:var(--ion-color-warning-shade,#e0ac08)!important;--ion-color-tint:var(--ion-color-warning-tint,#ffca22)!important}.ion-color-danger{--ion-color-base:var(--ion-color-danger,#eb445a)!important;--ion-color-base-rgb:var(--ion-color-danger-rgb,235,68,90)!important;--ion-color-contrast:var(--ion-color-danger-contrast,#fff)!important;--ion-color-contrast-rgb:var(--ion-color-danger-contrast-rgb,255,255,255)!important;--ion-color-shade:var(--ion-color-danger-shade,#cf3c4f)!important;--ion-color-tint:var(--ion-color-danger-tint,#ed576b)!important}.ion-color-light{--ion-color-base:var(--ion-color-light,#f4f5f8)!important;--ion-color-base-rgb:var(--ion-color-light-rgb,244,245,248)!important;--ion-color-contrast:var(--ion-color-light-contrast,#000)!important;--ion-color-contrast-rgb:var(--ion-color-light-contrast-rgb,0,0,0)!important;--ion-color-shade:var(--ion-color-light-shade,#d7d8da)!important;--ion-color-tint:var(--ion-color-light-tint,#f5f6f9)!important}.ion-color-medium{--ion-color-base:var(--ion-color-medium,#92949c)!important;--ion-color-base-rgb:var(--ion-color-medium-rgb,146,148,156)!important;--ion-color-contrast:var(--ion-color-medium-contrast,#fff)!important;--ion-color-contrast-rgb:var(--ion-color-medium-contrast-rgb,255,255,255)!important;--ion-color-shade:var(--ion-color-medium-shade,#808289)!important;--ion-color-tint:var(--ion-color-medium-tint,#9d9fa6)!important}.ion-color-dark{--ion-color-base:var(--ion-color-dark,#222428)!important;--ion-color-b ...
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
#  */:root{--border-secondary:#657182;--border-secondary-medium:#c6c8cd;--border-primary:#fbc500;--border-radius-xs:4px;--border-radius-sm:8px;--border-radius-md:12px;--border-width-100:1px;--border-width-200:2px;--link-link-medium:#78a6b8;--text-high-default:#fff;--text-medium-default:#b9bdcc;--background-medium:#111924;--background-medium-active:#222c38}/*! Source: https://github.com/h5bp/html5-boilerplate/blob/master/src/css/main.css */@media print{*,:after,:before{color:#000!important;text-shadow:none!important;background:transparent!important;box-shadow:none!important}a,a:visited{text-decoration:underline}a[href]:after{content:" (" attr(href) ")"}abbr[title]:after{content:" (" attr(title) ")"}a[href^="#"]:after,a[href^="javascript:"]:after{content:""}blockquote,pre{border:1px solid #999;page-break-inside:avoid}thead{display:table-header-group}img,tr{page-break-inside:avoid}img{max-width:100%!important}h2,h3,p{orphans:3;widows:3}h2,h3{page-break-after:avoid}.navbar{display:none}.btn>.caret,.dropup>.btn>.caret{border-top-color:#000!important}.label{border:1px solid #000}.table{border-collapse:collapse!important}.table td,.table th{background-color:#fff!important}.table-bordered td,.table-bordered th{border:1px solid #ddd!important}}*,:after,:before{box-sizing:border-box}html{font-size:10px;-webkit-tap-highlight-color:rgba(0,0,0,0)}body{font-family:Lato,Lato-fallback,Arial,sans-serif;font-size:14px;line-height:1.428571429;color:#333;background-color:#fff}button,input,select,textarea{font-family:inherit;font-size:inherit;line-height:inherit}a{color:#428bca}a,a:focus,a:hover{text-decoration:none}a:focus,a:hover{color:#2a6496}a:focus{outline:5px auto -webkit-focus-ring-color;outline-offset:-2px}figure{margin:0}img{vertical-align:middle}.img-responsive{display:block;max-width:100%;height:auto}.img-rounded{border-radius:6px}.img-thumbnail{padding:4px;line-height:1.428571429;background-color:#fff;border:1px solid #ddd;border-radius:4px;transition:all .2s ease-in-out;display:inline-block;max-width:100%;height:auto}.img-circle{border-radius:50%}hr{margin-top:20px;margin-bottom:20px;border:0;border-top:1px solid #eee}.sr-only{position:absolute;width:1px;height:1px;padding:0;margin:-1px;overflow:hidden;clip:rect(0,0,0,0);border:0}.sr-only-focusable:active,.sr-only-focusable:focus{position:static;width:auto;height:auto;margin:0;overflow:visible;clip:auto}[role=button]{cursor:pointer}.container{padding-right:15px;padding-left:15px;margin-right:auto;margin-left:auto}.container:after,.container:before{display:table;content:" "}.container:after{clear:both}@media(min-width:768px){.container{width:750px}}@media(min-width:992px){.container{width:970px}}@media(min-width:1200px){.container{width:1170px}}.container-fluid{padding-right:15px;padding-left:15px;margin-right:auto;margin-left:auto}.container-fluid:after,.container-fluid:before{display:table;content:" "}.container-fluid:after{clear:both}.row{margin-right:-15px;margin-left:-15px}.row:after,.row:before{display:table;content:" "}.row:after{clear:both}.row-no-gutters{margin-right:0;margin-left:0}.row-no-gutters [class*=col-]{padding-right:0;padding-left:0}.col-lg-1,.col-lg-2,.col-lg-3,.col-lg-4,.col-lg-5,.col-lg-6,.col-lg-7,.col-lg-8,.col-lg-9,.col-lg-10,.col-lg-11,.col-lg-12,.col-md-1,.col-md-2,.col-md-3,.col-md-4,.col-md-5,.col-md-6,.col-md-7,.col-md-8,.col-md-9,.col-md-10,.col-md-11,.col-md-12,.col-sm-1,.col-sm-2,.col-sm-3,.col-sm-4,.col-sm-5,.col-sm-6,.col-sm-7,.col-sm-8,.col-sm-9,.col-sm-10,.col-sm-11,.col-sm-12,.col-xs-1,.col-xs-2,.col-xs-3,.col-xs-4,.col-xs-5,.col-xs-6,.col-xs-7,.col-xs-8,.col-xs-9,.col-xs-10,.col-xs-11,.col-xs-12{position:relative;min-height:1px;padding-right:15px;padding-left:15px}.col-xs-1,.col-xs-2,.col-xs-3,.col-xs-4,.col-xs-5,.col-xs-6,.col-xs-7,.col-xs-8,.col-xs-9,.col-xs-10,.col-xs-11,.col-xs-12{float:left}.col-xs-1{width:8.3333333333%}.col-xs-2{width:16.6666666667%}.col-xs-3{width:25%}.col-xs-4{width:33.3333333333%}.col-xs-5{width:41.6666666667%}.col-xs-6{wid ...
# :host,:root{--fa-font-solid:normal 900 1em/1 "Font Awesome 6 Solid";--fa-font-regular:normal 400 1em/1 "Font Awesome 6 Regular";--fa-font-light:normal 300 1em/1 "Font Awesome 6 Light";--fa-font-thin:normal 100 1em/1 "Font Awesome 6 Thin";--fa-font-duotone:normal 900 1em/1 "Font Awesome 6 Duotone";--fa-font-sharp-solid:normal 900 1em/1 "Font Awesome 6 Sharp";--fa-font-sharp-regular:normal 400 1em/1 "Font Awesome 6 Sharp";--fa-font-sharp-light:normal 300 1em/1 "Font Awesome 6 Sharp";--fa-font-brands:normal 400 1em/1 "Font Awesome 6 Brands"}svg:not(:host).svg-inline--fa,svg:not(:root).svg-inline--fa{overflow:visible;box-sizing:content-box}.svg-inline--fa{display:var(--fa-display,inline-block);height:1em;overflow:visible;vertical-align:-.125em}.svg-inline--fa.fa-2xs{vertical-align:.1em}.svg-inline--fa.fa-xs{vertical-align:0}.svg-inline--fa.fa-sm{vertical-align:-.07143em}.svg-inline--fa.fa-lg{vertical-align:-.2em}.svg-inline--fa.fa-xl{vertical-align:-.25em}.svg-inline--fa.fa-2xl{vertical-align:-.3125em}.svg-inline--fa.fa-pull-left{margin-right:var(--fa-pull-margin,.3em);width:auto}.svg-inline--fa.fa-pull-right{margin-left:var(--fa-pull-margin,.3em);width:auto}.svg-inline--fa.fa-li{width:var(--fa-li-width,2em);top:.25em}.svg-inline--fa.fa-fw{width:var(--fa-fw-width,1.25em)}.fa-layers svg.svg-inline--fa{bottom:0;left:0;margin:auto;position:absolute;right:0;top:0}.fa-layers-counter,.fa-layers-text{display:inline-block;position:absolute;text-align:center}.fa-layers{display:inline-block;height:1em;position:relative;text-align:center;vertical-align:-.125em;width:1em}.fa-layers svg.svg-inline--fa{transform-origin:center center}.fa-layers-text{left:50%;top:50%;transform:translate(-50%,-50%);transform-origin:center center}.fa-layers-counter{background-color:var(--fa-counter-background-color,#ff253a);border-radius:var(--fa-counter-border-radius,1em);box-sizing:border-box;color:var(--fa-inverse,#fff);line-height:var(--fa-counter-line-height,1);max-width:var(--fa-counter-max-width,5em);min-width:var(--fa-counter-min-width,1.5em);overflow:hidden;padding:var(--fa-counter-padding,.25em .5em);right:var(--fa-right,0);text-overflow:ellipsis;top:var(--fa-top,0);transform:scale(var(--fa-counter-scale,.25));transform-origin:top right}.fa-layers-bottom-right{bottom:var(--fa-bottom,0);right:var(--fa-right,0);top:auto;transform:scale(var(--fa-layers-scale,.25));transform-origin:bottom right}.fa-layers-bottom-left{bottom:var(--fa-bottom,0);left:var(--fa-left,0);right:auto;top:auto;transform:scale(var(--fa-layers-scale,.25));transform-origin:bottom left}.fa-layers-top-right{top:var(--fa-top,0);right:var(--fa-right,0);transform:scale(var(--fa-layers-scale,.25));transform-origin:top right}.fa-layers-top-left{left:var(--fa-left,0);right:auto;top:var(--fa-top,0);transform:scale(var(--fa-layers-scale,.25));transform-origin:top left}.fa-1x{font-size:1em}.fa-2x{font-size:2em}.fa-3x{font-size:3em}.fa-4x{font-size:4em}.fa-5x{font-size:5em}.fa-6x{font-size:6em}.fa-7x{font-size:7em}.fa-8x{font-size:8em}.fa-9x{font-size:9em}.fa-10x{font-size:10em}.fa-2xs{font-size:.625em;line-height:.1em;vertical-align:.225em}.fa-xs{font-size:.75em;line-height:.08333em;vertical-align:.125em}.fa-sm{font-size:.875em;line-height:.07143em;vertical-align:.05357em}.fa-lg{font-size:1.25em;line-height:.05em;vertical-align:-.075em}.fa-xl{font-size:1.5em;line-height:.04167em;vertical-align:-.125em}.fa-2xl{font-size:2em;line-height:.03125em;vertical-align:-.1875em}.fa-fw{text-align:center;width:1.25em}.fa-ul{list-style-type:none;margin-left:var(--fa-li-margin,2.5em);padding-left:0}.fa-ul>li{position:relative}.fa-li{left:calc(var(--fa-li-width, 2em)*-1);position:absolute;text-align:center;width:var(--fa-li-width,2em);line-height:inherit}.fa-border{border-radius:var(--fa-border-radius,.1em);border:var(--fa-border-width,.08em) var(--fa-border-style,solid) var(--fa-border-color,#eee);padding:var(--fa-border-padding,.2em .25em .15em)}.fa-pull-left{float:left;margin-right:var(--fa-pull-margin,.3em)}.fa ...
# .vue-recycle-scroller{position:relative}.vue-recycle-scroller.direction-vertical:not(.page-mode){overflow-y:auto}.vue-recycle-scroller.direction-horizontal:not(.page-mode){overflow-x:auto}.vue-recycle-scroller.direction-horizontal{display:-webkit-box;display:-ms-flexbox;display:flex}.vue-recycle-scroller__slot{-webkit-box-flex:1;-ms-flex:auto 0 0px;flex:auto 0 0}.vue-recycle-scroller__item-wrapper{-webkit-box-flex:1;-ms-flex:1;flex:1;-webkit-box-sizing:border-box;box-sizing:border-box;overflow:hidden;position:relative}.vue-recycle-scroller.ready .vue-recycle-scroller__item-view{position:absolute;top:0;left:0;will-change:transform}.vue-recycle-scroller.direction-vertical .vue-recycle-scroller__item-wrapper{width:100%}.vue-recycle-scroller.direction-horizontal .vue-recycle-scroller__item-wrapper{height:100%}.vue-recycle-scroller.ready.direction-vertical .vue-recycle-scroller__item-view{width:100%}.vue-recycle-scroller.ready.direction-horizontal .vue-recycle-scroller__item-view{height:100%}.resize-observer[data-v-b329ee4c]{border:none;background-color:transparent;opacity:0}.resize-observer[data-v-b329ee4c],.resize-observer[data-v-b329ee4c] object{position:absolute;top:0;left:0;z-index:-1;width:100%;height:100%;pointer-events:none;display:block;overflow:hidden}
# :root{--border-secondary:#657182;--border-secondary-medium:#c6c8cd;--border-primary:#fbc500;--border-radius-xs:4px;--border-radius-sm:8px;--border-radius-md:12px;--border-width-100:1px;--border-width-200:2px;--link-link-medium:#78a6b8;--text-high-default:#fff;--text-medium-default:#b9bdcc;--background-medium:#111924;--background-medium-active:#222c38}body{overflow-x:hidden}ion-menu ion-content ion-toolbar,ion-popover ion-toolbar{--background:transparent!important}#app{position:relative;z-index:0}
# :root{--border-secondary:#657182;--border-secondary-medium:#c6c8cd;--border-primary:#fbc500;--border-radius-xs:4px;--border-radius-sm:8px;--border-radius-md:12px;--border-width-100:1px;--border-width-200:2px;--link-link-medium:#78a6b8;--text-high-default:#fff;--text-medium-default:#b9bdcc;--background-medium:#111924;--background-medium-active:#222c38}.navbar__button__link__item{text-transform:capitalize}.search-overlay{position:fixed;display:block;width:100vw;height:100vh;top:0;left:0;right:0;bottom:0;background-color:rgba(0,0,0,.5);cursor:pointer}.navbar{position:sticky;display:flex;background:#060d17;height:56px;width:100%;top:0;margin:0 auto;z-index:100}@media(max-width:1050px){.navbar{max-height:105px}}.navbar__wrapper{display:flex;justify-content:flex-end;width:100%;align-items:center;overflow:visible}@media(max-width:1050px){.navbar__wrapper{justify-content:center}}.navbar.navbar-hide{display:none!important}.navbar.bg-dark-brown{background:#141100}.navbar.landing-page{background:transparent}@media(min-width:1050px){.navbar.landing-page{height:86px;padding-top:15px;margin-bottom:-86px}.navbar.landing-page .navbar__logo img{width:219px}}@media(max-width:1050px){.navbar.landing-page{margin-bottom:0}}.navbar--hidden,.navbar.landing-page .landing-hide{display:none}.navbar--absolute{position:absolute}@media(max-width:1050px){.navbar{height:105px;align-items:flex-end}}@media(max-width:1050px){.navbar.navbar__button--watchlist a{color:var(--ion-color-primary)!important}}.navbar__logo{padding-inline-end:15px;display:flex;align-items:center;flex-shrink:0}.navbar__logo img{width:131px}@media(max-width:1050px){.navbar__logo{position:absolute;top:0;width:100%;min-height:46px;display:flex;justify-content:center;align-items:center;margin:0;padding-inline-end:0}}.navbar--is-mobile .navbar__logo{justify-content:left}.navbar--is-ios .navbar__logo{height:56px}.navbar__logo-link{display:flex;align-items:center}.navbar__logo .valentine-link{font-size:24px;margin-top:2px;margin-inline-start:8px}.navbar.container .navbar__logo{margin-inline-start:0;padding-inline-start:0}.navbar__search{z-index:1;flex-grow:2;height:52px;margin:0;margin-inline-end:7px;display:flex}.navbar__search .search-suggester .searchbar-input{color:#fff;box-shadow:none;border-radius:4px;font-size:15px;padding:4px 0;padding-inline-start:50px;padding-inline-end:15px}@media(max-width:992px){.navbar__search--expanded{left:0;right:0;position:absolute}}.navbar.landing-page .navbar__search{flex-grow:0;width:35em;transition:width .6s;transition-delay:.1s;align-items:center;display:flex}.navbar.landing-page .navbar__search:focus-within{width:100%}@media(max-width:1050px){.navbar.landing-page .navbar__search:focus-within{display:flex;align-items:center;justify-content:space-around}}.navbar__extra{display:flex;min-width:92px}@media(max-width:1050px){.navbar__extra{display:none}}.navbar__extra__small{display:none}@media(max-width:1050px){.navbar__extra__small{display:block;position:absolute;top:0;width:100%}[dir=ltr] .navbar__extra__small{right:0}[dir=rtl] .navbar__extra__small{left:0}.navbar__extra__small--left{display:flex;position:absolute}[dir=ltr] .navbar__extra__small--left{left:4px}[dir=rtl] .navbar__extra__small--left{right:4px}.navbar__extra__small--right{display:flex;position:absolute}[dir=ltr] .navbar__extra__small--right{right:0}[dir=rtl] .navbar__extra__small--right{left:0}}.navbar__extra--remove-spacing{min-width:unset}.navbar__button{height:56px;flex-grow:inherit;cursor:pointer}.navbar__button a{padding:0}.navbar__button>div,.navbar__button__link{justify-content:center}.navbar__button__link{display:flex;align-items:center;height:100%;white-space:nowrap;font-size:14px;color:#999c9f}.navbar__button__link.nav-link-active,.navbar__button__link.router-link-exact-active{font-weight:700;color:#d9e8ed!important}.navbar__button__link__item{margin:0 15px;display:flex;margin-inline-end:15px}@media(max-width:1050px){.navbar__button--home .navbar__button__link__item,.navbar__button- ...
# :root{--border-secondary:#657182;--border-secondary-medium:#c6c8cd;--border-primary:#fbc500;--border-radius-xs:4px;--border-radius-sm:8px;--border-radius-md:12px;--border-width-100:1px;--border-width-200:2px;--link-link-medium:#78a6b8;--text-high-default:#fff;--text-medium-default:#b9bdcc;--background-medium:#111924;--background-medium-active:#222c38}.freemium-filter__badge{display:inline-flex;align-items:center;font-size:14px;line-height:22px;letter-spacing:.2px;font-weight:700;text-align:center;color:#fff;background:linear-gradient(-225deg,#5c6374,#3b404e 31%,#272939 68%,#191d2a);padding:2px 7px;border-radius:4px;margin-inline-start:8px}.freemium-filter__badge--sm{padding:2px 6px;font-size:12px;line-height:16px}.freemium-filter__badge svg{margin-inline-end:8px}
# :root{--border-secondary:#657182;--border-secondary-medium:#c6c8cd;--border-primary:#fbc500;--border-radius-xs:4px;--border-radius-sm:8px;--border-radius-md:12px;--border-width-100:1px;--border-width-200:2px;--link-link-medium:#78a6b8;--text-high-default:#fff;--text-medium-default:#b9bdcc;--background-medium:#111924;--background-medium-active:#222c38}.search-suggester__results{overflow:auto;border-bottom-left-radius:8px;border-bottom-right-radius:8px;max-height:90vh;max-width:100vw}.search-suggester{position:relative}.search-suggester .sponsored-recommendation-search{margin-top:-10px;z-index:1000;position:relative;display:flex;width:100%}.search-suggester input[type=search]::-webkit-search-cancel-button{display:none}.search-suggester__results{z-index:200;padding:0 8px 8px;margin:-9px 0 0}.search-suggester__results--mobile{padding:0;margin:-11px -1em -.4em}.search-suggester--web{text-align:start;width:100%;padding:0;height:52px;z-index:10}.search-suggester--web ion-searchbar.ios{--background:#10161d;padding:8px;height:52px}.search-suggester--web .searchbar-cancel-button.sc-ion-searchbar-ios{background:#10161d;padding-inline-end:8px}.search-suggester__searchbar--mobile{padding-top:3px!important;padding-bottom:10px!important}.search-suggester__searchbar--mobile.md{height:52px;--background:#fff;--color:var(--ion-color-tertiary-shade)!important}.search-suggester__searchbar--mobile.md .searchbar-input{border-radius:4px!important}.search-suggester__searchbar input::-webkit-search-cancel-button{-webkit-appearance:none}.search-suggester__searchbar .searchbar-clear-icon{color:var(--ion-color-secondary)!important}.search-suggester__blocking{position:absolute;width:100%;padding:8px}.search-suggester__blocking__input{width:100%;height:38px;display:flex;align-items:center;background-color:var(--ion-color-tertiary-shade)}.searchbar-clear-button.sc-ion-searchbar-md{color:#fff!important}
# [data-v-6aa447f4]:root{--border-secondary:#657182;--border-secondary-medium:#c6c8cd;--border-primary:#fbc500;--border-radius-xs:4px;--border-radius-sm:8px;--border-radius-md:12px;--border-width-100:1px;--border-width-200:2px;--link-link-medium:#78a6b8;--text-high-default:#fff;--text-medium-default:#b9bdcc;--background-medium:#111924;--background-medium-active:#222c38}.logged-in[data-v-6aa447f4]{padding:0 15px;color:var(--ion-color-primary);font-size:18px}.logged-in[data-v-6aa447f4],.not-logged-in[data-v-6aa447f4]{height:100%;display:flex;align-items:center}@media(max-width:1050px){.not-logged-in__button[data-v-6aa447f4]{display:none}}.not-logged-in__icon[data-v-6aa447f4]{display:none;font-size:16px;cursor:pointer}@media(max-width:1050px){.not-logged-in__icon[data-v-6aa447f4]{display:block}}@media(max-width:1050px){.not-logged-in[data-v-6aa447f4]{padding:0 15px}}
# :root{--border-secondary:#657182;--border-secondary-medium:#c6c8cd;--border-primary:#fbc500;--border-radius-xs:4px;--border-radius-sm:8px;--border-radius-md:12px;--border-width-100:1px;--border-width-200:2px;--link-link-medium:#78a6b8;--text-high-default:#fff;--text-medium-default:#b9bdcc;--background-medium:#111924;--background-medium-active:#222c38}.basic-button{background:none;border:none;margin:0;padding:0;outline:none;white-space:nowrap;cursor:pointer}.basic-button__content{overflow:hidden;text-overflow:ellipsis;display:flex;align-items:center;justify-content:center}.basic-button.sm{font-size:13px;padding:.4rem 1.35rem}.basic-button.md{padding:.75rem 1.5rem}.basic-button.lg{font-size:18px;padding:1.6rem 4rem}.basic-button.lg.rounded{border-radius:8px}.basic-button.w-full{width:100%}.basic-button.rounded{border-radius:4px}.basic-button.uppercase{text-transform:uppercase}.basic-button.primary{font-weight:700;background-color:#fbc500;color:#000}.basic-button.primary.bg-none{color:#fbc500}.basic-button.primary.bg-none:hover{background-color:rgba(251,197,0,.1)}.basic-button.primary.border{color:#fbcb1a;border:1px solid #fbcb1a}.basic-button.primary.border:hover{background-color:rgba(251,197,0,.1)}.basic-button.primary:hover{background-color:#ddad00}.basic-button.secondary{color:#fff;font-weight:700;background-color:#4c5a67}.basic-button.secondary.bg-none{color:#4c5a67}.basic-button.secondary.bg-none:hover{background-color:rgba(94,107,118,.1)}.basic-button.secondary.border{border:1px solid #5e6b76}.basic-button.secondary.border:hover{background-color:rgba(94,107,118,.1)}.basic-button.secondary:hover{background-color:#ddad00}.basic-button.tertiary{color:#fff;background-color:#1c252f}.basic-button.tertiary.bg-none{color:#1c252f}.basic-button.tertiary.bg-none:hover{background-color:rgba(94,107,118,.1)}.basic-button.tertiary.border{border:1px solid #383d47}.basic-button.tertiary.border:hover{background-color:rgba(56,61,71,.1)}.basic-button.tertiary:hover{background-color:#383d47}.basic-button.light{color:#d9e8ed;background-color:#1c252f}.basic-button.light:hover{background-color:#383d47}.basic-button.medium{color:#fff;background-color:#8c8c8c}.basic-button.medium.border{color:#999c9f;border:1px solid #999c9f}.basic-button.medium.border:hover{background-color:rgba(153,156,159,.1)}.basic-button.medium:hover{background-color:#999c9f}.basic-button.bg-none{background:transparent}.basic-button.disabled{cursor:default;opacity:.5;pointer-events:none}
# .navbar__button__link[data-v-701c8f36]{background:none;border:none;outline:none;cursor:pointer}
# .login-menu-button__button[data-v-4dfb297b]{all:unset;display:flex;align-items:center;height:100%;padding:0 15px;font-size:16px}.login-menu-button__button--logged-in[data-v-4dfb297b]{color:var(--ion-color-primary)}
# [data-v-64e4e508]:root{--border-secondary:#657182;--border-secondary-medium:#c6c8cd;--border-primary:#fbc500;--border-radius-xs:4px;--border-radius-sm:8px;--border-radius-md:12px;--border-width-100:1px;--border-width-200:2px;--link-link-medium:#78a6b8;--text-high-default:#fff;--text-medium-default:#b9bdcc;--background-medium:#111924;--background-medium-active:#222c38}html[data-v-64e4e508]{scroll-padding-top:56px}@media screen and (max-width:1050px){html[data-v-64e4e508]{scroll-padding-top:105px}}.popular-page__spinner[data-v-64e4e508]{width:100%;height:100vh;display:flex;align-items:center;justify-content:center}.overlay-blocking-element[data-v-64e4e508]{position:absolute;height:100vh;width:100vw}.content-provider-content[data-v-64e4e508]{position:relative;width:100vw}.content-provider-content h1.section-title[data-v-64e4e508]{font-size:32px}@media(max-width:599px){.content-provider-content .content-header[data-v-64e4e508]{max-height:178px}.content-provider-content .content-header.content-header--expanded[data-v-64e4e508]{max-height:none}}.content-provider-content.font-style-2 .section-title[data-v-64e4e508]{font-family:Anton,Impact;letter-spacing:.64px!important;font-weight:400!important}.catalog-title[data-v-64e4e508]{display:flex;align-items:center;justify-content:flex-start;width:100%}@media(max-width:1050px){.catalog-title h2[data-v-64e4e508]{margin-inline-start:15px}}.show-filters[data-v-64e4e508]{margin:0 15px}@media(max-width:599px){.show-filters__text[data-v-64e4e508]{display:none}}.sponsored-recommendation[data-v-64e4e508]{grid-area:double-poster;height:100%}@media(max-width:540px){.sponsored-recommendation[data-v-64e4e508]{height:270px}}.list-options[data-v-64e4e508]{width:100%;display:flex;flex-direction:column;align-items:flex-start;justify-content:center;margin-bottom:16px}.filter-bar[data-v-64e4e508]{margin-top:24px}#catalog-jumplink[data-v-64e4e508]{position:relative;top:-50px}@media(max-width:1050px){#catalog-jumplink[data-v-64e4e508]{top:-90px}}
# [data-v-d7672432]:root{--border-secondary:#657182;--border-secondary-medium:#c6c8cd;--border-primary:#fbc500;--border-radius-xs:4px;--border-radius-sm:8px;--border-radius-md:12px;--border-width-100:1px;--border-width-200:2px;--link-link-medium:#78a6b8;--text-high-default:#fff;--text-medium-default:#b9bdcc;--background-medium:#111924;--background-medium-active:#222c38}.content[data-v-d7672432]{min-height:100vh;display:flex;flex-direction:column;--padding-top:56px}@media(max-width:1050px){.content[data-v-d7672432]{--padding-top:105px}}
# :root{--border-secondary:#657182;--border-secondary-medium:#c6c8cd;--border-primary:#fbc500;--border-radius-xs:4px;--border-radius-sm:8px;--border-radius-md:12px;--border-width-100:1px;--border-width-200:2px;--link-link-medium:#78a6b8;--text-high-default:#fff;--text-medium-default:#b9bdcc;--background-medium:#111924;--background-medium-active:#222c38}.toggle-filters{display:flex;align-items:center;margin:10px}.toggle-filters__label{margin-inline-end:5px}.toggle-filters.border.bg-none{color:#d5d5d5}.content-container{display:flex;align-items:center;position:relative}.center-banner{display:flex;justify-content:center}.display-none{display:none}.content-header{min-height:120px;max-height:120px;overflow:hidden;position:relative;width:100%}@media(max-width:1050px){.content-header{padding-left:15px;padding-right:15px}}.content-header:hover{cursor:pointer}.content-header--expanded{max-height:none}.content-header--no-text{min-height:70px}.content-header--gradient{position:absolute;bottom:0;width:100%;text-align:center;margin:0;padding:15px 0;background-image:linear-gradient(180deg,rgba(6,13,23,0),var(--ion-background-color))}[dir=ltr] .content-header--gradient{left:0}[dir=rtl] .content-header--gradient{right:0}.content-header h1{padding-inline-end:15px}.content-header__search-heading{flex-grow:1;display:flex;align-items:center}@media(max-width:1050px){.content-header__search-heading{padding-left:15px;padding-right:15px}}.content-header__search-heading h1{font-size:24px;line-height:32px;font-weight:700;color:#d9e8ed}@media(max-width:767px){.content-header__search-heading h1{font-size:16px;line-height:24px}}.content-header__search-heading div{font-size:15px;padding:10px 0 5px}.content-header__caret{position:absolute;top:18px}[dir=ltr] .content-header__caret{right:0}[dir=rtl] .content-header__caret{left:0}@media(max-width:1050px){[dir=ltr] .content-header__caret{right:20px}[dir=rtl] .content-header__caret{left:20px}}
# :root{--border-secondary:#657182;--border-secondary-medium:#c6c8cd;--border-primary:#fbc500;--border-radius-xs:4px;--border-radius-sm:8px;--border-radius-md:12px;--border-width-100:1px;--border-width-200:2px;--link-link-medium:#78a6b8;--text-high-default:#fff;--text-medium-default:#b9bdcc;--background-medium:#111924;--background-medium-active:#222c38}.popover__filter{--ion-background-color:#10161d}.popover__filter .popover-content{width:400px}.filter-bar-seo{background-color:rgba(6,13,23,.8);background:linear-gradient(180deg,#060d17,rgba(6,13,23,.85));-webkit-backdrop-filter:blur(20px);backdrop-filter:blur(20px);position:relative;width:100%;z-index:10;transition:transform .3s ease-out}@media(max-width:1050px){.filter-bar-seo .row-filter-bar{margin:0 15px}}.filter-bar-seo__reset{margin-inline-start:auto}.filter-bar-seo__popover{transform:translateY(50px)}@media(min-width:992px){.filter-bar-seo__filter-button{display:none!important}}@media(max-width:992px){.filter-bar-seo__filter-button{display:block}}.filter-bar-seo__additional{position:relative;padding-bottom:10px;display:flex;align-items:baseline;justify-content:flex-start}.filter-bar-seo__additional>div:not(:last-child){margin-inline-end:10px}.filter-bar-seo__additional__heading{white-space:nowrap;color:var(--ion-color-secondary);text-transform:uppercase;font-weight:700}.filter-bar-seo__additional .jw-chip-button{margin-bottom:0}.filter-bar-seo__additional .hidden-horizontal-scrollbar__items{margin:0!important;bottom:0!important}.filter-bar-seo__additional--long:not(:last-child){margin-inline-end:4px}@media(max-width:992px){.filter-bar-seo__additional--long{display:none!important}.filter-bar-seo__additional--long.always-active{display:block!important}}.filter-bar-seo a{transition:opacity .2s ease;cursor:pointer}.filter-bar-seo--inactive a{opacity:.4}.filter-bar-seo--hidden{transform:translateY(-180px)}.scrollbar div{padding-left:0!important}
# :root{--border-secondary:#657182;--border-secondary-medium:#c6c8cd;--border-primary:#fbc500;--border-radius-xs:4px;--border-radius-sm:8px;--border-radius-md:12px;--border-width-100:1px;--border-width-200:2px;--link-link-medium:#78a6b8;--text-high-default:#fff;--text-medium-default:#b9bdcc;--background-medium:#111924;--background-medium-active:#222c38}.filter-bar-container{display:flex;align-items:center}.filter-bar-seo__provider-row{margin-bottom:5px}@media(max-width:767px){.filter-bar-seo__provider-row{margin-left:0!important}.filter-bar-seo__provider-row .hidden-horizontal-scrollbar__items{padding-left:0!important}}.filter-bar-seo__provider-icon{display:inline-block;width:50px;height:50px;opacity:.25;margin:10px 5px;transition:opacity .2s ease-in-out;cursor:pointer}.filter-bar-seo__provider-icon button{all:unset}.filter-bar-seo__provider-icon img{width:100%}.filter-bar-seo__provider-icon:first-child{margin-inline-start:0}.filter-bar-seo__provider-icon.active{opacity:1}.filter-bar-seo__provider-icon.disabled{opacity:.25;filter:grayscale(100%);pointer-events:none}
# :root{--border-secondary:#657182;--border-secondary-medium:#c6c8cd;--border-primary:#fbc500;--border-radius-xs:4px;--border-radius-sm:8px;--border-radius-md:12px;--border-width-100:1px;--border-width-200:2px;--link-link-medium:#78a6b8;--text-high-default:#fff;--text-medium-default:#b9bdcc;--background-medium:#111924;--background-medium-active:#222c38}.provider-icon,.provider-icon img{border-radius:20%}.provider-icon--labelled{overflow:hidden;height:100%;display:flex;justify-content:center;align-items:center;font-size:1.2rem}.provider-icon--labelled.timeline__provider-block__logo{font-size:.7rem}.provider-icon .ribbon{position:absolute;top:6px;right:-10px;width:100%;text-align:center;background-color:#d5d5d5;color:#1c252f;font-size:9px;font-weight:700;padding:0 4px;border-radius:0 0 0 5px;z-index:1;transform:rotate(45deg)}
# ...
#          <li class="jw-app-footer__link" data-v-7c31ac2a="">
#           <a data-v-7c31ac2a="" href="/in/tv-show/sausage-party-foodtopia/season-1">
#            Sausage Party: Foodtopia Season 1
#           </a>
#          </li>
#          <li class="jw-app-footer__link" data-v-7c31ac2a="">
#           <a data-v-7c31ac2a="" href="/in/tv-show/vikings-valhalla/season-3">
#            Vikings: Valhalla Season 3
#           </a>
#          </li>
#          <li class="jw-app-footer__link" data-v-7c31ac2a="">
#           <a data-v-7c31ac2a="" href="/in/tv-show/me/season-1">
#            Me Season 1
#           </a>
#          </li>
#         </ul>
#        </div>
#        <div data-v-7c31ac2a="">
#         <h5 data-v-7c31ac2a="">
#          <a data-v-7c31ac2a="" href="/in/guide">
#           Top 5 latest news
#          </a>
#         </h5>
#         <ul class="list-unstyled top-articles" data-v-7c31ac2a="">
#          <li class="jw-app-footer__link" data-v-7c31ac2a="">
#           <a data-v-7c31ac2a="" href="/in/guide/movies-like-james-bond">
#            10 Best Movies to Watch If You Love James Bond (and Where to Stream Them)
#           </a>
#          </li>
#          <li class="jw-app-footer__link" data-v-7c31ac2a="">
#           <a data-v-7c31ac2a="" href="/in/guide/the-boys-in-order">
#            How to Watch The Boys in Order - A Complete Streaming Guide
#           </a>
#          </li>
#          <li class="jw-app-footer__link" data-v-7c31ac2a="">
#           <a data-v-7c31ac2a="" href="/in/guide/shows-like-stranger-things">
#            10 Best Shows to Watch If You Like Stranger Things and Where to Stream Them
#           </a>
#          </li>
#          <li class="jw-app-footer__link" data-v-7c31ac2a="">
#           <a data-v-7c31ac2a="" href="/in/guide/shows-like-bridgerton">
#            10 Shows to Watch If You Loved Bridgerton and Where to Stream Them
#           </a>
#          </li>
#          <li class="jw-app-footer__link" data-v-7c31ac2a="">
#           <a data-v-7c31ac2a="" href="/in/guide/game-of-thrones-in-order">
#            How to Watch Game of Thrones In Order: A Complete Streaming Guide
#           </a>
#          </li>
#         </ul>
#        </div>
#       </div>
#      </footer>
#      <!-- -->
#     </div>
#    </div>
#    <style>
#     null
#    </style>
#    <div>
#     <!-- -->
#     <!-- -->
#     <!-- -->
#     <!-- -->
#     <!-- -->
#     <!-- -->
#    </div>
#   </div>
#   <script data-vue-ssr-data="">
#    window.__DATA__={"state":{"app":{"geoLocation":"us","seoUser":true,"jwSession":null,"jwSessionExpires":null},"constant":{"providers":[{"clearName":"Netflix","hasSport":false,"hasTitles":true,"icon":"\u002Ficon\u002F207360008\u002F{profile}\u002Fnetflix.{format}","monetizationTypes":["FLATRATE"],"packageId":8,"selected":false,"shortName":"nfx","slug":"netflix","technicalName":"netflix"},{"clearName":"Amazon Prime Video","hasSport":true,"hasTitles":true,"icon":"\u002Ficon\u002F52449861\u002F{profile}\u002Famazonprimevideo.{format}","monetizationTypes":["FLATRATE"],"packageId":119,"selected":false,"shortName":"prv","slug":"amazon-prime-video","technicalName":"amazonprimevideo"},{"clearName":"Apple TV Plus","hasSport":true,"hasTitles":true,"icon":"\u002Ficon\u002F152862153\u002F{profile}\u002Fappletvplus.{format}","monetizationTypes":["FLATRATE"],"packageId":350,"selected":false,"shortName":"atp","slug":"apple-tv-plus","technicalName":"appletvplus"},{"clearName":"Apple TV","hasSport":true,"hasTitles":true,"icon":"\u002Ficon\u002F190848813\u002F{profile}\u002Fitunes.{format}","monetizationTypes":["BUY","RENT"],"packageId":2,"selected":false,"shortName":"itu","slug":"apple-tv","technicalName":"itunes"},{"clearName":"Crunchyroll","hasSport":false,"hasTitles":true,"icon":"\u002Ficon\u002F127445869\u002F{profile}\u002Fcrunchyroll.{format}","monetizationTypes":["ADS","FLATRATE"],"packageId":283,"selected":false,"shortName":"cru","slug":"crunchyroll","technicalName":"crunchyroll"},{"clearName":"Hotstar","hasSport":true,"hasTitles":true,"icon":"\u002Ficon\u002F240029443\u002F{profile}\u002Fhotstar.{format}","monetizationTypes":["FLATRATE"],"packageId":122,"selected":false,"shortName":"hst","slug":"hotstar","technicalName":"hotstar"},{"clearName":"Jio Cinema","hasSport":true,"hasTitles":true,"icon":"\u002Ficon\u002F312325227\u002F{profile}\u002Fjiocinema.{format}","monetizationTypes":["FLATRATE"],"packageId":220,"selected":false,"shortName":"jio","slug":"jio-cinema","technicalName":"jiocinema"},{"clearName":"Zee5","hasSport":false,"hasTitles":true,"icon":"\u002Ficon\u002F93795879\u002F{profile}\u002Fzee5.{format}","monetizationTypes":["ADS","FLATRATE","FREE"],"packageId":232,"selected":false,"shortName":"zee","slug":"zee5","technicalName":"zee5"},{"clearName":"Eros Now","hasSport":false,"hasTitles":true,"icon":"\u002Ficon\u002F247912837\u002F{profile}\u002Ferosnow.{format}","monetizationTypes":["FLATRATE"],"packageId":218,"selected":false,"shortName":"ern","slug":"eros-now","technicalName":"erosnow"},{"clearName":"MLS Season Pass","hasSport":true,"hasTitles":false,"icon":"\u002Ficon\u002F303372959\u002F{profile}\u002Fmlsseasonpass.{format}","monetizationTypes":["FLATRATE"],"packageId":1851,"selected":false,"shortName":"mls","slug":"mls-season-pass","technicalName":"mlsseasonpass"},{"clearName":"Google Play Movies","hasSport":false,"hasTitles":true,"icon":"\u002Ficon\u002F169478387\u002F{profile}\u002Fplay.{format}","monetizationTypes":["BUY","RENT"],"packageId":3,"selected":false,"shortName":"ply","slug":"google-play-movies","technicalName":"play"},{"clearName":"MUBI","hasSport":false,"hasTitles":true,"icon":"\u002Ficon\u002F164970114\u002F{profile}\u002Fmubi.{format}","monetizationTypes":["FLATRATE","RENT"],"packageId":11,"selected":false,"shortName":"mbi","slug":"mubi","technicalName":"mubi"},{"clearName":"Sony Liv","hasSport":true,"hasTitles":true,"icon":"\u002Ficon\u002F207468084\u002F{profile}\u002Fsonyliv.{format}","monetizationTypes":["ADS","FLATRATE"],"packageId":237,"selected":false,"shortName":"snl","slug":"sony-liv","technicalName":"sonyliv"},{"clearName":"YouTube","hasSport":true,"hasTitles":true,"icon":"\u002Ficon\u002F59562423\u002F{profile}\u002Fyoutube.{format}","monetizationTypes":["BUY","FLATRATE","RENT"],"packageId":192,"selected":false,"shortName":"yot","slug":"youtube","technicalName":"youtube"},{"clearName":"GuideDoc","hasSport":false,"hasTitles":true,"icon":"\u002Ficon\u002F2625277\u002F{profile}\u002Fguidedoc.{fo ...
#   </script>
#   <script>
#    window.__APOLLO_STATE__={"defaultClient":{"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).0":{"organization":"CBFC","__typename":"AgeCertification"},"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).1":{"organization":"CBFC","__typename":"AgeCertification"},"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).2":{"organization":"CBFC","__typename":"AgeCertification"},"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).3":{"organization":"CBFC","__typename":"AgeCertification"},"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).4":{"organization":"CBFC","__typename":"AgeCertification"},"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).5":{"organization":"CBFC","__typename":"AgeCertification"},"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).6":{"organization":"CBFC","__typename":"AgeCertification"},"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).7":{"organization":"CBFC","__typename":"AgeCertification"},"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).8":{"organization":"CBFC","__typename":"AgeCertification"},"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).9":{"organization":"CBFC","__typename":"AgeCertification"},"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).10":{"organization":"CBFC","__typename":"AgeCertification"},"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).11":{"organization":"CBFC","__typename":"AgeCertification"},"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).12":{"organization":"CBFC","__typename":"AgeCertification"},"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).13":{"organization":"CBFC","__typename":"AgeCertification"},"ROOT_QUERY":{"ageCertifications({\"country\":\"IN\"})":[{"type":"id","generated":true,"id":"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).0","typename":"AgeCertification"},{"type":"id","generated":true,"id":"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).1","typename":"AgeCertification"},{"type":"id","generated":true,"id":"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).2","typename":"AgeCertification"},{"type":"id","generated":true,"id":"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).3","typename":"AgeCertification"},{"type":"id","generated":true,"id":"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).4","typename":"AgeCertification"},{"type":"id","generated":true,"id":"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).5","typename":"AgeCertification"},{"type":"id","generated":true,"id":"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).6","typename":"AgeCertification"},{"type":"id","generated":true,"id":"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).7","typename":"AgeCertification"},{"type":"id","generated":true,"id":"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).8","typename":"AgeCertification"},{"type":"id","generated":true,"id":"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).9","typename":"AgeCertification"},{"type":"id","generated":true,"id":"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).10","typename":"AgeCertification"},{"type":"id","generated":true,"id":"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).11","typename":"AgeCertification"},{"type":"id","generated":true,"id":"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).12","typename":"AgeCertification"},{"type":"id","generated":true,"id":"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).13","typename":"AgeCertification"}],"ageCertifications({\"country\":\"IN\",\"objectType\":\"MOVIE\"})":[{"type":"id","generated":false,"id":"AgeCertification:27","typename":"AgeCertification"},{"type":"id","generated":false,"id":"AgeCertification:28","typename":"AgeCertification"},{"type":"id","generated":false,"id":"AgeCertification:29","typename":"AgeCertification"},{"type":"id","generated":false,"id":"AgeCertification:21388","typename":"AgeCertification"},{"type":"id","generated":false,"id":"AgeCertification:21405","typename":"AgeCertification"},{"type":"id","generated":false,"id":"AgeCertification:21427","typename":"AgeCertification"},{"type":"id","generated":false ...
#   </script>
#   <script>
#    // Runtime Env Vars
# 			window.DNS_PREFETCH=[{"rel":"dns-prefetch","href":"https://www.googletagmanager.com/"},{"rel":"dns-prefetch","href":"https://ib.adnxs.com"}];
# 			window.HTTP_PRECONNECT=[{"rel":"preconnect","crossorigin":"use-credentials","href":"https://images.justwatch.com"}];
# 			window.BUILD_CONFIG={"appVersion":"3.8.2","commitHash":"8685668d6a54ffbeb5c7cfa5957a6e2d2b8eb641","commitShortHash":"8685668","env":"prod","globals":{"ASSETS_DIR":"appassets","BUILD_TARGET":"SSR","IS_BUILD":true,"IS_SERVE":false,"IS_START":false,"IS_DEV":true,"IS_PROD":false}};
# 			window.JW_CONFIG={"API":"https://apis.justwatch.com/content","ASSETS_URL":"https://www.justwatch.com/static/compile_jw/assets","BRAZE_BASE_URL":"sdk.iad-05.braze.com","BRAZE_WEB_API_KEY":"1aad19f0-6f9f-4fd5-9a05-9ca5499795f9","CHECKIP_URL":"https://info.justwatch.com ","CLICK_URL":"https://click.justwatch.com","DISCOVERY_URL":"https://apis.justwatch.com/discovery","DOMAIN":"justwatch.com","EVENT_URL":"https://apis.justwatch.com/event","EXPERIMENT_CONFIG_URL":"https://apis.justwatch.com/configuration/experiments","FACEBOOK_APP_ID":"794243977319785","FEEDBACK_URL":"https://apis.justwatch.com/feedback","FIREBASE_API_KEY":"AIzaSyDv6JIzdDvbTBS-JWdR4Kl22UvgWGAyuo8","FIREBASE_APP_ID":"1:413470318987:web:28b910bbf217d7d5034f8e","FIREBASE_AUTH_DOMAIN":"accounts.justwatch.com","FIREBASE_MESSAGING_SENDER_ID":"413470318987","FIREBASE_PROJECT_ID":"justwatch-apps-beta","FIREBASE_STORAGE_BUCKET":"justwatch-apps-beta.appspot.com","GEOLOCATION_URL":"https://geo.justwatch.com","GOOGLE_CLIENT_ID":"532718895899-fhbuhnd9nsrae0ivadejq35vsr2sgr0l.apps.googleusercontent.com","GOOGLE_MAPS_API_KEY":"AIzaSyBVU86Zuf3v_6W8dnnV9BRKe_YSBXroqCA","GRAPHQL_URL":"https://apis.justwatch.com/graphql","GRAPHQL_INTERNAL_URL":"https://apis.justwatch.com/graphql","IDENTITY_URL":"https://apis.justwatch.com/identity","ID_URL":"https://i.tw.cx","IMAGESCALER_FAST_URL":"https://www.justwatch.com/images","IMAGESCALER_URL":"https://images.justwatch.com","JOBSITE_URL":"https://www.justwatch.com/talent/jobs","ITUNES_APP_ID":"979227482","NOTIFICATION_URL":"https://apis.justwatch.com/notification","PLOT_RECOMMENDER_URL":"https://apis.justwatch.com/plotpoint","REVENUE_CAT_API_URL":"https://api.revenuecat.com/v1","REVENUE_CAT_PUBLIC_KEY":"sijZLciaBRrTwuIAeBkAqzQNtMNQaXqV","SENTRY_DSN":"https://ad6b9c4b3a3f4e998e38c3c7ed92574f@sentry.justwatch.com/4","SENTRY_DSN_SSR_CLIENT":"https://e83b625f73464fe9af5aea210630233c@sentry.justwatch.com/9","SNOWPLOW_COLLECTOR_ENDPOINT":"sp.justwatch.com","USER_URL":"https://userapi.justwatch.com","WRITE_URL":"https://apis.justwatch.com/personalization","AD_TAG":"https://pubads.g.doubleclick.net/gampad/ads?iu=/21679119891/video_ads_trailers&description_url=https%3A%2F%2Fwww.justwatch.com%2F&tfcd=0&npa=0&sz=640x360%7C640x480&gdfp_req=1&output=vast&unviewed_position_start=1&env=vp&impl=s&correlator=&vad_type=linear","ZENDESK_SUBDOMAIN":"https://justwatch.zendesk.com","SUBSCRIPTIONS":{"regular":{"id":"prod_LKEY8MLBOZwwQN","priceId":"price_1Kda5MKD0TTmBHo0KnyileCK","type":"regular","timeframe":"monthly","price":2.49},"yearly":{"id":"prod_NzlZqI8lGP1soA","priceId":"price_1NDm2ZKD0TTmBHo0u99J14yr","type":"yearly","timeframe":"yearly","price":19.99},"monthly":{"id":"prod_NzlSDe5AXBSi4X","priceId":"price_1NDlvNKD0TTmBHo08pBWfjIZ","type":"monthly","timeframe":"monthly","price":3.99},"onetime":{"id":"prod_NzlbbPqyeBPsT8","priceId":"price_1NDm4CKD0TTmBHo0KnsX1AJw","type":"onetime","timeframe":"one time","price":59.99}}};
# 			window.IMG_POSTER_LOAD_COUNT=4;
# 			window.IMG_PROVIDERS_BAR_LOAD_COUNT=7;
# 			window.IMG_PROVIDERS_BUY_BOX_COUNT=6;
# 			window.IMG_NEW_TIMELINE_ROWS=1;
# 			window.IS_CANARY=false;
# 			window.NEW_TIMELINE_BUCKETS_LIMIT=4;
# 			window.NEW_TIMELINE_TITLES_PER_BUCKET_LIMIT=10;
# 			window.VUE_APP_TESTS_E2E=false;
#   </script>
#   <script defer="" src="/appassets/js/1720172319512_runtime.fc003d17.js">
#   </script>
#   <script defer="" src="/appassets/js/1720172319512_popular.e82ba5a3.js">
#   </script>
#   <script defer="" src="/appassets/js/1720172319512_chunk-5d4c672f.169e0d5f.js">
#   </script>
#   <script defer="" src="/appassets/js/1720172319512_title-list-grid.8f93decf.js">
#   </script>
#   <script defer="" src="/appassets/js/1720172319512_chunk-e3426c90.6548c84e.js">
#   </script>
#   <script defer="" src="/appassets/js/1720172319512_chunk-52c4f6ae.f1d5b608.js">
#   </script>
#   <script defer="" src="/appassets/js/1720172319512_default-footer.a4b9182a.js">
#   </script>
#   <script defer="" src="/appassets/js/1720172319512_low-priority-components.51993da0.js">
#   </script>
#   <script defer="" src="/appassets/js/1720172319512_npm.vue.53092bae.js">
#   </script>
#   <script defer="" src="/appassets/js/1720172319512_npm.firebase.3638ea87.js">
#   </script>
#   <script defer="" src="/appassets/js/1720172319512_npm.vueuse.b7d15e12.js">
#   </script>
#   <script defer="" src="/appassets/js/1720172319512_npm.sentry.911ad572.js">
#   </script>
#   <script defer="" src="/appassets/js/1720172319512_npm.sentry-internal.e001ff88.js">
#   </script>
#   <script defer="" src="/appassets/js/1720172319512_npm.graphql.f600a27c.js">
#   </script>
#   <script defer="" src="/appassets/js/1720172319512_npm.fortawesome.5e2b0570.js">
#   </script>
#   <script defer="" src="/appassets/js/1720172319512_npm.apollo-client.25b9e10b.js">
#   </script>
#   <script defer="" src="/appassets/js/1720172319512_npm.vue-router.3d04e099.js">
#   </script>
#   <script defer="" src="/appassets/js/1720172319512_npm.localforage.67c908d6.js">
#   </script>
#   <script defer="" src="/appassets/js/1720172319512_app.b9050618.js">
#   </script>
#  </body>
# </html>

# %% [markdown]
# ## **Fetching Tv shows Url details**

# %%
# Write Your Code here
tv_urls = []
for x in soup.find_all('a',attrs={'class':'title-list-grid__item--link'}):
  tv_urls.append('https://www.justwatch.com'+x['href'])
print(tv_urls)
print(len(tv_urls))
# Out:
# ['https://www.justwatch.com/in/tv-show/panchayat', 'https://www.justwatch.com/in/tv-show/house-of-the-dragon', 'https://www.justwatch.com/in/tv-show/mirzapur', 'https://www.justwatch.com/in/tv-show/the-boys', 'https://www.justwatch.com/in/tv-show/gullak', 'https://www.justwatch.com/in/tv-show/kota-factory', 'https://www.justwatch.com/in/tv-show/bridgerton', 'https://www.justwatch.com/in/tv-show/game-of-thrones', 'https://www.justwatch.com/in/tv-show/demon-slayer-kimetsu-no-yaiba', 'https://www.justwatch.com/in/tv-show/raising-voices', 'https://www.justwatch.com/in/tv-show/shogun-2024', 'https://www.justwatch.com/in/tv-show/heeramandi', 'https://www.justwatch.com/in/tv-show/the-bear', 'https://www.justwatch.com/in/tv-show/dark-matter-2024', 'https://www.justwatch.com/in/tv-show/apharan', 'https://www.justwatch.com/in/tv-show/aashram', 'https://www.justwatch.com/in/tv-show/the-good-doctor', 'https://www.justwatch.com/in/tv-show/the-acolyte', 'https://www.justwatch.com/in/tv-show/sunflower-2021', 'https://www.justwatch.com/in/tv-show/attack-on-titan', 'https://www.justwatch.com/in/tv-show/presumed-innocent', 'https://www.justwatch.com/in/tv-show/fargo', 'https://www.justwatch.com/in/tv-show/fallout', 'https://www.justwatch.com/in/tv-show/farzi', 'https://www.justwatch.com/in/tv-show/3-body-problem', 'https://www.justwatch.com/in/tv-show/from', 'https://www.justwatch.com/in/tv-show/supacell', 'https://www.justwatch.com/in/tv-show/maxton-hall-the-world-between-us', 'https://www.justwatch.com/in/tv-show/jamnapaar', 'https://www.justwatch.com/in/tv-show/bigg-boss-ott', 'https://www.justwatch.com/in/tv-show/paperhouse', 'https://www.justwatch.com/in/tv-show/breaking-bad', 'https://www.justwatch.com/in/tv-show/stranger-things', 'https://www.justwatch.com/in/tv-show/the-family-man', 'https://www.justwatch.com/in/tv-show/asur', 'https://www.justwatch.com/in/tv-show/mastram', 'https://www.justwatch.com/in/tv-show/tulsa-king', 'https://www.justwatch.com/in/tv-show/the-legend-of-hanuman', 'https://www.justwatch.com/in/tv-show/peaky-blinders', 'https://www.justwatch.com/in/tv-show/true-detective', 'https://www.justwatch.com/in/tv-show/joko-anwars-nightmares-and-daydreams', 'https://www.justwatch.com/in/tv-show/my-demon', 'https://www.justwatch.com/in/tv-show/the-orville', 'https://www.justwatch.com/in/tv-show/mtv-splitsvilla', 'https://www.justwatch.com/in/tv-show/anne-rices-mayfair-witches', 'https://www.justwatch.com/in/tv-show/dehati-ladke', 'https://www.justwatch.com/in/tv-show/jujutsu-kaisen', 'https://www.justwatch.com/in/tv-show/the-rookie', 'https://www.justwatch.com/in/tv-show/untitled-kapil-sharma-netflix-project', 'https://www.justwatch.com/in/tv-show/kaiju-no-8', 'https://www.justwatch.com/in/tv-show/lost', 'https://www.justwatch.com/in/tv-show/resident-alien', 'https://www.justwatch.com/in/tv-show/sweet-tooth', 'https://www.justwatch.com/in/tv-show/bigg-boss', 'https://www.justwatch.com/in/tv-show/dark', 'https://www.justwatch.com/in/tv-show/eric', 'https://www.justwatch.com/in/tv-show/jack-reacher', 'https://www.justwatch.com/in/tv-show/into-the-dark', 'https://www.justwatch.com/in/tv-show/modern-family', 'https://www.justwatch.com/in/tv-show/young-sheldon', 'https://www.justwatch.com/in/tv-show/naruto', 'https://www.justwatch.com/in/tv-show/lucifer', 'https://www.justwatch.com/in/tv-show/x-x-x-uncensored', 'https://www.justwatch.com/in/tv-show/murder-in-mahim', 'https://www.justwatch.com/in/tv-show/gandii-baat', 'https://www.justwatch.com/in/tv-show/sarkaar', 'https://www.justwatch.com/in/tv-show/suits', 'https://www.justwatch.com/in/tv-show/naruto-shippuden', 'https://www.justwatch.com/in/tv-show/agents-of-mystery', 'https://www.justwatch.com/in/tv-show/the-last-of-us', 'https://www.justwatch.com/in/tv-show/hitler-and-the-nazis-evil-on-trial', 'https://www.justwatch.com/in/tv-show/euphoria', 'https://www.justwatch.com/in/tv-show/spartacus', 'https://www.justwatch.com/in/tv-show/yellowstone', 'https://www.justwatch.com/in/tv-s ...
# 100

# %% [markdown]
# ## **Fetching Tv Show Title details**

# %%
# Write Your Code here
tv_title = []
for url in tv_urls:
  try:
    headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36',
    'Accept-Language': 'en-US,en;q=0.9',
    'Accept-Encoding': 'gzip, deflate, br',
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
}
    data = requests.get(url, headers = headers)
    soup = BeautifulSoup(data.text,'html.parser')
    title = soup.find_all('div',attrs={'class':'title-detail-hero__details'})[0].find_all('h1')[0].text
  except:
    title = "NA"
  tv_title.append(title)

print(tv_title)
print(len(tv_title))
# Out:
# [' Panchayat (2020)', ' House of the Dragon (2022)', ' Mirzapur (2018)', ' The Boys (2019)', ' Gullak (2019)', ' Kota Factory (2019)', ' Bridgerton (2020)', ' Game of Thrones (2011)', ' Demon Slayer: Kimetsu no Yaiba (2019)', ' Raising Voices (2024)', ' Shōgun (2024)', ' Heeramandi: The Diamond Bazaar (2024)', ' The Bear (2022)', ' Dark Matter (2024)', ' Apharan (2018)', ' Aashram (2020)', ' The Good Doctor (2017)', ' The Acolyte (2024)', ' Sunflower (2021)', ' Attack on Titan (2013)', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', ' Maxton Hall: The World Between Us (2024)', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', ' Mastram (2020)', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', ' The Great Indian Kapil Show (2024)', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', ' Naruto Shippūden (2007)', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', ' Hidden Love (2023)', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', ' One-Punch Man (2015)', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']
# 100

# %% [markdown]
# ## **Fetching Release Year**

# %%
# Tv Shows Release year

tv_release_years_list = []

for url in tv_urls:
    try:
        headers = {
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36',
            'Accept-Language': 'en-US,en;q=0.9',
            'Accept-Encoding': 'gzip, deflate, br',
            'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
        }

        response = requests.get(url, headers=headers)

        # Check if request was successful
        if response.status_code == 200:
            soup = BeautifulSoup(response.text, 'html.parser')

            # Extract release year
            release_element = soup.find('span', class_='release-year')

            if release_element:
                release_year = release_element.text.strip()
            else:
                release_year = "NA"  #  release year not found

        else:
            release_year = "NA"  # If request was not successful

    except Exception as e:
        print(f"Error processing {url}: {e}")
        release_year = "NA"  # If any exception occurs

    tv_release_years_list.append(release_year)




# Print release years
print(tv_release_years_list)
print(len(tv_release_years_list))
# Out:
# ['(2020)', '(2022)', '(2018)', '(2019)', '(2019)', '(2019)', '(2020)', '(2011)', '(2019)', '(2024)', '(2024)', '(2024)', '(2022)', '(2024)', '(2018)', '(2020)', '(2017)', '(2024)', '(2021)', '(2013)', '(2024)', '(2014)', '(2024)', '(2023)', '(2024)', '(2022)', '(2024)', '(2024)', '(2024)', '(2021)', '(2017)', '(2008)', '(2016)', '(2019)', '(2020)', '(2020)', '(2022)', '(2021)', '(2013)', '(2014)', '(2024)', '(2023)', '(2017)', '(2008)', '(2023)', '(2023)', '(2020)', '(2018)', '(2024)', 'NA', 'NA', 'NA', 'NA', 'NA', '(2017)', 'NA', 'NA', 'NA', 'NA', 'NA', '(2002)', 'NA', '(2018)', 'NA', 'NA', 'NA', 'NA', '(2007)', 'NA', 'NA', 'NA', '(2019)', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', '(2018)', 'NA', '(2020)', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', '(2009)', 'NA']
# 100

# %% [markdown]
# ## Convert Release year into string

# %%
tv_release_years = []
# Function to extract year from string
def extract_year(year_str):
    if not isinstance(year_str, str):
        return None
    match = re.search(r'\((\d{4})\)', year_str)
    return match.group(1) if match else 'NA'

# Append release years as strings to the list
for year in tv_release_years_list:
    release_year = extract_year(year)
    tv_release_years.append(str(release_year))

# Print the result
print(tv_release_years)
# Out:
# ['2020', '2022', '2018', '2019', '2019', '2019', '2020', '2011', '2019', '2024', '2024', '2024', '2022', '2024', '2018', '2020', '2017', '2024', '2021', '2013', '2024', '2014', '2024', '2023', '2024', '2022', '2024', '2024', '2024', '2021', '2017', '2008', '2016', '2019', '2020', '2020', '2022', '2021', '2013', '2014', '2024', '2023', '2017', '2008', '2023', '2023', '2020', '2018', '2024', 'NA', 'NA', 'NA', 'NA', 'NA', '2017', 'NA', 'NA', 'NA', 'NA', 'NA', '2002', 'NA', '2018', 'NA', 'NA', 'NA', 'NA', '2007', 'NA', 'NA', 'NA', '2019', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', '2018', 'NA', '2020', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', '2009', 'NA']

# %% [markdown]
# ## **Fetching TV Show Genre Details**

# %%
# Write Your Code here
tv_genre_list = []

for url in tv_urls:
    try:
        headers = {
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36',
            'Accept-Language': 'en-US,en;q=0.9',
            'Accept-Encoding': 'gzip, deflate, br',
            'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
        }

        response = requests.get(url, headers=headers)

        # Check if request was successful
        if response.status_code == 200:
            soup = BeautifulSoup(response.text, 'html.parser')

            # Extract genres
            genres = []
            h3_element = soup.find('h3', class_='detail-infos__subheading', string='Genres')
            if h3_element:
                div_element = h3_element.find_next_sibling('div', class_='detail-infos__value')
                if div_element:
                    genres = [genre.strip() for genre in div_element.text.split(',')]
                else:
                    genres = ["Genre Not Listed"]
            else:
                genres = ["Genre Not Listed"]

        else:
            genres = ["NA"]  # If request was not successful

    except Exception as e:
        print(f"Error processing {url}: {e}")
        genres = ["NA"]  # If any exception occurs

    tv_genre_list.append(genres)

# Print the scraped genres
print(tv_genre_list)
print(len(tv_genre_list))
# Out:
# [['Drama', 'Comedy'], ['Drama', 'Fantasy', 'Romance', 'Action & Adventure', 'Science-Fiction'], ['NA'], ['NA'], ['Comedy', 'Drama', 'Kids & Family'], ['Comedy', 'Drama'], ['NA'], ['NA'], ['Animation', 'Action & Adventure', 'Fantasy', 'Mystery & Thriller'], ['Drama'], ['NA'], ['NA'], ['NA'], ['NA'], ['NA'], ['NA'], ['NA'], ['NA'], ['NA'], ['NA'], ['NA'], ['NA'], ['NA'], ['Crime', 'Drama', 'Mystery & Thriller'], ['Science-Fiction', 'Drama', 'Fantasy'], ['NA'], ['NA'], ['Drama', 'Romance'], ['NA'], ['NA'], ['NA'], ['NA'], ['NA'], ['NA'], ['Drama', 'Mystery & Thriller', 'Crime'], ['Drama', 'Comedy', 'Fantasy'], ['NA'], ['NA'], ['NA'], ['NA'], ['NA'], ['NA'], ['NA'], ['NA'], ['NA'], ['NA'], ['Animation', 'Action & Adventure', 'Fantasy', 'Mystery & Thriller', 'Science-Fiction'], ['NA'], ['NA'], ['NA'], ['NA'], ['NA'], ['NA'], ['Reality TV', 'Kids & Family'], ['NA'], ['NA'], ['NA'], ['NA'], ['NA'], ['NA'], ['NA'], ['NA'], ['NA'], ['NA'], ['NA'], ['Reality TV'], ['Comedy', 'Drama'], ['NA'], ['NA'], ['NA'], ['NA'], ['NA'], ['NA'], ['NA'], ['NA'], ['NA'], ['NA'], ['NA'], ['NA'], ['NA'], ['NA'], ['NA'], ['Science-Fiction', 'Mystery & Thriller', 'Action & Adventure', 'Drama'], ['Mystery & Thriller', 'Drama'], ['NA'], ['NA'], ['Drama', 'Action & Adventure', 'Crime', 'Science-Fiction', 'Mystery & Thriller'], ['NA'], ['NA'], ['NA'], ['NA'], ['NA'], ['NA'], ['NA'], ['NA'], ['NA'], ['NA'], ['NA'], ['NA'], ['NA']]
# 100

# %% [markdown]
# ## **Fetching IMDB Rating Details**

# %%
# Write Your Code here
tv_imdb_list = []

for url in tv_urls:
    try:
        headers = {
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36',
            'Accept-Language': 'en-US,en;q=0.9',
            'Accept-Encoding': 'gzip, deflate, br',
            'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
        }

        response_g = requests.get(url, headers=headers)
        soup = BeautifulSoup(response_g.text, 'html.parser')

        # Selecting only those h3 whose heading is Rating
        h3_element = soup.find('h3', class_='detail-infos__subheading', string='Rating')

        if h3_element:
            # Check if the next sibling is a div with class "detail-infos__value"
            div_element = h3_element.find_next_sibling('div', class_='detail-infos__value')

            if div_element:
                inside_div = div_element.find_all('div', class_='jw-scoring-listing__rating')

                # Check if inside_div is non-empty
                if inside_div:
                    inside_div_last = inside_div[-1] #

                    # Check if inside_div_last is non-empty
                    if inside_div_last:
                        span_all = inside_div_last.find_all('span')

                        # Check if span_all is non-empty
                        if span_all:
                            span_last = span_all[-1] # Here we are extracting rating from the last span(span_last) inside last div(inside_div_last) of main div_element(div_element)
                            tv_imdb_list.append(span_last.text.strip())
                        else:
                            tv_imdb_list.append("Imdb Rating Not Listed.")
                    else:
                        tv_imdb_list.append("Imdb Rating Not Listed.")
                else:
                    tv_imdb_list.append("Imdb Rating Not Listed.")
            else:
                tv_imdb_list.append("Imdb Rating Not Listed.")
        else:
            tv_imdb_list.append("Imdb Rating Not Listed.")

    except Exception as e:
        print(f"Error processing {url}: {e}")
        tv_imdb_list.append("Imdb Rating Not Listed.")

# Print theIMDb ratings
print(tv_imdb_list)
print(len(tv_imdb_list))
# Out:
# ['Imdb Rating Not Listed.', 'Imdb Rating Not Listed.', '8.5  (83k)', '8.7  (680k)', '9.1  (23k)', '9.0  (83k)', '7.4  (186k)', 'Imdb Rating Not Listed.', '8.6  (155k)', '7.2  (3k)', 'Imdb Rating Not Listed.', 'Imdb Rating Not Listed.', 'Imdb Rating Not Listed.', 'Imdb Rating Not Listed.', 'Imdb Rating Not Listed.', '7.4  (32k)', 'Imdb Rating Not Listed.', '3.5  (77k)', 'Imdb Rating Not Listed.', 'Imdb Rating Not Listed.', 'Imdb Rating Not Listed.', 'Imdb Rating Not Listed.', 'Imdb Rating Not Listed.', 'Imdb Rating Not Listed.', 'Imdb Rating Not Listed.', 'Imdb Rating Not Listed.', 'Imdb Rating Not Listed.', '7.6  (10k)', 'Imdb Rating Not Listed.', 'Imdb Rating Not Listed.', 'Imdb Rating Not Listed.', 'Imdb Rating Not Listed.', 'Imdb Rating Not Listed.', '8.7  (99k)', 'Imdb Rating Not Listed.', '6.9  (2k)', '8.0  (72k)', 'Imdb Rating Not Listed.', 'Imdb Rating Not Listed.', '8.9  (662k)', 'Imdb Rating Not Listed.', 'Imdb Rating Not Listed.', 'Imdb Rating Not Listed.', 'Imdb Rating Not Listed.', 'Imdb Rating Not Listed.', 'Imdb Rating Not Listed.', 'Imdb Rating Not Listed.', '8.0  (76k)', 'Imdb Rating Not Listed.', 'Imdb Rating Not Listed.', 'Imdb Rating Not Listed.', 'Imdb Rating Not Listed.', '7.7  (71k)', '3.7  (4k)', 'Imdb Rating Not Listed.', 'Imdb Rating Not Listed.', 'Imdb Rating Not Listed.', 'Imdb Rating Not Listed.', 'Imdb Rating Not Listed.', 'Imdb Rating Not Listed.', 'Imdb Rating Not Listed.', 'Imdb Rating Not Listed.', 'Imdb Rating Not Listed.', 'Imdb Rating Not Listed.', 'Imdb Rating Not Listed.', 'Imdb Rating Not Listed.', 'Imdb Rating Not Listed.', '8.7  (174k)', 'Imdb Rating Not Listed.', 'Imdb Rating Not Listed.', 'Imdb Rating Not Listed.', '8.3  (247k)', '8.5  (258k)', 'Imdb Rating Not Listed.', 'Imdb Rating Not Listed.', 'Imdb Rating Not Listed.', 'Imdb Rating Not Listed.', 'Imdb Rating Not Listed.', 'Imdb Rating Not Listed.', 'Imdb Rating Not Listed.', 'Imdb Rating Not Listed.', 'Imdb Rating Not Listed.', 'Imdb Rating Not Listed.', 'Imdb Rating Not Listed.', 'Imdb Rating Not Listed.', 'Imdb Rating Not Listed.', 'Imdb Rating Not Listed.', 'Imdb Rating Not Listed.', 'Imdb Rating Not Listed.', 'Imdb Rating Not Listed.', 'Imdb Rating Not Listed.', 'Imdb Rating Not Listed.', '7.9  (30k)', '7.1  (59k)', 'Imdb Rating Not Listed.', 'Imdb Rating Not Listed.', 'Imdb Rating Not Listed.', 'Imdb Rating Not Listed.', 'Imdb Rating Not Listed.', 'Imdb Rating Not Listed.']
# 100

# %% [markdown]
# ### IMDB Rating

# %%
# Function to extract the first value
def extract_first_value(imdb_rating):
    match = re.match(r"(\d+(\.\d+)?)", imdb_rating)
    return match.group(1) if match else None

# Extracted ratings
Tv_imdb_ratings = [extract_first_value(rating) for rating in tv_imdb_list]

# Print the extracted ratings
print(Tv_imdb_ratings)

# Print the length of the extracted ratings list
print(len(Tv_imdb_ratings))
# Out:
# [None, None, '8.5', '8.7', '9.1', '9.0', '7.4', None, '8.6', '7.2', None, None, None, None, None, '7.4', None, '3.5', None, None, None, None, None, None, None, None, None, '7.6', None, None, None, None, None, '8.7', None, '6.9', '8.0', None, None, '8.9', None, None, None, None, None, None, None, '8.0', None, None, None, None, '7.7', '3.7', None, None, None, None, None, None, None, None, None, None, None, None, None, '8.7', None, None, None, '8.3', '8.5', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, '7.9', '7.1', None, None, None, None, None, None]
# 100

# %% [markdown]
# ### Number of Reviews

# %%
# Function to extract the second value
def extract_second_value(imdb_rating):
    match = re.search(r"\((\d+[kKmM]?)\)", imdb_rating)
    return match.group(1) if match else 'NA'

# Extracted second values
tv_reviews = [extract_second_value(rating) for rating in tv_imdb_list]

# Print the extracted second values
print(tv_reviews)

# Print the length of the extracted second values list
print(len(tv_reviews))
# Out:
# ['NA', 'NA', '83k', '680k', '23k', '83k', '186k', 'NA', '155k', '3k', 'NA', 'NA', 'NA', 'NA', 'NA', '32k', 'NA', '77k', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', '10k', 'NA', 'NA', 'NA', 'NA', 'NA', '99k', 'NA', '2k', '72k', 'NA', 'NA', '662k', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', '76k', 'NA', 'NA', 'NA', 'NA', '71k', '4k', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', '174k', 'NA', 'NA', 'NA', '247k', '258k', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', '30k', '59k', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']
# 100

# %% [markdown]
# ## **Fetching Age Rating Details**

# %%
# Write Your Code here
tv_age_rating_list = []# List to store all movie age rating

# For every movie title present in movies_title_list , Finding their Age Rating
for url in tv_urls:
    headers = {
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36',
            'Accept-Language': 'en-US,en;q=0.9',
            'Accept-Encoding': 'gzip, deflate, br',
            'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
        }

    response_g = requests.get(url, headers=headers)

    soup = BeautifulSoup(response_g.text,'html.parser')

    # Selecting only those h3 whose heading is Age rating
    h3_element = soup.find('h3', class_='detail-infos__subheading', string='Age rating')

    if h3_element:
        # Check if the next sibling is a div with class "detail-infos__value"
        div_element = h3_element.find_next_sibling('div', class_='detail-infos__value')

        if div_element:
            tv_age_rating_list.append(div_element.text.strip())
        else:
            tv_age_rating_list.append("Age Rating Not Listed.")
    else:
         tv_age_rating_list.append("Age Rating Not Listed.")

print(tv_age_rating_list)
print(len(tv_age_rating_list))
# Out:
# ['Age Rating Not Listed.', 'A', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'A', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'A', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'U', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'A', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.']
# 100

# %% [markdown]
# ## **Fetching Production Country details**

# %%
# Fetching Production Country details tv

tv_production_country_list = []

for url in tv_urls:
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36',
        'Accept-Language': 'en-US,en;q=0.9',
        'Accept-Encoding': 'gzip, deflate, br',
        'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
    }

    response_g = requests.get(url, headers=headers)
    soup = BeautifulSoup(response_g.text, 'html.parser')

    # Selecting only those h3 whose sub-heading inside details- infos is 'Production Country'
    h3_element = soup.find('h3', class_='detail-infos__subheading', string=' Production country ')

    if h3_element:
        # Check if the next sibling is a div with class "detail-infos__value"
        div_element = h3_element.find_next_sibling('div', class_='detail-infos__value')

        if div_element:
            tv_production_country_list.append(div_element.text.strip())
        else:
            tv_production_country_list.append("Production Country Not Listed")
    else:
        tv_production_country_list.append("Production Country Not Listed")

print(tv_production_country_list)
print(len(tv_production_country_list))
# Out:
# ['Production Country Not Listed', 'Production Country Not Listed', 'India', 'United States', 'India', 'India', 'Production Country Not Listed', 'Production Country Not Listed', 'Japan', 'Spain', 'United States', 'India', 'Production Country Not Listed', 'Production Country Not Listed', 'Production Country Not Listed', 'India', 'Production Country Not Listed', 'United States', 'Production Country Not Listed', 'Production Country Not Listed', 'Production Country Not Listed', 'Production Country Not Listed', 'Production Country Not Listed', 'Production Country Not Listed', 'Production Country Not Listed', 'Production Country Not Listed', 'Production Country Not Listed', 'Production Country Not Listed', 'India', 'Production Country Not Listed', 'Production Country Not Listed', 'Production Country Not Listed', 'Production Country Not Listed', 'India', 'India', 'India', 'Production Country Not Listed', 'Production Country Not Listed', 'Production Country Not Listed', 'United States', 'Production Country Not Listed', 'Production Country Not Listed', 'Production Country Not Listed', 'Production Country Not Listed', 'Production Country Not Listed', 'Production Country Not Listed', 'Production Country Not Listed', 'Production Country Not Listed', 'India', 'Japan', 'Production Country Not Listed', 'Production Country Not Listed', 'Production Country Not Listed', 'Production Country Not Listed', 'Germany', 'Production Country Not Listed', 'Production Country Not Listed', 'Production Country Not Listed', 'Production Country Not Listed', 'Production Country Not Listed', 'Production Country Not Listed', 'Production Country Not Listed', 'Production Country Not Listed', 'Production Country Not Listed', 'India', 'India', 'Production Country Not Listed', 'Japan', 'Production Country Not Listed', 'Production Country Not Listed', 'Production Country Not Listed', 'Production Country Not Listed', 'Production Country Not Listed', 'Production Country Not Listed', 'Production Country Not Listed', 'Production Country Not Listed', 'Production Country Not Listed', 'Production Country Not Listed', 'Production Country Not Listed', 'Production Country Not Listed', 'Production Country Not Listed', 'Production Country Not Listed', 'Production Country Not Listed', 'Production Country Not Listed', 'Production Country Not Listed', 'India', 'United States', 'Production Country Not Listed', 'Production Country Not Listed', 'Production Country Not Listed', 'Production Country Not Listed', 'Production Country Not Listed', 'United States', 'Production Country Not Listed', 'Production Country Not Listed', 'Production Country Not Listed', 'Production Country Not Listed', 'Production Country Not Listed', 'Production Country Not Listed', 'Production Country Not Listed']
# 100

# %% [markdown]
# ## **Fetching Streaming Service details**

# %%
# Write Your Code here
tv_streaming_list=[]# List to store all movie streaming platform

# For every movie title present in movies_title_list , Finding their Streaming Platform
for url in tv_urls:

    headers = {
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36',
            'Accept-Language': 'en-US,en;q=0.9',
            'Accept-Encoding': 'gzip, deflate, br',
            'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
        }

    response_g = requests.get(url, headers=headers)
    soup = BeautifulSoup(response_g.text,'html.parser')

    # Finding the outer div element with the class "buybox-row stream"
    outer_div = soup.find('div', class_='buybox-row promoted stream')

    if outer_div:
        # Finding the nested div with class "buybox-row__offers" inside the outer div
        inner_div = outer_div.find('div', class_='buybox-row__offers')

        if inner_div:
            # Find the picture element within the nested div
            picture_element = inner_div.find('picture')

            if picture_element:
                # Extract the alt attribute from the img element inside the picture which contains streaming platform name
                img_element = picture_element.find('img')
                if img_element:
                    alt_text = img_element['alt']
                    tv_streaming_list.append(alt_text)
                else:
                    tv_streaming_list.append("NA.")
            else:
                tv_streaming_list.append("NA")
        else:
            tv_streaming_list.append("NA")
    else:
        tv_streaming_list.append("NA")

print(tv_streaming_list)
print(len(tv_streaming_list))
# Out:
# ['NA', 'NA', 'Amazon Prime Video', 'Amazon Prime Video', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']
# 100

# %% [markdown]
# ## **Fetching Duration Details**

# %%
# Write Your Code here
tv_runtime_list=[]

# For every movie title present in movies_title_list
for url in tv_urls:

    headers = {
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36',
            'Accept-Language': 'en-US,en;q=0.9',
            'Accept-Encoding': 'gzip, deflate, br',
            'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
        }

    response_g = requests.get(url, headers=headers)
    soup = BeautifulSoup(response_g.text,'html.parser')

    # Selecting only those h3 whose heading is runtine
    h3_element = soup.find('h3', class_='detail-infos__subheading', string='Runtime')

    if h3_element:
        # Check if the next sibling is a div with class "detail-infos__value"
        div_element = h3_element.find_next_sibling('div', class_='detail-infos__value')

        if div_element:
            tv_runtime_list.append(div_element.text.strip())
        else:
            tv_runtime_list.append("No Runtime/Duration mentioned")
    else:
      tv_runtime_list.append("No Runtime/Duration mentioned")

print(tv_runtime_list)
print(len(tv_runtime_list))
# Out:
# ['No Runtime/Duration mentioned', '59min', '50min', 'No Runtime/Duration mentioned', '30min', 'No Runtime/Duration mentioned', '1h 2min', 'No Runtime/Duration mentioned', '26min', 'No Runtime/Duration mentioned', '59min', 'No Runtime/Duration mentioned', 'No Runtime/Duration mentioned', '52min', 'No Runtime/Duration mentioned', '43min', 'No Runtime/Duration mentioned', '36min', 'No Runtime/Duration mentioned', 'No Runtime/Duration mentioned', 'No Runtime/Duration mentioned', 'No Runtime/Duration mentioned', 'No Runtime/Duration mentioned', 'No Runtime/Duration mentioned', 'No Runtime/Duration mentioned', 'No Runtime/Duration mentioned', 'No Runtime/Duration mentioned', '45min', 'No Runtime/Duration mentioned', 'No Runtime/Duration mentioned', 'No Runtime/Duration mentioned', 'No Runtime/Duration mentioned', '1h 1min', 'No Runtime/Duration mentioned', '47min', '28min', '38min', 'No Runtime/Duration mentioned', 'No Runtime/Duration mentioned', 'No Runtime/Duration mentioned', 'No Runtime/Duration mentioned', 'No Runtime/Duration mentioned', 'No Runtime/Duration mentioned', 'No Runtime/Duration mentioned', 'No Runtime/Duration mentioned', 'No Runtime/Duration mentioned', 'No Runtime/Duration mentioned', 'No Runtime/Duration mentioned', '55min', 'No Runtime/Duration mentioned', 'No Runtime/Duration mentioned', 'No Runtime/Duration mentioned', '50min', '1h 16min', 'No Runtime/Duration mentioned', 'No Runtime/Duration mentioned', 'No Runtime/Duration mentioned', 'No Runtime/Duration mentioned', 'No Runtime/Duration mentioned', 'No Runtime/Duration mentioned', 'No Runtime/Duration mentioned', 'No Runtime/Duration mentioned', 'No Runtime/Duration mentioned', 'No Runtime/Duration mentioned', '44min', '52min', '44min', '24min', 'No Runtime/Duration mentioned', 'No Runtime/Duration mentioned', 'No Runtime/Duration mentioned', '58min', '54min', 'No Runtime/Duration mentioned', 'No Runtime/Duration mentioned', 'No Runtime/Duration mentioned', 'No Runtime/Duration mentioned', 'No Runtime/Duration mentioned', 'No Runtime/Duration mentioned', 'No Runtime/Duration mentioned', 'No Runtime/Duration mentioned', 'No Runtime/Duration mentioned', 'No Runtime/Duration mentioned', 'No Runtime/Duration mentioned', 'No Runtime/Duration mentioned', 'No Runtime/Duration mentioned', 'No Runtime/Duration mentioned', 'No Runtime/Duration mentioned', 'No Runtime/Duration mentioned', 'No Runtime/Duration mentioned', 'No Runtime/Duration mentioned', '23min', '51min', 'No Runtime/Duration mentioned', 'No Runtime/Duration mentioned', 'No Runtime/Duration mentioned', 'No Runtime/Duration mentioned', 'No Runtime/Duration mentioned', 'No Runtime/Duration mentioned', 'No Runtime/Duration mentioned']
# 100

# %% [markdown]
# ## **Creating TV Show DataFrame**

# %%
# Write Your Code here
data_tv  = {
    'TV Show Title':tv_title,
    'IMDB Rating':Tv_imdb_ratings,
    'Number of Reviews':tv_reviews,
    'Release Year': tv_release_years,
    'Genre':tv_genre_list,
    'Runtime/Duration':tv_runtime_list,
    'Age Rating':tv_age_rating_list,
    'Production Country':tv_production_country_list,
    'Streaming Platform':tv_streaming_list,
    'URL':tv_urls
}

# %%
df_tv = pd.DataFrame(data_tv)
df_tv.head(10)
# Out:
#                             TV Show Title IMDB Rating Number of Reviews  \
# 0                        Panchayat (2020)        None                NA
# 1              House of the Dragon (2022)        None                NA
# 2                         Mirzapur (2018)         8.5               83k
# 3                         The Boys (2019)         8.7              680k
# 4                           Gullak (2019)         9.1               23k
# 5                     Kota Factory (2019)         9.0               83k
# 6                       Bridgerton (2020)         7.4              186k
# 7                  Game of Thrones (2011)        None                NA
# 8   Demon Slayer: Kimetsu no Yaiba (2019)         8.6              155k
# 9                   Raising Voices (2024)         7.2                3k
#
#   Release Year                                              Genre  \
# 0         2020                                    [Drama, Comedy]
# 1         2022  [Drama, Fantasy, Romance, Action & Adventure, ...
# 2         2018                                               [NA]
# 3         2019                                               [NA]
# 4         2019                     [Comedy, Drama, Kids & Family]
# 5         2019                                    [Comedy, Drama]
# 6         2020                                               [NA]
# 7         2011                                               [NA]
# 8         2019  [Animation, Action & Adventure, Fantasy, Myste...
# 9         2024                                            [Drama]
#
#                 Runtime/Duration              Age Rating  \
# 0  No Runtime/Duration mentioned  Age Rating Not Listed.
# 1                          59min                       A
# 2                          50min  Age Rating Not Listed.
# 3  No Runtime/Duration mentioned  Age Rating Not Listed.
# 4                          30min  Age Rating Not Listed.
# 5  No Runtime/Duration mentioned  Age Rating Not Listed.
# 6                        1h 2min                       A
# 7  No Runtime/Duration mentioned  Age Rating Not Listed.
# 8                          26min  Age Rating Not Listed.
# 9  No Runtime/Duration mentioned  Age Rating Not Listed.
#
#               Production Country  Streaming Platform  \
# 0  Production Country Not Listed                  NA
# 1  Production Country Not Listed                  NA
# 2                          India  Amazon Prime Video
# 3                  United States  Amazon Prime Video
# 4                          India                  NA
# 5                          India                  NA
# 6  Production Country Not Listed                  NA
# 7  Production Country Not Listed                  NA
# 8                          Japan                  NA
# 9                          Spain                  NA
#
#                                                  URL
# 0     https://www.justwatch.com/in/tv-show/panchayat
# 1  https://www.justwatch.com/in/tv-show/house-of-...
# 2      https://www.justwatch.com/in/tv-show/mirzapur
# 3      https://www.justwatch.com/in/tv-show/the-boys
# 4        https://www.justwatch.com/in/tv-show/gullak
# 5  https://www.justwatch.com/in/tv-show/kota-factory
# 6    https://www.justwatch.com/in/tv-show/bridgerton
# 7  https://www.justwatch.com/in/tv-show/game-of-t...
# 8  https://www.justwatch.com/in/tv-show/demon-sla...
# 9  https://www.justwatch.com/in/tv-show/raising-v...

# %% [markdown]
# ## **Task 2 :- Data Filtering & Analysis**

# %%
import datetime
import re

current_date = datetime.datetime.now()

# Calculate the year two years ago
two_years_ago = current_date.year - 2



# Convert IMDB Rating to float
df_movies['IMDB Rating'] = pd.to_numeric(df_movies['IMDB Rating'], errors='coerce')
df_tv['IMDB Rating'] = pd.to_numeric(df_tv['IMDB Rating'], errors='coerce')

# Filter the dataframe
filtered_df_movies = df_movies[(df_movies['Release Year'] >= str(two_years_ago)) & (df_movies['IMDB Rating'] >= 7)]# Filter for movies
filtered_df_tv_shows = df_tv[(df_tv['Release Year'] >= str(two_years_ago)) & (df_tv['IMDB Rating'] >= 7)]  # Filter for TV shows

# %%
filtered_df_movies.head(10)
# Out:
#                    Movie Title  IMDB Rating Number of Reviews Release Year  \
# 0              Aavesham (2024)          8.0               13k         2024
# 1                Munjya (2024)          7.2               14k         2024
# 2         Kalki 2898 AD (2024)          8.0               28k         2024
# 4    Godzilla Minus One (2023)          7.7              129k         2023
# 7          The Fall Guy (2024)          7.0              113k         2024
# 8        Manjummel Boys (2024)          8.3               17k         2024
# 10      Laapataa Ladies (2024)          8.5               34k         2024
# 12              Maidaan (2024)          8.1               16k         2024
# 19              Premalu (2024)          7.9               12k         2024
# 21          Oppenheimer (2023)          8.3              762k         2023
#
#                                                 Genre  \
# 0                                                [NA]
# 1                                    [Comedy, Horror]
# 2   [Fantasy, Science-Fiction, Drama, Action & Adv...
# 4   [Horror, Drama, Science-Fiction, Action & Adve...
# 7                                                [NA]
# 8                         [Drama, Mystery & Thriller]
# 10                                               [NA]
# 12                                               [NA]
# 19                                               [NA]
# 21                                   [Drama, History]
#
#                  Runtime/Duration              Age Rating  \
# 0                        2h 38min  Age Rating Not Listed.
# 1                         2h 3min  Age Rating Not Listed.
# 2   No Runtime/Duration mentioned  Age Rating Not Listed.
# 4                         2h 5min  Age Rating Not Listed.
# 7   No Runtime/Duration mentioned                      UA
# 8                        2h 15min                      UA
# 10                        2h 2min                      UA
# 12  No Runtime/Duration mentioned  Age Rating Not Listed.
# 19  No Runtime/Duration mentioned                       U
# 21                        3h 0min  Age Rating Not Listed.
#
#                Production Country            Streaming Platform  \
# 0   Production Country Not Listed  Not Available for Streaming.
# 1   Production Country Not Listed  Not Available for Streaming.
# 2   Production Country Not Listed  Not Available for Streaming.
# 4   Production Country Not Listed  Not Available for Streaming.
# 7                   United States  Not Available for Streaming.
# 8   Production Country Not Listed  Not Available for Streaming.
# 10  Production Country Not Listed  Not Available for Streaming.
# 12  Production Country Not Listed  Not Available for Streaming.
# 19  Production Country Not Listed  Not Available for Streaming.
# 21  Production Country Not Listed  Not Available for Streaming.
#
#                                                   URL
# 0    https://www.justwatch.com/in/movie/aavesham-2024
# 1           https://www.justwatch.com/in/movie/munjha
# 2        https://www.justwatch.com/in/movie/project-k
# 4   https://www.justwatch.com/in/movie/godzilla-mi...
# 7     https://www.justwatch.com/in/movie/the-fall-guy
# 8   https://www.justwatch.com/in/movie/manjummel-boys
# 10  https://www.justwatch.com/in/movie/laapataa-la...
# 12         https://www.justwatch.com/in/movie/maidaan
# 19         https://www.justwatch.com/in/movie/premalu
# 21     https://www.justwatch.com/in/movie/oppenheimer

# %%
filtered_df_tv_shows.head(10)
# Out:
#                                 TV Show Title  IMDB Rating Number of Reviews  \
# 9                       Raising Voices (2024)          7.2                3k
# 27   Maxton Hall: The World Between Us (2024)          7.6               10k
# 36                                         NA          8.0               72k
# 52                                         NA          7.7               71k
# 72                                         NA          8.5              258k
# 92                                         NA          7.9               30k
# 93                                         NA          7.1               59k
#
#    Release Year             Genre               Runtime/Duration  \
# 9          2024           [Drama]  No Runtime/Duration mentioned
# 27         2024  [Drama, Romance]                          45min
# 36         2022              [NA]                          38min
# 52           NA              [NA]                          50min
# 72           NA              [NA]                          54min
# 92           NA              [NA]                          51min
# 93           NA              [NA]  No Runtime/Duration mentioned
#
#                 Age Rating             Production Country Streaming Platform  \
# 9   Age Rating Not Listed.                          Spain                 NA
# 27  Age Rating Not Listed.  Production Country Not Listed                 NA
# 36  Age Rating Not Listed.  Production Country Not Listed                 NA
# 52  Age Rating Not Listed.  Production Country Not Listed                 NA
# 72  Age Rating Not Listed.  Production Country Not Listed                 NA
# 92  Age Rating Not Listed.                  United States                 NA
# 93  Age Rating Not Listed.  Production Country Not Listed                 NA
#
#                                                   URL
# 9   https://www.justwatch.com/in/tv-show/raising-v...
# 27  https://www.justwatch.com/in/tv-show/maxton-ha...
# 36    https://www.justwatch.com/in/tv-show/tulsa-king
# 52   https://www.justwatch.com/in/tv-show/sweet-tooth
# 72     https://www.justwatch.com/in/tv-show/spartacus
# 92  https://www.justwatch.com/in/tv-show/the-walki...
# 93      https://www.justwatch.com/in/tv-show/scorpion

# %% [markdown]
# ## **Calculating Mean IMDB Ratings for both Movies and Tv Shows**

# %%
# Write Your Code here
# Calculating Movies mean IMDb rating
movie_mean_imdb = filtered_df_movies['IMDB Rating'].mean()
movie_mean_imdb_rounded = round(movie_mean_imdb, 2)
print("Mean IMDb Rating for Movies is:", movie_mean_imdb_rounded)

# Calculating Tv Shows mean IMDb rating
tv_mean_imdb = filtered_df_tv_shows['IMDB Rating'].mean()
tv_mean_imdb_rounded = round(tv_mean_imdb, 2)
print("Mean IMDb Rating for Tv Shows is:", tv_mean_imdb_rounded)
# Out:
# Mean IMDb Rating for Movies is: 7.8
# Mean IMDb Rating for Tv Shows is: 7.71

# %% [markdown]
# ### Top 5 Highest IMDB Rating Movies

# %%
top_5_movies = filtered_df_movies.nlargest(5, 'IMDB Rating') # highest imdb rating
print(top_5_movies.loc[:, ['Movie Title', 'IMDB Rating']])
# Out:
#                 Movie Title  IMDB Rating
# 32         12th Fail (2023)          8.9
# 43     The Goat Life (2024)          8.6
# 10   Laapataa Ladies (2024)          8.5
# 8     Manjummel Boys (2024)          8.3
# 21       Oppenheimer (2023)          8.3

# %% [markdown]
# ### Top 5 Highest IMDB Rating Tv Show

# %%
top_5_tv_shows = filtered_df_tv_shows.nlargest(5, 'IMDB Rating') # highest imdb rating
print(top_5_tv_shows.loc[:, ['TV Show Title', 'IMDB Rating']])
# Out:
#                                 TV Show Title  IMDB Rating
# 72                                         NA          8.5
# 36                                         NA          8.0
# 92                                         NA          7.9
# 52                                         NA          7.7
# 27   Maxton Hall: The World Between Us (2024)          7.6

# %% [markdown]
# ## **Analyzing Top Genres**

# %% [markdown]
# ### **Movies**

# %%
# Write Your Code here
# Top Movies Genres
top_movies_genres = filtered_df_movies['Genre'].explode().value_counts()
print("Top Movies Genres:")
print(top_movies_genres)
# Out:
# Top Movies Genres:
# Genre
# Drama                 13
# NA                     9
# Action & Adventure     6
# Science-Fiction        5
# Comedy                 4
# Mystery & Thriller     4
# Horror                 3
# Fantasy                3
# Romance                2
# History                1
# Animation              1
# Kids & Family          1
# War & Military         1
# Crime                  1
# Name: count, dtype: int64

# %%
# visualize movie_genre using wordcloud

import matplotlib.pyplot as plt
from wordcloud import WordCloud

# Create a dictionary of words and their frequencies
word_counts = {}
for genre, count in top_movies_genres.items(): # Iterate over items to get both genre and count
  word_counts[str(genre)] = count  # Convert genre to string

# Create a wordcloud object
wordcloud = WordCloud(width=800, height=400, background_color="white")

# Generate the wordcloud
wordcloud.generate_from_frequencies(word_counts)

# Display the wordcloud
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %% [markdown]
# ###  **Tv shows**

# %%
# Top Movies Genres
top_tv_shows_genres = filtered_df_tv_shows['Genre'].explode().value_counts()
print("Top Tv shhows Genres:")
print(top_tv_shows_genres)
# Out:
# Top Tv shhows Genres:
# Genre
# NA         5
# Drama      2
# Romance    1
# Name: count, dtype: int64

# %%
# Create a dictionary of words and their frequencies
word_counts = {}
for genre, count in top_tv_shows_genres.items(): # Iterate over items to get both genre and count
  word_counts[str(genre)] = count  # Convert genre to string

# Create a wordcloud object
wordcloud = WordCloud(width=800, height=400, background_color="white")

# Generate the wordcloud
wordcloud.generate_from_frequencies(word_counts)

# Display the wordcloud
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %% [markdown]
# ## **Finding Predominant Streaming Service**

# %%
# Write Your Code here

# %%
#Let's Visvalize it using word cloud

# %% [markdown]
# ## **Task 3 :- Data Export**

# %%
#saving final dataframe as Final Data in csv format

# %%
#saving filter data as Filter Data in csv format

# %% [markdown]
# # **Dataset Drive Link (View Access with Anyone) -**

# %% [markdown]
# # ***Congratulations!!! You have completed your Assignment.***
